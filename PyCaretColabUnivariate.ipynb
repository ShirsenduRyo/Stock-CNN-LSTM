# %%
import pandas as pd

# %%
data = pd.read_csv('WFC Daily1.csv')
data.set_index(['Date'],inplace=True)
data = data.dropna()
data = data[['Close']]
data.reset_index(level=0, inplace=True)
data['Date'] = pd.to_datetime(data['Date'])
data.head()
# Out:
#         Date     Close
# 0 2000-01-03  19.56250
# 1 2000-01-04  18.59375
# 2 2000-01-05  18.40625
# 3 2000-01-06  19.21875
# 4 2000-01-07  19.56250

# %%
data['Date']=data['Date'].astype(str)
data['Date'] = pd.to_datetime(data['Date'])
data = data.groupby('Date').sum()
data = data.asfreq(freq ='D')
data['Close'] = data['Close'].ffill()

# %%
# pip install pycaret-ts-alpha

# %%
from pycaret.time_series import *
setup(data, fh = 7, fold = 3, session_id = 123)
# Out:
# INFO:logs:PyCaret TSForecastingExperiment
# INFO:logs:Logging name: ts-default-name
# INFO:logs:ML Usecase: MLUsecase.TIME_SERIES
# INFO:logs:version 3.0.0
# INFO:logs:Initializing setup()
# INFO:logs:self.USI: 36af
# INFO:logs:self.variable_keys: {'display_container', 'fold_param', 'variable_keys', '_available_plots', 'seasonality_present', 'y_transformed', 'data', 'y_train', 'experiment__', 'X', 'gpu_param', 'X_train', 'master_model_container', 'y', 'seasonal_period', 'enforce_pi', 'index_type', 'X_test_transformed', 'fold_generator', 'y_test_transformed', 'y_test', '_ml_usecase', 'html_param', 'strictly_positive', '_all_models', 'memory', 'exogenous_present', 'X_transformed', '_all_models_internal', 'seed', 'y_train_transformed', 'exp_name_log', '_all_metrics', 'fold_groups_param_full', '_gpu_n_jobs_param', 'USI', 'primary_sp_to_use', 'fh', 'idx', 'all_sp_values', 'pipeline', 'enforce_exogenous', 'approach_type', 'n_jobs_param', 'log_plots_param', 'exp_id', 'logging_param', 'X_test', 'X_train_transformed'}
# INFO:logs:Checking environment
# INFO:logs:python_version: 3.7.15
# INFO:logs:python_build: ('default', 'Oct 12 2022 19:14:55')
# INFO:logs:machine: x86_64
# INFO:logs:platform: Linux-5.10.133+-x86_64-with-Ubuntu-18.04-bionic
# INFO:logs:Memory: svmem(total=13616353280, available=12672090112, percent=6.9, used=684204032, free=6120456192, active=867057664, inactive=6267179008, buffers=418344960, cached=6393348096, shared=1200128, slab=298496000)
# INFO:logs:Physical Core: 1
# INFO:logs:Logical Core: 2
# INFO:logs:Checking libraries
# INFO:logs:pd==1.3.5
# INFO:logs:numpy==1.21.6
# INFO:logs:sklearn==1.0.2
# INFO:logs:lightgbm==3.3.3
# INFO:logs:xgboost==0.90
# WARNING:logs:catboost not found
# WARNING:logs:mlflow not found
# INFO:logs:Set Forecast Horizon.
# INFO:logs:Set up Train-Test Splits.
# INFO:logs:Preparing preprocessing pipeline...
# INFO:logs:Finished creating preprocessing pipeline.
# INFO:logs:Pipeline: PyCaretForecastingPipeline(steps=[('forecaster',
#                                    TransformedTargetForecaster(steps=[('model',
#                                                                        DummyForecaster())]))])
# INFO:logs:Set up Seasonal Period.
# INFO:logs:Set up whether Multiplicative components allowed.
# INFO:logs:Creating final display dataframe.
# INFO:logs:Setup Display Container:                     Description                    Value
# 0                    session_id                      123
# 1                        Target                    Close
# 2                      Approach               Univariate
# 3           Exogenous Variables              Not Present
# 4                    Data shape                (8349, 1)
# 5              Train data shape                (8342, 1)
# 6               Test data shape                   (7, 1)
# 7                Fold Generator  ExpandingWindowSplitter
# 8                   Fold Number                        3
# 9   Enforce Prediction Interval                    False
# 10    Seasonal Period(s) Tested                        7
# 11          Seasonality Present                     True
# 12       Seasonalities Detected                      [7]
# 13          Primary Seasonality                        7
# 14     Target Strictly Positive                     True
# 15           Target White Noise                       No
# 16                Recommended d                        1
# 17       Recommended Seasonal D                        0
# 18               Missing Values                        0
# 19                   Preprocess                     True
# 20                     CPU Jobs                       -1
# 21                      Use GPU                    False
# 22               Log Experiment                    False
# 23              Experiment Name          ts-default-name
# 24                          USI                     36af
# INFO:logs:Preparing display monitor
#                     Description                    Value
# 0                    session_id                      123
# 1                        Target                    Close
# 2                      Approach               Univariate
# 3           Exogenous Variables              Not Present
# 4                    Data shape                (8349, 1)
# 5              Train data shape                (8342, 1)
# 6               Test data shape                   (7, 1)
# 7                Fold Generator  ExpandingWindowSplitter
# 8                   Fold Number                        3
# 9   Enforce Prediction Interval                    False
# 10    Seasonal Period(s) Tested                        7
# 11          Seasonality Present                     True
# 12       Seasonalities Detected                      [7]
# 13          Primary Seasonality                        7
# 14     Target Strictly Positive                     True
# 15           Target White Noise                       No
# 16                Recommended d                        1
# 17       Recommended Seasonal D                        0
# 18               Missing Values                        0
# 19                   Preprocess                     True
# 20                     CPU Jobs                       -1
# 21                      Use GPU                    False
# 22               Log Experiment                    False
# 23              Experiment Name          ts-default-name
# 24                          USI                     36af
# WARNING:logs:Wrong xgboost version. Expected xgboost>=1.1.0, got xgboost==(0, 90)
# WARNING:logs:Wrong xgboost version. Expected xgboost>=1.1.0, got xgboost==(0, 90)
# WARNING:logs:Couldn't import catboost.CatBoostRegressor
# WARNING:logs:Couldn't import catboost.CatBoostRegressor
# WARNING:logs:Wrong xgboost version. Expected xgboost>=1.1.0, got xgboost==(0, 90)
# WARNING:logs:Wrong xgboost version. Expected xgboost>=1.1.0, got xgboost==(0, 90)
# WARNING:logs:Couldn't import catboost.CatBoostRegressor
# WARNING:logs:Couldn't import catboost.CatBoostRegressor
# INFO:logs:setup() successfully completed in 0.54s...............

# %%
best = compare_models()
# Out:
#                                                              Model     MAE  \
# lasso_cds_dt             Lasso w/ Cond. Deseasonalize & Detrending  0.3587
# omp_cds_dt       Orthogonal Matching Pursuit w/ Cond. Deseasona...  0.5058
# naive                                             Naive Forecaster  0.5567
# huber_cds_dt             Huber w/ Cond. Deseasonalize & Detrending  0.5667
# lr_cds_dt               Linear w/ Cond. Deseasonalize & Detrending  0.5699
# br_cds_dt        Bayesian Ridge w/ Cond. Deseasonalize & Detren...  0.5704
# gbr_cds_dt       Gradient Boosting w/ Cond. Deseasonalize & Det...  0.5704
# ridge_cds_dt             Ridge w/ Cond. Deseasonalize & Detrending  0.5701
# lar_cds_dt       Least Angular Regressor w/ Cond. Deseasonalize...  0.5699
# exp_smooth                                   Exponential Smoothing  0.5879
# ets                                                            ETS  0.5884
# theta                                             Theta Forecaster  0.5899
# et_cds_dt          Extra Trees w/ Cond. Deseasonalize & Detrending  0.6122
# rf_cds_dt        Random Forest w/ Cond. Deseasonalize & Detrending  0.6651
# lightgbm_cds_dt  Light Gradient Boosting w/ Cond. Deseasonalize...  0.7152
# en_cds_dt          Elastic Net w/ Cond. Deseasonalize & Detrending  0.8298
# arima                                                        ARIMA  0.8822
# knn_cds_dt         K Neighbors w/ Cond. Deseasonalize & Detrending  0.9073
# ada_cds_dt            AdaBoost w/ Cond. Deseasonalize & Detrending   1.006
# dt_cds_dt        Decision Tree w/ Cond. Deseasonalize & Detrending  1.0492
# snaive                                   Seasonal Naive Forecaster  1.6048
# croston                                                    Croston  2.2354
# par_cds_dt       Passive Aggressive w/ Cond. Deseasonalize & De...  3.1367
# polytrend                              Polynomial Trend Forecaster  6.0421
# llar_cds_dt      Lasso Least Angular Regressor w/ Cond. Deseaso...   6.044
# grand_means                                 Grand Means Forecaster  8.8766
#
#                    RMSE    MAPE   SMAPE    MASE   RMSSE        R2  TT (Sec)
# lasso_cds_dt     0.4806  0.0079  0.0079  0.3614  0.3255    0.1276    1.3233
# omp_cds_dt       0.6651  0.0112  0.0112  0.5097  0.4506   -0.5778    1.3200
# naive            0.7257  0.0123  0.0124   0.561  0.4916   -0.8936    1.1967
# huber_cds_dt     0.7311  0.0125  0.0126  0.5711  0.4953   -0.9245    1.3833
# lr_cds_dt        0.7202  0.0126  0.0127  0.5743  0.4879   -0.8708    1.4100
# br_cds_dt        0.7207  0.0126  0.0127  0.5748  0.4882   -0.8734    1.3767
# gbr_cds_dt       0.7217  0.0126  0.0127  0.5748  0.4889   -0.8582    3.0000
# ridge_cds_dt     0.7204  0.0126  0.0127  0.5745   0.488   -0.8718    1.3067
# lar_cds_dt       0.7202  0.0126  0.0127  0.5743  0.4879   -0.8708    1.3000
# exp_smooth       0.7467   0.013  0.0131  0.5925  0.5058   -1.0137    3.0133
# ets              0.7472   0.013  0.0131   0.593  0.5061   -1.0165    0.9733
# theta            0.7463   0.013  0.0131  0.5945  0.5056   -1.0122    0.6967
# et_cds_dt        0.8076  0.0135  0.0137   0.617  0.5471   -1.3475    3.2033
# rf_cds_dt        0.8373  0.0147  0.0149  0.6703  0.5672   -1.6078    5.7800
# lightgbm_cds_dt  0.8975  0.0159  0.0161  0.7209   0.608   -1.9613    1.8700
# en_cds_dt        0.9219  0.0184  0.0186  0.8363  0.6245   -2.0792    1.3533
# arima            1.0962  0.0197    0.02  0.8892  0.7426   -3.6265    1.3000
# knn_cds_dt       1.0553  0.0201  0.0203  0.9143  0.7148     -3.28    1.7800
# ada_cds_dt       1.1401   0.022  0.0223  1.0134  0.7722   -5.0474    1.8900
# dt_cds_dt        1.3817  0.0231  0.0235  1.0572  0.9359   -6.1197    1.4000
# snaive           1.7557  0.0357  0.0366  1.6173  1.1894   -9.9561    0.0267
# croston          2.2989  0.0493  0.0506  2.2523  1.5571   -18.921    0.0367
# par_cds_dt       3.7697  0.0679  0.0746  3.1589  2.5527 -112.4841    1.3133
# polytrend         6.065  0.1344  0.1255  6.0888  4.1084 -129.3543    0.0400
# llar_cds_dt      6.0668  0.1344  0.1256  6.0907  4.1095 -129.4284    1.3000
# grand_means      8.8933  0.1957  0.2172  8.9435  6.0236 -310.3421    0.0267
# INFO:logs:master_model_container: 26
# INFO:logs:display_container: 2
# INFO:logs:BaseCdsDtForecaster(regressor=Lasso(random_state=123), sp=7, window_length=7)
# INFO:logs:compare_models() successfully completed......................................

# %% [markdown]
# # Prediction

# %%
prediction = predict_model(best, fh = 90)
prediction.to_frame()
prediction
# Out:
# WARNING:logs:predict_model >> Prediction Indices do not match test indices. Metrics will not be displayed.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-edc1bbd9863a> in <module>
#       1 prediction = predict_model(best, fh = 90)
# ----> 2 prediction.to_frame()
#       3 prediction
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_frame'
