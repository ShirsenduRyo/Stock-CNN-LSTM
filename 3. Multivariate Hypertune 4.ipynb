# %% [markdown]
# # The Packages

# %%
# Two models not trained with Eval metrics created

# %%
import numpy as np
import pandas as pd
import os
import gc
import datetime
import warnings

# %%
import statsmodels.api as sm
from datetime import date

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
import tensorflow as tf
import math 
# keras = tf.keras
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LSTM
from tensorflow.keras import losses
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.utils import plot_model

# %%
tf.__version__
# Out:
# '2.10.1'

# %%
# DATA VISUALIZATION
# ------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (20.0, 10.0)
sns.set_style("darkgrid")
sns.color_palette("mako", as_cmap=True)
import plotly.express as px

# %%
# CONFIGURATIONS
# ------------------------------------------------------
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.2f}'.format
warnings.filterwarnings('ignore')

# %% [markdown]
# # Utility Functions

# %%
def plotSeries(time, series, lab,form='-'):
    plt.plot(time, series, form, label=lab)
    plt.xlabel("Date")
    plt.ylabel("Close Price")
    plt.grid(True)

# %%
def plotEvaluation(testData, predData, columns):
    testDf = pd.DataFrame(testData, columns = columns)
    predDf = pd.DataFrame(predData, columns = columns)
    plt.figure(figsize=(15,5))
    plt.plot(testDf.Close, label='Real')
    plt.plot(predDf.Close, label='Prediction')

    plt.legend(loc="best")
    #for saving figures
    plt.show()

# %% [markdown]
# # The Data

# %%
wfc = pd.read_csv('Dataset/Treasury.csv')

# %%
wfc.head()
# Out:
#          Date  Close  Weekday  volumeChange  closeChange  EMA 10  EMA 20  \
# 0  2000-01-03  19.56        0         68.61        -4.95   19.56   19.56
# 1  2000-01-04  18.59        1        -46.00        -1.01   19.03   19.05
# 2  2000-01-05  18.41        2          1.20         4.41   18.78   18.82
# 3  2000-01-06  19.22        3         -7.39         1.79   18.92   18.93
# 4  2000-01-07  19.56        4         16.11        -3.19   19.11   19.08
#
#    EMA 50  EMA 100  ROC5  ROC10  ROC15  ROC20     DTB6    DGS5
# 0   19.56    19.56  0.00   0.00   0.00   0.00 50550.00 6050.00
# 1   19.07    19.07  0.00   0.00   0.00   0.00 50500.00 6040.00
# 2   18.84    18.85  0.00   0.00   0.00   0.00 50490.00 6051.00
# 3   18.94    18.94  0.00   0.00   0.00   0.00 50440.00 6046.00
# 4   19.07    19.07 -0.59   0.00   0.00   0.00 50420.00 6042.00

# %%
wfc.Date.dtype
# Out:
# dtype('O')

# %%
wfc['Date'] = pd.to_datetime(wfc['Date'])
#wfc.set_index(['Date'],inplace=True)

# %%
wfc.head()
# Out:
#         Date  Close  Weekday  volumeChange  closeChange  EMA 10  EMA 20  \
# 0 2000-01-03  19.56        0         68.61        -4.95   19.56   19.56
# 1 2000-01-04  18.59        1        -46.00        -1.01   19.03   19.05
# 2 2000-01-05  18.41        2          1.20         4.41   18.78   18.82
# 3 2000-01-06  19.22        3         -7.39         1.79   18.92   18.93
# 4 2000-01-07  19.56        4         16.11        -3.19   19.11   19.08
#
#    EMA 50  EMA 100  ROC5  ROC10  ROC15  ROC20     DTB6    DGS5
# 0   19.56    19.56  0.00   0.00   0.00   0.00 50550.00 6050.00
# 1   19.07    19.07  0.00   0.00   0.00   0.00 50500.00 6040.00
# 2   18.84    18.85  0.00   0.00   0.00   0.00 50490.00 6051.00
# 3   18.94    18.94  0.00   0.00   0.00   0.00 50440.00 6046.00
# 4   19.07    19.07 -0.59   0.00   0.00   0.00 50420.00 6042.00

# %%
wfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5754 entries, 0 to 5753
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5754 non-null   datetime64[ns]
#  1   Close         5754 non-null   float64
#  2   Weekday       5754 non-null   int64
#  3   volumeChange  5754 non-null   float64
#  4   closeChange   5754 non-null   float64
#  5   EMA 10        5754 non-null   float64
#  6   EMA 20        5754 non-null   float64
#  7   EMA 50        5754 non-null   float64
#  8   EMA 100       5754 non-null   float64
#  9   ROC5          5754 non-null   float64
#  10  ROC10         5754 non-null   float64
#  11  ROC15         5754 non-null   float64
#  12  ROC20         5754 non-null   float64
#  13  DTB6          5754 non-null   float64
#  14  DGS5          5754 non-null   float64
# dtypes: datetime64[ns](1), float64(13), int64(1)
# memory usage: 674.4 KB

# %%
wfc.describe()
# Out:
#         Close  Weekday  volumeChange  closeChange  EMA 10  EMA 20  EMA 50  \
# count 5754.00  5754.00       5754.00      5754.00 5754.00 5754.00 5754.00
# mean    36.38     2.02          5.93         0.04   36.36   36.34   36.27
# std     11.75     1.40         39.58         2.45   11.71   11.68   11.59
# min      8.12     0.00        -84.21       -23.82   10.68   12.45   15.86
# 25%     26.74     1.00        -18.62        -0.84   26.76   26.85   26.86
# 50%     32.64     2.00         -0.81         0.00   32.47   32.43   32.12
# 75%     47.79     3.00         20.93         0.86   47.87   47.96   48.12
# max     65.93     4.00        480.19        32.76   65.12   64.10   61.54
#
#        EMA 100    ROC5   ROC10   ROC15   ROC20     DTB6    DGS5
# count  5754.00 5754.00 5754.00 5754.00 5754.00  5754.00 5754.00
# mean     36.16    0.05    0.04    0.04    0.04  6689.76 2101.97
# std      11.45    0.99    0.65    0.52    0.43 13368.12 1528.92
# min      17.93  -10.67   -6.28   -4.60   -3.39     0.00    0.00
# 25%      27.03   -0.34   -0.22   -0.16   -0.13    14.00 1045.00
# 50%      31.70    0.04    0.04    0.04    0.04  1012.00 2031.00
# 75%      47.94    0.43    0.30    0.25    0.22  4096.00 3068.00
# max      59.00   11.66    7.05    5.18    3.79 60240.00 6083.00

# %%
correlation = wfc.corr ()  
correlation. style.background_gradient ()
# Out:
# <style type="text/css">
# #T_bc496_row0_col0, #T_bc496_row0_col4, #T_bc496_row1_col1, #T_bc496_row2_col2, #T_bc496_row3_col3, #T_bc496_row4_col0, #T_bc496_row4_col4, #T_bc496_row4_col5, #T_bc496_row5_col4, #T_bc496_row5_col5, #T_bc496_row5_col6, #T_bc496_row6_col5, #T_bc496_row6_col6, #T_bc496_row6_col7, #T_bc496_row7_col6, #T_bc496_row7_col7, #T_bc496_row8_col8, #T_bc496_row9_col9, #T_bc496_row10_col10, #T_bc496_row11_col11, #T_bc496_row12_col12, #T_bc496_row13_col13 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_bc496_row0_col1, #T_bc496_row1_col10, #T_bc496_row4_col1, #T_bc496_row4_col11, #T_bc496_row5_col1, #T_bc496_row6_col1, #T_bc496_row7_col1, #T_bc496_row12_col2, #T_bc496_row12_col9, #T_bc496_row13_col2 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T
{
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_bc496_row8_col6, #T_bc496_row10_col5 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_bc496_row8_col9 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_bc496_row8_col10 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_bc496_row8_col11 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_bc496_row9_col3 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_bc496_row9_col5 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_bc496_row9_col6 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_bc496_row9_col7 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_bc496_row9_col8 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_bc496_row9_col10, #T_bc496_row12_col13 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_bc496_row9_col11 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_bc496_row10_col0, #T_bc496_row10_col12, #T_bc496_row11_col0, #T_bc496_row11_col12 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_bc496_row10_col6 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_bc496_row10_col7 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_bc496_row10_col8 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_bc496_row10_col9 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_bc496_row10_col11, #T_bc496_row11_col10 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_bc496_row11_col3, #T_bc496_row11_col6 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_bc496_row11_col7 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_bc496_row11_col8 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_bc496_row11_col9 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_bc496_row12_col10 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_bc496_row13_col0, #T_bc496_row13_col4, #T_bc496_row13_col5, #T_bc496_row13_col6, #T_bc496_row13_col7 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_bc496_row13_col3 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_bc496_row13_col11 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_bc496_row13_col12 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bc496">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc496_level0_col0" class="col_heading level0 col0" >Close</th>
#       <th id="T_bc496_level0_col1" class="col_heading level0 col1" >Weekday</th>
#       <th id="T_bc496_level0_col2" class="col_heading level0 col2" >volumeChange</th>
#       <th id="T_bc496_level0_col3" class="col_heading level0 col3" >closeChange</th>
#       <th id="T_bc496_level0_col4" class="col_heading level0 col4" >EMA 10</th>
#       <th id="T_bc496_level0_col5" class

# %%
#Dropping Volume for Clearer Scale

# %% [markdown]
# # The Split

# %%
min_date = wfc.Date.min()
max_date = wfc.Date.max()
print("Min:", min_date, "Max:", max_date)
# Out:
# Min: 2000-01-03 00:00:00 Max: 2022-11-11 00:00:00

# %%
train_percent = .75
valid_percent = .12

time_between = max_date - min_date

train_cutoff = min_date + train_percent*time_between
valid_cutoff = min_date + (train_percent + valid_percent)*time_between

print("Training Cutoff Date: {:s}".format(str(train_cutoff)))
print("Validation Cutoff Date: {:s}".format(str(valid_cutoff)))
# Out:
# Training Cutoff Date: 2017-02-23 00:00:00
# Validation Cutoff Date: 2019-11-21 18:14:24

# %%
train_df = wfc[wfc.Date <= train_cutoff]
valid_df = wfc[(wfc.Date > train_cutoff) & (wfc.Date <= valid_cutoff)]
test_df = wfc[wfc.Date > valid_cutoff]

# %%
print("Dataset shape: {:s}".format(str(wfc.shape)))
print("Train dataset shape: {:s}".format(str(train_df.shape)))
print("Vaid dataset shape: {:s}".format(str(valid_df.shape)))
print("Test dataset shape: {:s}".format(str(test_df.shape)))
# Out:
# Dataset shape: (5754, 15)
# Train dataset shape: (4313, 15)
# Vaid dataset shape: (692, 15)
# Test dataset shape: (749, 15)

# %% [markdown]
# # Stock Price Graph

# %%
plotSeries(train_df.Date, train_df.Close, "Training Data")
plotSeries(valid_df.Date, valid_df.Close, "Validation Data")
plotSeries(test_df.Date, test_df.Close, "Test Data")
plt.legend(loc='upper left')

# %% [markdown]
# # Feature Engineering

# %%
train_df.set_index(['Date'],inplace=True)
test_df.set_index(['Date'],inplace=True)
valid_df.set_index(['Date'],inplace=True)

# %%
train_df.head()
# Out:
#             Close  Weekday  volumeChange  closeChange  EMA 10  EMA 20  EMA 50  \
# Date
# 2000-01-03  19.56        0         68.61        -4.95   19.56   19.56   19.56
# 2000-01-04  18.59        1        -46.00        -1.01   19.03   19.05   19.07
# 2000-01-05  18.41        2          1.20         4.41   18.78   18.82   18.84
# 2000-01-06  19.22        3         -7.39         1.79   18.92   18.93   18.94
# 2000-01-07  19.56        4         16.11        -3.19   19.11   19.08   19.07
#
#             EMA 100  ROC5  ROC10  ROC15  ROC20     DTB6    DGS5
# Date
# 2000-01-03    19.56  0.00   0.00   0.00   0.00 50550.00 6050.00
# 2000-01-04    19.07  0.00   0.00   0.00   0.00 50500.00 6040.00
# 2000-01-05    18.85  0.00   0.00   0.00   0.00 50490.00 6051.00
# 2000-01-06    18.94  0.00   0.00   0.00   0.00 50440.00 6046.00
# 2000-01-07    19.07 -0.59   0.00   0.00   0.00 50420.00 6042.00

# %%
scaler = MinMaxScaler()

trainNorm = scaler.fit_transform(train_df.values)
testNorm = scaler.transform(test_df.values)
validNorm = scaler.transform(valid_df.values)

trainNormDf = pd.DataFrame(trainNorm, columns=train_df.columns)
testNormDf = pd.DataFrame(testNorm, columns=test_df.columns)
validNormDf = pd.DataFrame(validNorm, columns=valid_df.columns)

# %%
def splitSequence(sequence, look_back, forecast_horizon):
    X, y = list(), list()
    for i in range(len(sequence)): 
        lag_end = i + look_back
        forecast_end = lag_end + forecast_horizon
        if forecast_end > len(sequence):
            break
        seq_x, seq_y = sequence[i:lag_end], sequence[lag_end:forecast_end]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
LOOK_BACK = 24
FORECAST_RANGE = 5
n_features = len(trainNormDf.columns)

# %%
#Add valid df
Xtrain, Ytrain = splitSequence(trainNormDf, look_back=LOOK_BACK, forecast_horizon=FORECAST_RANGE)
Xvalid, Yvalid = splitSequence(validNormDf, look_back=LOOK_BACK, forecast_horizon=FORECAST_RANGE)
Xtest, Ytest = splitSequence(testNormDf, look_back=LOOK_BACK, forecast_horizon=FORECAST_RANGE)

# %%
print(Xtrain.shape)
print(Ytrain.shape)
print(Xvalid.shape)
print(Yvalid.shape)
print(Xtest.shape)
print(Ytest.shape)
# Out:
# (4285, 24, 14)
# (4285, 5, 14)
# (664, 24, 14)
# (664, 5, 14)
# (721, 24, 14)
# (721, 5, 14)

# %%
def inverse_transform(y_test, yhat):
    y_test_reshaped = y_test.reshape(-1, y_test.shape[-1])
    yhat_reshaped = yhat.reshape(-1, yhat.shape[-1])
    yhat_inverse = scaler.inverse_transform(yhat_reshaped)
    y_test_inverse = scaler.inverse_transform(y_test_reshaped)
    return yhat_inverse, y_test_inverse

# %%
def plotMAPEperRange(testData, predData):
    y_test_inverse_time_step  = testData.reshape(int(testData.shape[0]/FORECAST_RANGE), \
                                                      FORECAST_RANGE, testData.shape[-1])
    yhat_inverse_time_step = predData.reshape(int(predData.shape[0]/FORECAST_RANGE), \
                                                  FORECAST_RANGE, predData.shape[-1])
    # yhat_inverse_time_step and y_test_inverse_time_step are both same dimension.
    time_step_list_yhat = [[] for i in range(FORECAST_RANGE)]
    time_step_list_y_test = [[] for i in range(FORECAST_RANGE)]
    for i in range(0, yhat_inverse_time_step.shape[0]):
        for j in range(0, yhat_inverse_time_step.shape[1]):
            time_step_list_yhat[j].append(list(yhat_inverse_time_step[i][j]))
            time_step_list_y_test[j].append(list(y_test_inverse_time_step[i][j]))
    yhat_time_step = np.array(time_step_list_yhat)
    yhat_time_step = yhat_time_step.reshape(yhat_time_step.shape[0], -1)
    y_test_time_step = np.array(time_step_list_y_test)
    y_test_time_step = y_test_time_step.reshape(y_test_time_step.shape[0], -1)
    # plotting
    mape_list = []
    for i in range(0, FORECAST_RANGE):
        mape = mape_(y_test_time_step[i], yhat_time_step[i])
        print(mape)
        mape_list.append(mape)
    plt.plot(range(0, FORECAST_RANGE), mape_list, marker='o')
    plt.xticks((range(0, FORECAST_RANGE)))
    plt.xlabel('Forecast Range')
    plt.ylabel('MAPE')

# %%
def evaluate_forecast(y_test_inverse, yhat_inverse):
    mse_ = tf.keras.losses.MeanSquaredError()
    mae_ = tf.keras.losses.MeanAbsoluteError()
    mape_ = tf.keras.losses.MeanAbsolutePercentageError()
    mae = mae_(y_test_inverse,yhat_inverse)
    print('mae:', mae)
    mse = mse_(y_test_inverse,yhat_inverse)
    print('mse:', mse)
    mape = mape_(y_test_inverse,yhat_inverse)
    print('mape:', mape)

# %%
mse_ = tf.keras.losses.MeanSquaredError()
mae_ = tf.keras.losses.MeanAbsoluteError()
mape_ = tf.keras.losses.MeanAbsolutePercentageError()
# mae = mae_(y_test_inverse,yhat_inverse)
# # print('mae:', mae)
# mse = mse_(y_test_inverse,yhat_inverse)
# # print('mse:', mse)
# mape = mape_(y_test_inverse,yhat_inverse)
# # print('mape:', mape)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, TimeDistributed, Conv1D, MaxPooling1D, Flatten, Bidirectional, Input, Flatten, Activation, Reshape, RepeatVector, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %% [markdown]
# # Multihead CNN LSTM Model

# %%
tf.keras.backend.clear_session()

# %%
input_layer = Input(shape=(LOOK_BACK, n_features)) 
head_list = []
for i in range(0, n_features):
    conv_layer_head = Conv1D(filters=4, kernel_size=7, activation='relu')(input_layer)
    conv_layer_head_2 = Conv1D(filters=6, kernel_size=11, activation='relu')(conv_layer_head)
    conv_layer_flatten = Flatten()(conv_layer_head_2)
    head_list.append(conv_layer_flatten)

concat_cnn = Concatenate(axis=1)(head_list)
reshape = Reshape((head_list[0].shape[1], n_features))(concat_cnn)
lstm = LSTM(100)(reshape)
repeat = RepeatVector(FORECAST_RANGE)(lstm)
lstm_2 = LSTM(100, return_sequences=True)(repeat)
dropout = Dropout(0.2)(lstm_2)
dense = Dense(n_features, activation='linear')(dropout)
multi_head_cnn_lstm_model = Model(inputs=input_layer, outputs=dense)
multi_head_cnn_lstm_model.compile(optimizer='adam', loss='mse')

# %% [markdown]
# ## Tuning Hypertuning LR

# %%
lrSchedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch:1e-8*10**(epoch/20))
earlyStop = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=45, restore_best_weights=True)

# %%
optimizer = Adam(1e-3)
multi_head_cnn_lstm_model.compile(loss=tf.keras.losses.MeanSquaredError(),
             optimizer = optimizer,
             metrics = ["mae"])

# %%
history = multi_head_cnn_lstm_model.fit(Xtrain,Ytrain,batch_size=128, epochs=500, callbacks=[lrSchedule, earlyStop])
# Out:
# Epoch 1/500
# 34/34 [==============================] - 8s 67ms/step - loss: 0.2181 - mae: 0.4104 - lr: 1.0000e-08
# Epoch 2/500
# 34/34 [==============================] - 2s 68ms/step - loss: 0.2181 - mae: 0.4103 - lr: 1.1220e-08
# Epoch 3/500
# 34/34 [==============================] - 3s 74ms/step - loss: 0.2181 - mae: 0.4103 - lr: 1.2589e-08
# Epoch 4/500
# 34/34 [==============================] - 3s 76ms/step - loss: 0.2181 - mae: 0.4103 - lr: 1.4125e-08
# Epoch 5/500
# 34/34 [==============================] - 3s 74ms/step - loss: 0.2180 - mae: 0.4103 - lr: 1.5849e-08
# Epoch 6/500
# 34/34 [==============================] - 3s 74ms/step - loss: 0.2181 - mae: 0.4103 - lr: 1.7783e-08
# Epoch 7/500
# 34/34 [==============================] - 3s 74ms/step - loss: 0.2181 - mae: 0.4103 - lr: 1.9953e-08
# Epoch 8/500
# 34/34 [==============================] - 3s 74ms/step - loss: 0.2180 - mae: 0.4103 - lr: 2.2387e-08
# Epoch 9/500
# 34/34 [==============================] - 2s 73ms/step - loss: 0.2180 - mae: 0.4103 - lr: 2.5119e-08
# Epoch 10/500
# 34/34 [==============================] - 2s 73ms/step - loss: 0.2180 - mae: 0.4103 - lr: 2.8184e-08
# Epoch 11/500
# 34/34 [==============================] - 3s 74ms/step - loss: 0.2180 - mae: 0.4103 - lr: 3.1623e-08
# Epoch 12/500
# 34/34 [==============================] - 3s 74ms/step - loss: 0.2180 - mae: 0.4102 - lr: 3.5481e-08
# Epoch 13/500
# 34/34 [==============================] - 3s 77ms/step - loss: 0.2180 - mae: 0.4102 - lr: 3.9811e-08
# Epoch 14/500
# 34/34 [==============================] - 3s 77ms/step - loss: 0.2179 - mae: 0.4102 - lr: 4.4668e-08
# Epoch 15/500
# 34/34 [==============================] - 3s 77ms/step - loss: 0.2179 - mae: 0.4102 - lr: 5.0119e-08
# Epoch 16/500
# 34/34 [==============================] - 3s 77ms/step - loss: 0.2179 - mae: 0.4102 - lr: 5.6234e-08
# Epoch 17/500
# 34/34 [==============================] - 3s 78ms/step - loss: 0.2179 - mae: 0.4101 - lr: 6.3096e-08
# Epoch 18/500
# 34/34 [==============================] - 3s 79ms/step - loss: 0.2178 - mae: 0.4101 - lr: 7.0795e-08
# Epoch 19/500
# 34/34 [==============================] - 3s 78ms/step - loss: 0.2178 - mae: 0.4101 - lr: 7.9433e-08
# Epoch 20/500
# 34/34 [==============================] - 3s 79ms/step - loss: 0.2178 - mae: 0.4100 - lr: 8.9125e-08
# Epoch 21/500
# 34/34 [==============================] - 3s 76ms/step - loss: 0.2177 - mae: 0.4100 - lr: 1.0000e-07
# Epoch 22/500
# 34/34 [==============================] - 3s 77ms/step - loss: 0.2177 - mae: 0.4099 - lr: 1.1220e-07
# Epoch 23/500
# 34/34 [==============================] - 3s 77ms/step - loss: 0.2176 - mae: 0.4099 - lr: 1.2589e-07
# Epoch 24/500
# 34/34 [==============================] - 3s 78ms/step - loss: 0.2176 - mae: 0.4098 - lr: 1.4125e-07
# Epoch 25/500
# 34/34 [==============================] - 3s 79ms/step - loss: 0.2175 - mae: 0.4097 - lr: 1.5849e-07
# Epoch 26/500
# 34/34 [==============================] - 3s 79ms/step - loss: 0.2174 - mae: 0.4097 - lr: 1.7783e-07
# Epoch 27/500
# 34/34 [==============================] - 3s 80ms/step - loss: 0.2173 - mae: 0.4096 - lr: 1.9953e-07
# Epoch 28/500
# 34/34 [==============================] - 3s 78ms/step - loss: 0.2172 - mae: 0.4095 - lr: 2.2387e-07
# Epoch 29/500
# 34/34 [==============================] - 3s 77ms/step - loss: 0.2171 - mae: 0.4094 - lr: 2.5119e-07
# Epoch 30/500
# 34/34 [==============================] - 3s 79ms/step - loss: 0.2170 - mae: 0.4092 - lr: 2.8184e-07
# Epoch 31/500
# 34/34 [==============================] - 3s 77ms/step - loss: 0
500
# 34/34 [==============================] - 3s 76ms/step - loss: 0.1412 - mae: 0.2617 - lr: 4.4668
# Epoch 175/500
# 34/34 [==============================] - 3s 76ms/step - loss: 0.1825 - mae: 0.2907 - lr: 5.0119
# Epoch 176/500
# 34/34 [==============================] - 3s 77ms/step - loss: 0.2226 - mae: 0.3307 - lr: 5.6234
# Epoch 177/500
# 34/34 [==============================] - 3s 79ms/step - loss: 0.3959 - mae: 0.4419 - lr: 6.3096
# Epoch 178/500
# 34/34 [==============================] - 3s 75ms/step - loss: 0.2136 - mae: 0.3201 - lr: 7.0795
# Epoch 179/500
# 34/34 [==============================] - 3s 75ms/step - loss: 0.5482 - mae: 0.5153 - lr: 7.9433

# %%
plt.figure(figsize=(20,8))
plt.semilogx(history.history["lr"], history.history["loss"])

# %%
plt.figure(figsize=(20,8))
plt.semilogx(history.history["lr"], history.history["loss"])
plt.axis([1e-3, 1e-1, 0, 0.1])
# Out:
# (0.001, 0.1, 0.0, 0.1)

# %% [markdown]
# ## Final Model

# %%
multi_head_cnn_lstm_model.compile(loss=tf.keras.losses.MeanSquaredError(),
              optimizer=Adam(1e-3),
              metrics=['mae'])

# %%
# plot_model(model=model_enc_dec, show_shapes=True)

# %%
log_dir = "logs\\" + datetime.datetime.now().strftime("%d-%m-%Y_%H%M%S")
# model_path = ""
tensorboard_callback = [
#                         tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1),
#                         ModelCheckpoint(model_path, verbose=1, save_best_only=True),
                        ReduceLROnPlateau(monitor='val_mae', factor=0.3,patience=5, min_lr=1e-6, verbose=1),
#                         CSVLogger(csv_path),
                        TensorBoard(),
                        EarlyStopping(monitor= "val_mae", patience=10, restore_best_weights=True)
                       ]

# %%
history = multi_head_cnn_lstm_model.fit(Xtrain, Ytrain,batch_size=128, epochs=100, verbose=1,validation_data=(Xvalid, Yvalid), \
                            callbacks=tensorboard_callback)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 10s 114ms/step - loss: 0.0041 - mae: 0.0378 - val_loss: 0.0040 - val_mae: 0.0376 - lr: 0.0010
# Epoch 2/100
# 34/34 [==============================] - 2s 74ms/step - loss: 0.0039 - mae: 0.0362 - val_loss: 0.0038 - val_mae: 0.0364 - lr: 0.0010
# Epoch 3/100
# 34/34 [==============================] - 3s 75ms/step - loss: 0.0038 - mae: 0.0357 - val_loss: 0.0038 - val_mae: 0.0353 - lr: 0.0010
# Epoch 4/100
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0037 - mae: 0.0354 - val_loss: 0.0037 - val_mae: 0.0353 - lr: 0.0010
# Epoch 5/100
# 34/34 [==============================] - 3s 74ms/step - loss: 0.0037 - mae: 0.0351 - val_loss: 0.0036 - val_mae: 0.0346 - lr: 0.0010
# Epoch 6/100
# 34/34 [==============================] - 3s 76ms/step - loss: 0.0037 - mae: 0.0347 - val_loss: 0.0037 - val_mae: 0.0352 - lr: 0.0010
# Epoch 7/100
# 34/34 [==============================] - 2s 68ms/step - loss: 0.0036 - mae: 0.0343 - val_loss: 0.0035 - val_mae: 0.0338 - lr: 0.0010
# Epoch 8/100
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0036 - mae: 0.0341 - val_loss: 0.0035 - val_mae: 0.0339 - lr: 0.0010
# Epoch 9/100
# 34/34 [==============================] - 3s 75ms/step - loss: 0.0036 - mae: 0.0339 - val_loss: 0.0035 - val_mae: 0.0336 - lr: 0.0010
# Epoch 10/100
# 34/34 [==============================] - 3s 75ms/step - loss: 0.0035 - mae: 0.0336 - val_loss: 0.0035 - val_mae: 0.0348 - lr: 0.0010
# Epoch 11/100
# 34/34 [==============================] - 3s 75ms/step - loss: 0.
ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0031 - mae: 0.0302 - val_loss: 0.0031 - val_mae: 0.0310 - lr: 3.0000e-04
# Epoch 35/100
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0031 - mae: 0.0301 - val_loss: 0.0030 - val_mae: 0.0300 - lr: 9.0000e-05
# Epoch 36/100
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0031 - mae: 0.0300 - val_loss: 0.0030 - val_mae: 0.0297 - lr: 9.0000e-05
# Epoch 37/100
# 34/34 [==============================] - 3s 75ms/step - loss: 0.0031 - mae: 0.0301 - val_loss: 0.0031 - val_mae: 0.0302 - lr: 9.0000e-05
# Epoch 38/100
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0031 - mae: 0.0300 - val_loss: 0.0031 - val_mae: 0.0301 - lr: 9.0000e-05
# Epoch 39/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0031 - mae: 0.0300
# Epoch 39: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0031 - mae: 0.0300 - val_loss: 0.0030 - val_mae: 0.0299 - lr: 9.0000e-05

# %% [markdown]
# ## Keras Score

# %%
trainScore = multi_head_cnn_lstm_model.evaluate(Xtrain, Ytrain, verbose=1)
validScore = multi_head_cnn_lstm_model.evaluate(Xvalid, Yvalid, verbose=1)
testScore = multi_head_cnn_lstm_model.evaluate(Xtest, Ytest, verbose=1)
# Out:
# 134/134 [==============================] - 1s 9ms/step - loss: 0.0027 - mae: 0.0243
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0030 - mae: 0.0296
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0039 - mae: 0.0370

# %%
testScore, validScore, trainScore
# Out:
# ([0.0038708702195435762, 0.0370241180062294],
#  [0.003014274640008807, 0.029631221666932106],
#  [0.002667410299181938, 0.024333415552973747])

# %%
yhat = multi_head_cnn_lstm_model.predict(Xtest, verbose=0)

# %%
predData, testData = inverse_transform(Ytest, yhat)
evaluate_forecast(testData, predData)
# Out:
# mae: tf.Tensor(58.571365, shape=(), dtype=float32)
# mse: tf.Tensor(40213.766, shape=(), dtype=float32)
# mape: tf.Tensor(1135903400.0, shape=(), dtype=float32)

# %%
plotEvaluation(testData, predData, columns = testNormDf.columns)

# %% [markdown]
# ## Ploting The Evaluation

# %%
plotMAPEperRange(testData, predData)
# Out:
# tf.Tensor(1007188200.0, shape=(), dtype=float32)
# tf.Tensor(1086933400.0, shape=(), dtype=float32)
# tf.Tensor(1023369000.0, shape=(), dtype=float32)
# tf.Tensor(880817700.0, shape=(), dtype=float32)
# tf.Tensor(1681208800.0, shape=(), dtype=float32)

# %%
def displayMetricsByFeatures(testData, predData, columns):
    for i in range(0, len(columns)):
        print('->', columns[i])
        mae = mae_(testData[:,i],predData[:,i])
        print('mae:', mae)
        mse = mse_(testData[:,i],predData[:,i])
        print('mse:', mse)
        mape = mape_(testData[:,i],predData[:,i])
        print('mape:', mape)

# %%
def displayMetricsByColumn(testData, predData, columns, i):

    print('->', columns[i])
    mae = mae_(testData[:,i],predData[:,i])
    print('mae:', mae)
    mse = mse_(testData[:,i],predData[:,i])
    print('mse:', mse)
    mape = mape_(testData[:,i],predData[:,i])
    print('mape:', mape)

# %%
displayMetricsByColumn(testData, predData, train_df.columns, 0)
# Out:
# -> Close
# mae: tf.Tensor(1.8627146, shape=(), dtype=float32)
# mse: tf.Tensor(6.559395, shape=(), dtype=float32)
# mape: tf.Tensor(5.0746317, shape=(), dtype=float32)

# %%
displayMetricsByFeatures(testData, predData, train_df.columns)
# Out:
# -> Close
# mae: tf.Tensor(1.8627146, shape=(), dtype=float32)
# mse: tf.Tensor(6.559395, shape=(), dtype=float32)
# mape: tf.Tensor(5.0746317, shape=(), dtype=float32)
# -> Weekday
# mae: tf.Tensor(0.28738454, shape=(), dtype=float32)
# mse: tf.Tensor(0.32752675, shape=(), dtype=float32)
# mape: tf.Tensor(90425440.0, shape=(), dtype=float32)
# -> volumeChange
# mae: tf.Tensor(26.760702, shape=(), dtype=float32)
# mse: tf.Tensor(1509.1852, shape=(), dtype=float32)
# mape: tf.Tensor(317118.16, shape=(), dtype=float32)
# -> closeChange
# mae: tf.Tensor(2.0155342, shape=(), dtype=float32)
# mse: tf.Tensor(8.302617, shape=(), dtype=float32)
# mape: tf.Tensor(1881776.1, shape=(), dtype=float32)
# -> EMA 10
# mae: tf.Tensor(1.1882727, shape=(), dtype=float32)
# mse: tf.Tensor(2.6135702, shape=(), dtype=float32)
# mape: tf.Tensor(3.2594166, shape=(), dtype=float32)
# -> EMA 20
# mae: tf.Tensor(0.90978366, shape=(), dtype=float32)
# mse: tf.Tensor(1.4434392, shape=(), dtype=float32)
# mape: tf.Tensor(2.5273578, shape=(), dtype=float32)
# -> EMA 50
# mae: tf.Tensor(0.55197847, shape=(), dtype=float32)
# mse: tf.Tensor(0.5090174, shape=(), dtype=float32)
# mape: tf.Tensor(1.489852, shape=(), dtype=float32)
# -> EMA 100
# mae: tf.Tensor(1.6907978, shape=(), dtype=float32)
# mse: tf.Tensor(4.7816195, shape=(), dtype=float32)
# mape: tf.Tensor(4.4672484, shape=(), dtype=float32)
# -> ROC5
# mae: tf.Tensor(0.8711972, shape=(), dtype=float32)
# mse: tf.Tensor(1.4138056, shape=(), dtype=float32)
# mape: tf.Tensor(35290.562, shape=(), dtype=float32)
# -> ROC10
# mae: tf.Tensor(0.5605589, shape=(), dtype=float32)
# mse: tf.Tensor(0.55732346, shape=(), dtype=float32)
# mape: tf.Tensor(14670.494, shape=(), dtype=float32)
# -> ROC15
# mae: tf.Tensor(0.3757859, shape=(), dtype=float32)
# mse: tf.Tensor(0.27803928, shape=(), dtype=float32)
# mape: tf.Tensor(9834.6, shape=(), dtype=float32)
# -> ROC20
# mae: tf.Tensor(0.29503453, shape=(), dtype=float32)
# mse: tf.Tensor(0.16720004, shape=(), dtype=float32)
# mape: tf.Tensor(10323.133, shape=(), dtype=float32)
# -> DTB6
# mae: tf.Tensor(442.32593, shape=(), dtype=float32)
# mse: tf.Tensor(332562.94, shape=(), dtype=float32)
# mape: tf.Tensor(7604585000.0, shape=(), dtype=float32)
# -> DGS5
# mae: tf.Tensor(340.3033, shape=(), dtype=float32)
# mse: tf.Tensor(228893.62, shape=(), dtype=float32)
# mape: tf.Tensor(8205369000.0, shape=(), dtype=float32)

# %% [markdown]
# # WIP

# %%
testData[:20,1]
# Out:
# array([0., 1., 3., 4., 0., 1., 3., 4., 0., 1., 3., 4., 0., 1., 2., 4., 0.,
#        1., 2., 3.])

# %%
predData[:20,1]
# Out:
# array([0.70922107, 1.0380843 , 2.120926  , 3.0733366 , 3.760275  ,
#        0.87605304, 1.9485066 , 3.047633  , 3.8749378 , 0.04199588,
#        2.0980062 , 3.0757375 , 3.6471486 , 0.18925548, 1.0830363 ,
#        3.7347448 , 0.5345811 , 1.2208338 , 2.1180556 , 3.174611  ],
#       dtype=float32)

# %%
Ytest.shape
# Out:
# (721, 5, 14)

# %%
testData.shape
# Out:
# (3605, 14)

# %%
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.metrics import mean_absolute_percentage_error as MAPE

# %%
key = 0
testFore1, testFore2, testFore3, testFore4, testFore5 = list(), list(), list(), list(), list()
predFore1, predFore2, predFore3, predFore4, predFore5 = list(), list(), list(), list(), list()
for i in range(testData.shape[0]): #testData.shape(0)
    remainder = i%5
    if remainder == 0:
        testFore1.append(testData[i][key])
        predFore1.append(predData[i][key])
    elif remainder == 1:
        testFore2.append(testData[i][key])
        predFore2.append(predData[i][key])
    elif remainder == 2:
        testFore3.append(testData[i][key])
        predFore3.append(predData[i][key])
    elif remainder == 3:
        testFore4.append(testData[i][key])
        predFore4.append(predData[i][key])
    elif remainder == 4:
        testFore5.append(testData[i][key])
        predFore5.append(predData[i][key])

# %%
len(testFore1), len(testFore5), len(predFore1), len(predFore5)
# Out:
# (721, 721, 721, 721)

# %%
evalDict = {"testData1" : testFore1, "testData2" : testFore2, "testData3": testFore3, "testData4" : testFore4, \
                  "testData5" : testFore5, "predData1" : predFore1, "predData2" : predFore2, "predData3": predFore3, \
                  "predData4" : predFore4, "predData5" : predFore5}

# %%
evaluationDf = pd.DataFrame(evalDict)
evaluationDf.head()
# Out:
#    testData1  testData2  testData3  testData4  testData5  predData1  \
# 0      53.60      53.80      53.75      53.42      53.10      52.60
# 1      53.80      53.75      53.42      53.10      52.66      52.12
# 2      53.75      53.42      53.10      52.66      52.82      52.63
# 3      53.42      53.10      52.66      52.82      52.73      50.98
# 4      53.10      52.66      52.82      52.73      52.50      52.31
#
#    predData2  predData3  predData4  predData5
# 0      52.27      52.80      52.67      52.67
# 1      52.25      52.25      52.15      52.07
# 2      52.68      52.60      52.60      52.53
# 3      51.24      51.16      51.41      51.22
# 4      52.01      52.43      52.20      52.25

# %%
def average():
    s = (MAPE(evaluationDf.testData1, evaluationDf.predData1) + MAPE(evaluationDf.testData2, evaluationDf.predData2) + \
    MAPE(evaluationDf.testData3, evaluationDf.predData3) + MAPE(evaluationDf.testData4, evaluationDf.predData4) + \
    MAPE(evaluationDf.testData5, evaluationDf.predData5))/5
    print(s)

# %%
MAPE(evaluationDf.testData1, evaluationDf.predData1)
# Out:
# 0.04192206832675681

# %%
MAPE(evaluationDf.testData2, evaluationDf.predData2)
# Out:
# 0.0464696728370514

# %%
MAPE(evaluationDf.testData3, evaluationDf.predData3)
# Out:
# 0.05074969472777128

# %%
MAPE(evaluationDf.testData4, evaluationDf.predData4)
# Out:
# 0.05505457544152746

# %%
MAPE(evaluationDf.testData5, evaluationDf.predData5)
# Out:
# 0.05953559800633685

# %%
average()
# Out:
# 0.05074632186788876
