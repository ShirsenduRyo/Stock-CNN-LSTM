# %% [markdown]
# # The Packages

# %%
# Two models not trained with Eval metrics created

# %%
import numpy as np
import pandas as pd
import os
import gc
import datetime
import warnings

# %%
import statsmodels.api as sm
from datetime import date

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
import tensorflow as tf
import math 
# keras = tf.keras
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LSTM
from tensorflow.keras import losses
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.utils import plot_model

# %%
tf.__version__
# Out:
# '2.10.1'

# %%
# DATA VISUALIZATION
# ------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (20.0, 10.0)
sns.set_style("darkgrid")
sns.color_palette("mako", as_cmap=True)
import plotly.express as px

# %%
# CONFIGURATIONS
# ------------------------------------------------------
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.2f}'.format
warnings.filterwarnings('ignore')

# %% [markdown]
# # Utility Functions

# %%
def plotSeries(time, series, lab,form='-'):
    plt.plot(time, series, form, label=lab)
    plt.xlabel("Date")
    plt.ylabel("Close Price")
    plt.grid(True)

# %%
def plotEvaluation(testData, predData, columns):
    testDf = pd.DataFrame(testData, columns = columns)
    predDf = pd.DataFrame(predData, columns = columns)
    plt.figure(figsize=(15,5))
    plt.plot(testDf.Close, label='Real')
    plt.plot(predDf.Close, label='Prediction')

    plt.legend(loc="best")
    #for saving figures
    plt.show()

# %% [markdown]
# # The Data

# %%
wfc = pd.read_csv('Dataset/Treasury.csv')

# %%
wfc.head()
# Out:
#          Date  Close  Weekday  volumeChange  closeChange  EMA 10  EMA 20  \
# 0  2000-01-03  19.56        0         68.61        -4.95   19.56   19.56
# 1  2000-01-04  18.59        1        -46.00        -1.01   19.03   19.05
# 2  2000-01-05  18.41        2          1.20         4.41   18.78   18.82
# 3  2000-01-06  19.22        3         -7.39         1.79   18.92   18.93
# 4  2000-01-07  19.56        4         16.11        -3.19   19.11   19.08
#
#    EMA 50  EMA 100  ROC5  ROC10  ROC15  ROC20     DTB6    DGS5
# 0   19.56    19.56  0.00   0.00   0.00   0.00 50550.00 6050.00
# 1   19.07    19.07  0.00   0.00   0.00   0.00 50500.00 6040.00
# 2   18.84    18.85  0.00   0.00   0.00   0.00 50490.00 6051.00
# 3   18.94    18.94  0.00   0.00   0.00   0.00 50440.00 6046.00
# 4   19.07    19.07 -0.59   0.00   0.00   0.00 50420.00 6042.00

# %%
wfc.Date.dtype
# Out:
# dtype('O')

# %%
wfc['Date'] = pd.to_datetime(wfc['Date'])
#wfc.set_index(['Date'],inplace=True)

# %%
wfc.head()
# Out:
#         Date  Close  Weekday  volumeChange  closeChange  EMA 10  EMA 20  \
# 0 2000-01-03  19.56        0         68.61        -4.95   19.56   19.56
# 1 2000-01-04  18.59        1        -46.00        -1.01   19.03   19.05
# 2 2000-01-05  18.41        2          1.20         4.41   18.78   18.82
# 3 2000-01-06  19.22        3         -7.39         1.79   18.92   18.93
# 4 2000-01-07  19.56        4         16.11        -3.19   19.11   19.08
#
#    EMA 50  EMA 100  ROC5  ROC10  ROC15  ROC20     DTB6    DGS5
# 0   19.56    19.56  0.00   0.00   0.00   0.00 50550.00 6050.00
# 1   19.07    19.07  0.00   0.00   0.00   0.00 50500.00 6040.00
# 2   18.84    18.85  0.00   0.00   0.00   0.00 50490.00 6051.00
# 3   18.94    18.94  0.00   0.00   0.00   0.00 50440.00 6046.00
# 4   19.07    19.07 -0.59   0.00   0.00   0.00 50420.00 6042.00

# %%
wfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5754 entries, 0 to 5753
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5754 non-null   datetime64[ns]
#  1   Close         5754 non-null   float64
#  2   Weekday       5754 non-null   int64
#  3   volumeChange  5754 non-null   float64
#  4   closeChange   5754 non-null   float64
#  5   EMA 10        5754 non-null   float64
#  6   EMA 20        5754 non-null   float64
#  7   EMA 50        5754 non-null   float64
#  8   EMA 100       5754 non-null   float64
#  9   ROC5          5754 non-null   float64
#  10  ROC10         5754 non-null   float64
#  11  ROC15         5754 non-null   float64
#  12  ROC20         5754 non-null   float64
#  13  DTB6          5754 non-null   float64
#  14  DGS5          5754 non-null   float64
# dtypes: datetime64[ns](1), float64(13), int64(1)
# memory usage: 674.4 KB

# %%
wfc.describe()
# Out:
#         Close  Weekday  volumeChange  closeChange  EMA 10  EMA 20  EMA 50  \
# count 5754.00  5754.00       5754.00      5754.00 5754.00 5754.00 5754.00
# mean    36.38     2.02          5.93         0.04   36.36   36.34   36.27
# std     11.75     1.40         39.58         2.45   11.71   11.68   11.59
# min      8.12     0.00        -84.21       -23.82   10.68   12.45   15.86
# 25%     26.74     1.00        -18.62        -0.84   26.76   26.85   26.86
# 50%     32.64     2.00         -0.81         0.00   32.47   32.43   32.12
# 75%     47.79     3.00         20.93         0.86   47.87   47.96   48.12
# max     65.93     4.00        480.19        32.76   65.12   64.10   61.54
#
#        EMA 100    ROC5   ROC10   ROC15   ROC20     DTB6    DGS5
# count  5754.00 5754.00 5754.00 5754.00 5754.00  5754.00 5754.00
# mean     36.16    0.05    0.04    0.04    0.04  6689.76 2101.97
# std      11.45    0.99    0.65    0.52    0.43 13368.12 1528.92
# min      17.93  -10.67   -6.28   -4.60   -3.39     0.00    0.00
# 25%      27.03   -0.34   -0.22   -0.16   -0.13    14.00 1045.00
# 50%      31.70    0.04    0.04    0.04    0.04  1012.00 2031.00
# 75%      47.94    0.43    0.30    0.25    0.22  4096.00 3068.00
# max      59.00   11.66    7.05    5.18    3.79 60240.00 6083.00

# %%
correlation = wfc.corr ()  
correlation. style.background_gradient ()
# Out:
# <style type="text/css">
# #T_1c6b7_row0_col0, #T_1c6b7_row0_col4, #T_1c6b7_row1_col1, #T_1c6b7_row2_col2, #T_1c6b7_row3_col3, #T_1c6b7_row4_col0, #T_1c6b7_row4_col4, #T_1c6b7_row4_col5, #T_1c6b7_row5_col4, #T_1c6b7_row5_col5, #T_1c6b7_row5_col6, #T_1c6b7_row6_col5, #T_1c6b7_row6_col6, #T_1c6b7_row6_col7, #T_1c6b7_row7_col6, #T_1c6b7_row7_col7, #T_1c6b7_row8_col8, #T_1c6b7_row9_col9, #T_1c6b7_row10_col10, #T_1c6b7_row11_col11, #T_1c6b7_row12_col12, #T_1c6b7_row13_col13 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1c6b7_row0_col1, #T_1c6b7_row1_col10, #T_1c6b7_row4_col1, #T_1c6b7_row4_col11, #T_1c6b7_row5_col1, #T_1c6b7_row6_col1, #T_1c6b7_row7_col1, #T_1c6b7_row12_col2, #T_1c6b7_row12_col9, #T_1c6b7_row13_col2 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_1c6b7_row0_col2, #T_1c6b7_row4_col2, #T_1c6b7_row5_col2, #T_1c6b7_row6_col2, #T_1c6b7_row7_col2, #T_1c6b7_row8_col1, #T_1c6b7_row9_col1, #T_1c6b7_row10_col1, #T_1c6b7_row11_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_1c6b7_row0_col3, #T_1c6b7_row1_col2, #T_1c6b7_row2_col1, #T_1c6b7_row6_col8, #T_1c6b7_row6_col9, #T_1c6b7_row7_col8, #T_1c6b7_row7_col9, #T_1c6b7_row7_col10, #T_1c6b7_row7_col11, #T_1c6b7_row7_col12, #T_1c6b7_row7_col13, #T_1c6b7_row12_col0, #T_1c6b7_row12_col4, #T_1c6b7_row12_col5, #T_1c6b7_row12_col6, #T_1c6b7_row12_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_1c6b7_row0_col5, #T_1c6b7_row4_col6, #T_1c6b7_row5_col0, #T_1c6b7_row6_col4 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_1c6b7_row0_col6, #T_1c6b7_row5_col7, #T_1c6b7_row6_col0, #T_1c6b7_row7_col5 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_1c6b7_row0_col7, #T_1c6b7_row7_col0 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_1c6b7_row0_col8 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_1c6b7_row0_col9, #T_1c6b7_row1_col11, #T_1c6b7_row13_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_1c6b7_row0_col10, #T_1c6b7_row12_col11 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_1c6b7_row0_col11 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_1c6b7_row0_col12, #T_1c6b7_row0_col13, #T_1c6b7_row4_col12, #T_1c6b7_row4_col13, #T_1c6b7_row5_col3, #T_1c6b7_row5_col12, #T_1c6b7_row5_col13, #T_1c6b7_row6_col3, #T_1c6b7_row6_col10 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_1c6b7_row1_col0, #T_1c6b7_row1_col4, #T_1c6b7_row1_col5, #T_1c6b7_row2_col6, #T_1c6b7_row8_col0 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_1c6b7_row1_col3, #T_1c6b7_row5_col9 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_1c6b7_row1_col6, #T_1c6b7_row2_col7, #T_1c6b7_row3_col10 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_1c6b7_row1_col7, #T_1c6b7_row2_col12, #T_1c6b7_row3_col12, #T_1c6b7_row9_col0 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_1c6b7_row1_col8, #T_1c6b7_row5_col11, #T_1c6b7_row8_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_1c6b7_row1_col9, #T_1c6b7_row13_col9 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_1c6b7_row1_col12, #T_1c6b7_row8_col12, #T_1c6b7_row9_col12 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_1c6b7_row1_col13 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_1c6b7_row2_col0, #T_1c6b7_row2_col4, #T_1c6b7_row2_col5 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_1c6b7_row2_col3, #T_1c6b7_row4_col8, #T_1c6b7_row6_col11, #T_1c6b7_row7_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_1c6b7_row2_col8 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_1c6b7_row2_col9, #T_1c6b7_row13_col8 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_1c6b7_row2_col10, #T_1c6b7_row3_col1, #T_1c6b7_row11_col2 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_1c6b7_row2_col11, #T_1c6b7_row12_col1, #T_1c6b7_row13_col10 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_1c6b7_row2_col13, #T_1c6b7_row3_col7, #T_1c6b7_row3_col11, #T_1c6b7_row11_col13 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_1c6b7_row3_col0, #T_1c6b7_row9_col4 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_1c6b7_row3_col2, #T_1c6b7_row9_col2, #T_1c6b7_row10_col2, #T_1c6b7_row12_col8 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_1c6b7_row3_col4 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_1c6b7_row3_col5, #T_1c6b7_row3_col13, #T_1c6b7_row10_col4 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_1c6b7_row3_col6, #T_1c6b7_row8_col13, #T_1c6b7_row9_col13, #T_1c6b7_row10_col13, #T_1c6b7_row11_col4 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_1c6b7_row3_col8 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_1c6b7_row3_col9 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_1c6b7_row4_col3, #T_1c6b7_row5_col8, #T_1c6b7_row6_col12, #T_1c6b7_row6_col13 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_1c6b7_row4_col7, #T_1c6b7_row7_col4 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_1c6b7_row4_col9 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_1c6b7_row4_col10 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_1c6b7_row5_col10, #T_1c6b7_row12_col3 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_1c6b7_row8_col3 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_1c6b7_row8_col4 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_1c6b7_row8_col5, #T_1c6b7_row8_col7, #T_1c6b7_row10_col3, #T_1c6b7_row11_col5 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_1c6b7_row8_col6, #T_1c6b7_row10_col5 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_1c6b7_row8_col9 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_1c6b7_row8_col10 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_1c6b7_row8_col11 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_1c6b7_row9_col3 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_1c6b7_row9_col5 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_1c6b7_row9_col6 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_1c6b7_row9_col7 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_1c6b7_row9_col8 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_1c6b7_row9_col10, #T_1c6b7_row12_col13 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_1c6b7_row9_col11 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_1c6b7_row10_col0, #T_1c6b7_row10_col12, #T_1c6b7_row11_col0, #T_1c6b7_row11_col12 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_1c6b7_row10_col6 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_1c6b7_row10_col7 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_1c6b7_row10_col8 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_1c6b7_row10_col9 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_1c6b7_row10_col11, #T_1c6b7_row11_col10 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_1c6b7_row11_col3, #T_1c6b7_row11_col6 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_1c6b7_row11_col7 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_1c6b7_row11_col8 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_1c6b7_row11_col9 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_1c6b7_row12_col10 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_1c6b7_row13_col0, #T_1c6b7_row13_col4, #T_1c6b7_row13_col5, #T_1c6b7_row13_col6, #T_1c6b7_row13_col7 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_1c6b7_row13_col3 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_1c6b7_row13_col11 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_1c6b7_row13_col12 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1c6b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c6b7_level0_col0" class="col_heading level0 col0" >Close</th>
#       <th id="T_1c6b7_level0_col1" class="col_heading level0 col1" >Weekday</th>
#       <th id="T_1c6b7_level0_col2" class="col_heading level0 col2" >volumeChange</th>
#       <th id="T_1c6b7_level0_col3" class="col_heading level0 col3" >closeChange</th>
#       <th id="T_1c6b7_level0_col4" class="col_heading level0 col4" >EMA 10</th>
#       <th id="T_1c6b7_level0_col5" class

# %%
#Dropping Volume for Clearer Scale

# %% [markdown]
# # The Split

# %%
min_date = wfc.Date.min()
max_date = wfc.Date.max()
print("Min:", min_date, "Max:", max_date)
# Out:
# Min: 2000-01-03 00:00:00 Max: 2022-11-11 00:00:00

# %%
train_percent = .75
valid_percent = .12

time_between = max_date - min_date

train_cutoff = min_date + train_percent*time_between
valid_cutoff = min_date + (train_percent + valid_percent)*time_between

print("Training Cutoff Date: {:s}".format(str(train_cutoff)))
print("Validation Cutoff Date: {:s}".format(str(valid_cutoff)))
# Out:
# Training Cutoff Date: 2017-02-23 00:00:00
# Validation Cutoff Date: 2019-11-21 18:14:24

# %%
train_df = wfc[wfc.Date <= train_cutoff]
valid_df = wfc[(wfc.Date > train_cutoff) & (wfc.Date <= valid_cutoff)]
test_df = wfc[wfc.Date > valid_cutoff]

# %%
print("Dataset shape: {:s}".format(str(wfc.shape)))
print("Train dataset shape: {:s}".format(str(train_df.shape)))
print("Vaid dataset shape: {:s}".format(str(valid_df.shape)))
print("Test dataset shape: {:s}".format(str(test_df.shape)))
# Out:
# Dataset shape: (5754, 15)
# Train dataset shape: (4313, 15)
# Vaid dataset shape: (692, 15)
# Test dataset shape: (749, 15)

# %% [markdown]
# # Stock Price Graph

# %%
plotSeries(train_df.Date, train_df.Close, "Training Data")
plotSeries(valid_df.Date, valid_df.Close, "Validation Data")
plotSeries(test_df.Date, test_df.Close, "Test Data")
plt.legend(loc='upper left')

# %% [markdown]
# # Feature Engineering

# %%
train_df.set_index(['Date'],inplace=True)
test_df.set_index(['Date'],inplace=True)
valid_df.set_index(['Date'],inplace=True)

# %%
train_df.head()
# Out:
#             Close  Weekday  volumeChange  closeChange  EMA 10  EMA 20  EMA 50  \
# Date
# 2000-01-03  19.56        0         68.61        -4.95   19.56   19.56   19.56
# 2000-01-04  18.59        1        -46.00        -1.01   19.03   19.05   19.07
# 2000-01-05  18.41        2          1.20         4.41   18.78   18.82   18.84
# 2000-01-06  19.22        3         -7.39         1.79   18.92   18.93   18.94
# 2000-01-07  19.56        4         16.11        -3.19   19.11   19.08   19.07
#
#             EMA 100  ROC5  ROC10  ROC15  ROC20     DTB6    DGS5
# Date
# 2000-01-03    19.56  0.00   0.00   0.00   0.00 50550.00 6050.00
# 2000-01-04    19.07  0.00   0.00   0.00   0.00 50500.00 6040.00
# 2000-01-05    18.85  0.00   0.00   0.00   0.00 50490.00 6051.00
# 2000-01-06    18.94  0.00   0.00   0.00   0.00 50440.00 6046.00
# 2000-01-07    19.07 -0.59   0.00   0.00   0.00 50420.00 6042.00

# %%
scaler = MinMaxScaler()

trainNorm = scaler.fit_transform(train_df.values)
testNorm = scaler.transform(test_df.values)
validNorm = scaler.transform(valid_df.values)

trainNormDf = pd.DataFrame(trainNorm, columns=train_df.columns)
testNormDf = pd.DataFrame(testNorm, columns=test_df.columns)
validNormDf = pd.DataFrame(validNorm, columns=valid_df.columns)

# %%
def splitSequence(sequence, look_back, forecast_horizon):
    X, y = list(), list()
    for i in range(len(sequence)): 
        lag_end = i + look_back
        forecast_end = lag_end + forecast_horizon
        if forecast_end > len(sequence):
            break
        seq_x, seq_y = sequence[i:lag_end], sequence[lag_end:forecast_end]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
LOOK_BACK = 24
FORECAST_RANGE = 5
n_features = len(trainNormDf.columns)

# %%
#Add valid df
Xtrain, Ytrain = splitSequence(trainNormDf, look_back=LOOK_BACK, forecast_horizon=FORECAST_RANGE)
Xvalid, Yvalid = splitSequence(validNormDf, look_back=LOOK_BACK, forecast_horizon=FORECAST_RANGE)
Xtest, Ytest = splitSequence(testNormDf, look_back=LOOK_BACK, forecast_horizon=FORECAST_RANGE)

# %%
print(Xtrain.shape)
print(Ytrain.shape)
print(Xvalid.shape)
print(Yvalid.shape)
print(Xtest.shape)
print(Ytest.shape)
# Out:
# (4285, 24, 14)
# (4285, 5, 14)
# (664, 24, 14)
# (664, 5, 14)
# (721, 24, 14)
# (721, 5, 14)

# %%
def inverse_transform(y_test, yhat):
    y_test_reshaped = y_test.reshape(-1, y_test.shape[-1])
    yhat_reshaped = yhat.reshape(-1, yhat.shape[-1])
    yhat_inverse = scaler.inverse_transform(yhat_reshaped)
    y_test_inverse = scaler.inverse_transform(y_test_reshaped)
    return yhat_inverse, y_test_inverse

# %%
def plotMAPEperRange(testData, predData):
    y_test_inverse_time_step  = testData.reshape(int(testData.shape[0]/FORECAST_RANGE), \
                                                      FORECAST_RANGE, testData.shape[-1])
    yhat_inverse_time_step = predData.reshape(int(predData.shape[0]/FORECAST_RANGE), \
                                                  FORECAST_RANGE, predData.shape[-1])
    # yhat_inverse_time_step and y_test_inverse_time_step are both same dimension.
    time_step_list_yhat = [[] for i in range(FORECAST_RANGE)]
    time_step_list_y_test = [[] for i in range(FORECAST_RANGE)]
    for i in range(0, yhat_inverse_time_step.shape[0]):
        for j in range(0, yhat_inverse_time_step.shape[1]):
            time_step_list_yhat[j].append(list(yhat_inverse_time_step[i][j]))
            time_step_list_y_test[j].append(list(y_test_inverse_time_step[i][j]))
    yhat_time_step = np.array(time_step_list_yhat)
    yhat_time_step = yhat_time_step.reshape(yhat_time_step.shape[0], -1)
    y_test_time_step = np.array(time_step_list_y_test)
    y_test_time_step = y_test_time_step.reshape(y_test_time_step.shape[0], -1)
    # plotting
    mape_list = []
    for i in range(0, FORECAST_RANGE):
        mape = mape_(y_test_time_step[i], yhat_time_step[i])
        print(mape)
        mape_list.append(mape)
    plt.plot(range(0, FORECAST_RANGE), mape_list, marker='o')
    plt.xticks((range(0, FORECAST_RANGE)))
    plt.xlabel('Forecast Range')
    plt.ylabel('MAPE')

# %%
def evaluate_forecast(y_test_inverse, yhat_inverse):
    mse_ = tf.keras.losses.MeanSquaredError()
    mae_ = tf.keras.losses.MeanAbsoluteError()
    mape_ = tf.keras.losses.MeanAbsolutePercentageError()
    mae = mae_(y_test_inverse,yhat_inverse)
    print('mae:', mae)
    mse = mse_(y_test_inverse,yhat_inverse)
    print('mse:', mse)
    mape = mape_(y_test_inverse,yhat_inverse)
    print('mape:', mape)

# %%
mse_ = tf.keras.losses.MeanSquaredError()
mae_ = tf.keras.losses.MeanAbsoluteError()
mape_ = tf.keras.losses.MeanAbsolutePercentageError()
# mae = mae_(y_test_inverse,yhat_inverse)
# # print('mae:', mae)
# mse = mse_(y_test_inverse,yhat_inverse)
# # print('mse:', mse)
# mape = mape_(y_test_inverse,yhat_inverse)
# # print('mape:', mape)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, TimeDistributed, Conv1D, MaxPooling1D, Flatten, Bidirectional, Input, Flatten, Activation, Reshape, RepeatVector, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %% [markdown]
# ## CNN-LSTM Encoder-Decoder Model

# %%
from keras import backend as K
from keras.layers.core import Activation
from keras.utils.generic_utils import get_custom_objects

# %%
tf.keras.backend.clear_session()
model_enc_dec_cnn = Sequential()

# %% [markdown]
# # Custom Activation Function

# %%
def custom_activation(x):
  
    return (  epoch/(1 + K.exp(-x)))
     
get_custom_objects().update({'custom_activation': Activation(custom_activation)})

# %%
model_enc_dec_cnn.add(Conv1D(filters=32, kernel_size=9, activation='custom_activation', input_shape=(LOOK_BACK, n_features)))
model_enc_dec_cnn.add(Conv1D(filters=32, kernel_size=11, activation='custom_activation'))
model_enc_dec_cnn.add(MaxPooling1D(pool_size=2))
model_enc_dec_cnn.add(Flatten())
model_enc_dec_cnn.add(RepeatVector(FORECAST_RANGE))
model_enc_dec_cnn.add(LSTM(200, return_sequences=True))
model_enc_dec_cnn.add(TimeDistributed(Dense(100, activation='custom_activation')))
model_enc_dec_cnn.add(TimeDistributed(Dense(n_features)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [68], line 1
# ----> 1 model_enc_dec_cnn.add(Conv1D(filters=32, kernel_size=9, activation='custom_activation', input_shape=(LOOK_BACK, n_features)))
#       2 model_enc_dec_cnn.add(Conv1D(filters=32, kernel_size=11, activation='custom_activation'))
#       3 model_enc_dec_cnn.add(MaxPooling1D(pool_size=2))
#
# File D:\Anac\envs\tf1\lib\site-packages\tensorflow\python\trackable\base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     203 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#     207   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File D:\Anac\envs\tf1\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# Cell In [67], line 3, in custom_activation(x)
#       1 def custom_activation(x):
# ----> 3     return (  epoch/(1 + K.exp(-x)))
#
# NameError: Exception encountered when calling layer "activation" "                 f"(type Activation).
#
# name 'epoch' is not defined
#
# Call arguments received by layer "activation" "                 f"(type Activation):
#   • inputs=tf.Tensor(shape=(None, 16, 32), dtype=float32)

# %%
# model_enc_dec_cnn.add(Conv1D(filters=64, kernel_size=9, activation='relu', input_shape=(LOOK_BACK, n_features)))
# model_enc_dec_cnn.add(Conv1D(filters=64, kernel_size=11, activation='relu'))
# model_enc_dec_cnn.add(MaxPooling1D(pool_size=2))
# model_enc_dec_cnn.add(Flatten())
# model_enc_dec_cnn.add(RepeatVector(FORECAST_RANGE))
# model_enc_dec_cnn.add(LSTM(200, return_sequences=True))
# model_enc_dec_cnn.add(TimeDistributed(Dense(100, activation='relu')))
# model_enc_dec_cnn.add(TimeDistributed(Dense(n_features)))

# %% [markdown]
# # Hypertuning LR

# %%
lrSchedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch:1e-8*10**(epoch/20))
earlyStop = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10, restore_best_weights=True)

# %%
optimizer = Adam(1e-3)
model_enc_dec_cnn.compile(loss=tf.keras.losses.MeanSquaredError(),
             optimizer = optimizer,
             metrics = ["mae"])

# %%
history = model_enc_dec_cnn.fit(Xtrain,Ytrain,batch_size=128, epochs=50, callbacks=[lrSchedule, earlyStop])
# Out:
# Epoch 1/50
# 34/34 [==============================] - 3s 18ms/step - loss: 0.3118 - mae: 0.4744 - lr: 1.0000e-08
# Epoch 2/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3117 - mae: 0.4744 - lr: 1.1220e-08
# Epoch 3/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3117 - mae: 0.4743 - lr: 1.2589e-08
# Epoch 4/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3116 - mae: 0.4743 - lr: 1.4125e-08
# Epoch 5/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.3116 - mae: 0.4742 - lr: 1.5849e-08
# Epoch 6/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.3115 - mae: 0.4742 - lr: 1.7783e-08
# Epoch 7/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3115 - mae: 0.4741 - lr: 1.9953e-08
# Epoch 8/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3114 - mae: 0.4741 - lr: 2.2387e-08
# Epoch 9/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3113 - mae: 0.4740 - lr: 2.5119e-08
# Epoch 10/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.3112 - mae: 0.4739 - lr: 2.8184e-08
# Epoch 11/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3111 - mae: 0.4738 - lr: 3.1623e-08
# Epoch 12/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3109 - mae: 0.4737 - lr: 3.5481e-08
# Epoch 13/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3108 - mae: 0.4736 - lr: 3.9811e-08
# Epoch 14/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3106 - mae: 0.4734 - lr: 4.4668e-08
# Epoch 15/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.3104 - mae: 0.4733 - lr: 5.0119e-08
# Epoch 16/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3102 - mae: 0.4731 - lr: 5.6234e-08
# Epoch 17/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.3100 - mae: 0.4729 - lr: 6.3096e-08
# Epoch 18/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.3098 - mae: 0.4727 - lr: 7.0795e-08
# Epoch 19/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.3095 - mae: 0.4725 - lr: 7.9433e-08
# Epoch 20/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.3091 - mae: 0.4722 - lr: 8.9125e-08
# Epoch 21/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.3088 - mae: 0.4719 - lr: 1.0000e-07
# Epoch 22/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3084 - mae: 0.4716 - lr: 1.1220e-07
# Epoch 23/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3079 - mae: 0.4712 - lr: 1.2589e-07
# Epoch 24/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3074 - mae: 0.4708 - lr: 1.4125e-07
# Epoch 25/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3068 - mae: 0.4704 - lr: 1.5849e-07
# Epoch 26/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3062 - mae: 0.4698 - lr: 1.7783e-07
# Epoch 27/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3055 - mae: 0.4693 - lr: 1.9953e-07
# Epoch 28/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3047 - mae: 0.4686 - lr: 2.2387e-07
# Epoch 29/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3038 - mae: 0.4679 - lr: 2.5119e-07
# Epoch 30/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3028 - mae: 0.4670 - lr: 2.8184e-07
# Epoch 31/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3017 - mae: 0.4661 - lr: 3.1623e-07
# Epoch 32/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3004 - mae: 0.4651 - lr: 3.5481e-07
# Epoch 33/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.2990 - mae: 0.4639 - lr: 3.9811e-07
# Epoch 34/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.2975 - mae: 0.4626 - lr: 4.4668e-07
# Epoch 35/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.2957 - mae: 0.4612 - lr: 5.0119e-07
# Epoch 36/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.2938 - mae: 0.4595 - lr: 5.6234e-07
# Epoch 37/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.2916 - mae: 0.4577 - lr: 6.3096e-07
# Epoch 38/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.2892 - mae: 0.4557 - lr: 7.0795e-07
# Epoch 39/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.2865 - mae: 0.4534 - lr: 7.9433e-07
# Epoch 40/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.2835 - mae: 0.4508 - lr: 8.9125e-07
# Epoch 41/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.2801 - mae: 0.4479 - lr: 1.0000e-06
# Epoch 42/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.2764 - mae: 0.4447 - lr: 1.1220e-06
# Epoch 43/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.2722 - mae: 0.4411 - lr: 1.2589e-06
# Epoch 44/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.2676 - mae: 0.4370 - lr: 1.4125e-06
# Epoch 45/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.2624 - mae: 0.4325 - lr: 1.5849e-06
# Epoch 46/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.2567 - mae: 0.4274 - lr: 1.7783e-06
# Epoch 47/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.2504 - mae: 0.4217 - lr: 1.9953e-06
# Epoch 48/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.2433 - mae: 0.4153 - lr: 2.2387e-06
# Epoch 49/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.2355 - mae: 0.4080 - lr: 2.5119e-06
# Epoch 50/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.2268 - mae: 0.3999 - lr: 2.8184e-06

# %%
plt.figure(figsize=(20,8))
plt.semilogx(history.history["lr"], history.history["loss"])
# plt.savefig('media/LearningRate.png')

# %%
end()

# %% [markdown]
# ## Final Model

# %%
model_enc_dec_cnn.compile(loss=tf.keras.losses.MeanSquaredError(),
              optimizer=Adam(1e-3),
              metrics=['mae'])

# %%
log_dir = "logs\\" + datetime.datetime.now().strftime("%d-%m-%Y_%H%M%S")
# model_path = ""
tensorboard_callback = [
#                         tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1),
#                         ModelCheckpoint(model_path, verbose=1, save_best_only=True),
                        ReduceLROnPlateau(monitor='val_mae', factor=0.3,patience=10, min_lr=1e-6, verbose=1),
#                         CSVLogger(csv_path),
                        TensorBoard(),
                        EarlyStopping(monitor= "val_mae", patience=10, restore_best_weights=True)
                       ]

# %%
history = model_enc_dec_cnn.fit(Xtrain, Ytrain,batch_size=128, epochs=100, verbose=1,validation_data=(Xvalid, Yvalid), \
                            callbacks=tensorboard_callback)

# %%
trainScore = model_enc_dec_cnn.evaluate(Xtrain, Ytrain, verbose=1)
validScore = model_enc_dec_cnn.evaluate(Xvalid, Yvalid, verbose=1)
testScore = model_enc_dec_cnn.evaluate(Xtest, Ytest, verbose=1)

# %%
testScore, validScore, trainScore

# %%
yhat = model_enc_dec_cnn.predict(Xtest, verbose=0)

# %%
predData, testData = inverse_transform(Ytest, yhat)
evaluate_forecast(testData, predData)

# %%
plotEvaluation(testData, predData, columns = testNormDf.columns)

# %%
def displayMetricsByColumn(testData, predData, columns, i):

    print('->', columns[i])
    mae = mae_(testData[:,i],predData[:,i])
    print('mae:', mae)
    mse = mse_(testData[:,i],predData[:,i])
    print('mse:', mse)
    mape = mape_(testData[:,i],predData[:,i])
    print('mape:', mape)

# %%
displayMetricsByColumn(testData, predData, train_df.columns, 0)

# %% [markdown]
# # WIP

# %%
testData[:20,1]

# %%
predData[:20,1]

# %%
Ytest.shape

# %%
testData.shape

# %%
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.metrics import mean_absolute_percentage_error as MAPE

# %%
key = 0
testFore1, testFore2, testFore3, testFore4, testFore5 = list(), list(), list(), list(), list()
predFore1, predFore2, predFore3, predFore4, predFore5 = list(), list(), list(), list(), list()
for i in range(testData.shape[0]): #testData.shape(0)
    remainder = i%5
    if remainder == 0:
        testFore1.append(testData[i][key])
        predFore1.append(predData[i][key])
    elif remainder == 1:
        testFore2.append(testData[i][key])
        predFore2.append(predData[i][key])
    elif remainder == 2:
        testFore3.append(testData[i][key])
        predFore3.append(predData[i][key])
    elif remainder == 3:
        testFore4.append(testData[i][key])
        predFore4.append(predData[i][key])
    elif remainder == 4:
        testFore5.append(testData[i][key])
        predFore5.append(predData[i][key])

# %%
len(testFore1), len(testFore5), len(predFore1), len(predFore5)

# %%
evalDict = {"testData1" : testFore1, "testData2" : testFore2, "testData3": testFore3, "testData4" : testFore4, \
                  "testData5" : testFore5, "predData1" : predFore1, "predData2" : predFore2, "predData3": predFore3, \
                  "predData4" : predFore4, "predData5" : predFore5}

# %%
evaluationDf = pd.DataFrame(evalDict)
evaluationDf.head()

# %%
MAPE(evaluationDf.testData1, evaluationDf.predData1)

# %%
MAPE(evaluationDf.testData2, evaluationDf.predData2)

# %%
MAPE(evaluationDf.testData3, evaluationDf.predData3)

# %%
MAPE(evaluationDf.testData4, evaluationDf.predData4)

# %%
MAPE(evaluationDf.testData5, evaluationDf.predData5)

# %%
plt.figure(figsize=(12,5))
plt.plot(evaluationDf.testData1, label='Real')
plt.plot(evaluationDf.predData1, label='Prediction')

plt.legend(loc="best")
#for saving figures
plt.savefig('media/CnnLstmEnDe.png')
plt.show()

# %%
def average():
    s = (MAPE(evaluationDf.testData1, evaluationDf.predData1) + MAPE(evaluationDf.testData2, evaluationDf.predData2) + \
    MAPE(evaluationDf.testData3, evaluationDf.predData3) + MAPE(evaluationDf.testData4, evaluationDf.predData4) + \
    MAPE(evaluationDf.testData5, evaluationDf.predData5))/5
    print(s)

# %%
average()

# %%
n_features
