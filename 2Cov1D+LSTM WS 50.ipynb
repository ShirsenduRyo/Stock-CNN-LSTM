# %% [markdown]
# # The Packages

# %%
import numpy as np
import pandas as pd
import os
import gc
import datetime
import warnings

# %%
import statsmodels.api as sm
from datetime import date

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
import tensorflow as tf
import math 
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LSTM
from tensorflow.keras import losses
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.utils import plot_model

# %%
tf.__version__
# Out:
# '2.10.1'

# %%
# DATA VISUALIZATION
# ------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (20.0, 10.0)
sns.set_style("darkgrid")
sns.color_palette("mako", as_cmap=True)
import plotly.express as px

# %%
# CONFIGURATIONS
# ------------------------------------------------------
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.2f}'.format
warnings.filterwarnings('ignore')

# %%
tf.random.set_seed(99)
np.random.seed(99)

# %% [markdown]
# # Utility Functions

# %%
def plotSeries(time, series, lab,form='-'):
    plt.plot(time, series, form, label=lab)
    plt.xlabel("Date")
    plt.ylabel("Close Price")
    plt.grid(True)

# %% [markdown]
# # The Data

# %%
wfc = pd.read_csv('Dataset/WFC Daily1.csv')

# %%
wfc.head()
# Out:
#          Date  Open  High   Low  Close  Adj Close    Volume
# 0  2000-01-03 20.16 20.19 19.00  19.56      10.44   9037000
# 1  2000-01-04 18.62 18.84 18.00  18.59       9.92  15237200
# 2  2000-01-05 18.50 18.88 18.03  18.41       9.82   8228200
# 3  2000-01-06 18.53 19.50 18.47  19.22      10.25   8326800
# 4  2000-01-07 19.62 19.84 19.28  19.56      10.44   7711200

# %%
wfc.Date.dtype
# Out:
# dtype('O')

# %%
wfc['Date'] = pd.to_datetime(wfc['Date'])
#wfc.set_index(['Date'],inplace=True)

# %%
wfc.head()
# Out:
#         Date  Open  High   Low  Close  Adj Close    Volume
# 0 2000-01-03 20.16 20.19 19.00  19.56      10.44   9037000
# 1 2000-01-04 18.62 18.84 18.00  18.59       9.92  15237200
# 2 2000-01-05 18.50 18.88 18.03  18.41       9.82   8228200
# 3 2000-01-06 18.53 19.50 18.47  19.22      10.25   8326800
# 4 2000-01-07 19.62 19.84 19.28  19.56      10.44   7711200

# %%
wfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5754 entries, 0 to 5753
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5754 non-null   datetime64[ns]
#  1   Open       5754 non-null   float64
#  2   High       5754 non-null   float64
#  3   Low        5754 non-null   float64
#  4   Close      5754 non-null   float64
#  5   Adj Close  5754 non-null   float64
#  6   Volume     5754 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 314.8 KB

# %%
wfc.describe()
# Out:
#          Open    High     Low   Close  Adj Close       Volume
# count 5754.00 5754.00 5754.00 5754.00    5754.00      5754.00
# mean    36.38   36.78   35.98   36.38      28.01  24313450.19
# std     11.74   11.77   11.73   11.75      12.85  26705062.78
# min      8.65    8.94    7.80    8.12       5.76   1774000.00
# 25%     26.71   27.20   26.25   26.74      18.01  10091200.00
# 50%     32.65   33.13   32.25   32.64      23.18  17086600.00
# 75%     47.75   48.19   47.33   47.79      41.58  29145250.00
# max     65.89   66.31   65.66   65.93      57.96 478736600.00

# %%
correlation = wfc.corr ()  
correlation. style.background_gradient ()
# Out:
# <style type="text/css">
# #T_236a7_row0_col0, #T_236a7_row0_col1, #T_236a7_row0_col2, #T_236a7_row0_col3, #T_236a7_row1_col0, #T_236a7_row1_col1, #T_236a7_row1_col2, #T_236a7_row1_col3, #T_236a7_row2_col0, #T_236a7_row2_col1, #T_236a7_row2_col2, #T_236a7_row2_col3, #T_236a7_row3_col0, #T_236a7_row3_col1, #T_236a7_row3_col2, #T_236a7_row3_col3, #T_236a7_row4_col4, #T_236a7_row5_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_236a7_row0_col4, #T_236a7_row2_col4, #T_236a7_row3_col4 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_236a7_row0_col5, #T_236a7_row3_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_236a7_row1_col4, #T_236a7_row4_col0, #T_236a7_row4_col1, #T_236a7_row4_col2, #T_236a7_row4_col3 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_236a7_row1_col5 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_236a7_row2_col5, #T_236a7_row5_col0, #T_236a7_row5_col1, #T_236a7_row5_col2, #T_236a7_row5_col3, #T_236a7_row5_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_236a7_row4_col5 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# </style>
# <table id="T_236a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_236a7_level0_col0" class="col_heading level0 col0" >Open</th>
#       <th id="T_236a7_level0_col1" class="col_heading level0 col1" >High</th>
#       <th id="T_236a7_level0_col2" class="col_heading level0 col2" >Low</th>
#       <th id="T_236a7_level0_col3" class="col_heading level0 col3" >Close</th>
#       <th id="T_236a7_level0_col4" class="col_heading level0 col4" >Adj Close</th>
#       <th id="T_236a7_level0_col5" class="col_heading level0 col5" >Volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_236a7_level0_row0" class="row_heading level0 row0" >Open</th>
#       <td id="T_236a7_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_236a7_row0_col1" class="data row0 col1" >0.999324</td>
#       <td id="T_236a7_row0_col2" class="data row0 col2" >0.999274</td>
#       <td id="T_236a7_row0_col3" class="data row0 col3" >0.998754</td>
#       <td id="T_236a7_row0_col4" class="data row0 col4" >0.965403</td>
#       <td id="T_236a7_row0_col5" class="data row0 col5" >-0.184389</td>
#     </tr>
#     <tr>
#       <th id="T_236a7_level0_row1" class="row_heading level0 row1" >High</th>
#       <td id="T_236a7_row1_col0" class="data row1 col0" >0.999324</td>
#       <td id="T_236a7_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_236a7_row1_col2" class="data row1 col2" >0.998796</td>
#       <td id="T_236a7_row1_col3" class="data row1 col3" >0.999323</td>
#       <td id="T_236a7_row1_col4" class="data row1 col4" >0.967945</td>
#       <td id="T_236a7_row1_col5" class="data row1 col5" >-0.169457</td>
#     </tr>
#     <tr>
#       <th id="T_236a7_level0_row2" class="row_heading level0 row2" >Low</th>
#       <td id="T_236a7_row2_col0" class="data row2 col0" >0.999274</td>
#       <td id="T_236a7_row2_col1" class="data row2 col1" >0.998796</td>
#       <td id="T_236a7_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_236a7_row2_col3" class="data row2 col3" >0.999303</td>
#       <td id="T_236a7_row2_col4" class="data row2 col4" >0.963519</td>
#       <td id="T_236a7_row2_col5" class="data row2 col5" >-0.199335</td>
#     </tr>
#     <tr>
#       <th id="T_236a7_level0_row3" class="row_heading level0 row3" >Close</th>
#       <td id="T_236a7_row3_col0" class="data row3 col0" >0.998754</td>
#       <td id="T_236a7_row3_col1" class="data row3 col1" >0.999323</td>
#       <td id="T_236a7_row3_col2" class="data row3 col2" >0.999303</td>
#       <td id="T_236a7_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_236a7_row3_col4" class="data row3 col4" >0.966149</td>
#       <td id="T_236a7_row3_col5" class="data row3 col5" >-0.183272</td>
#     </tr>
#     <tr>
#       <th id="T_236a7_level0_row4" class="row_heading level0 row4" >Adj Close</th>
#       <td id="T_236a7_row4_col0" class="data row4 col0" >0.965403</td>
#       <td id="T_236a7_row4_col1" class="data row4 col1" >0.967945</td>
#       <td id="T_236a7_row4_col2" class="data row4 col2" >0.963519</td>
#       <td id="T_236a7_row4_col3" class="data row4 col3" >0.966149</td>
#       <td id="T_236a7_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_236a7_row4_col5" class="data row4 col5" >-0.080189</td>
#     </tr>
#     <tr>
#       <th id="T_236a7_level0_row5" class="row_heading level0 row5" >Volume</th>
#       <td id="T_236a7_row5_col0" class="data row5 col0" >-0.184389</td>
#       <td id="T_236a7_row5_col1" class="data row5 col1" >-0.169457</td>
#       <td id="T_236a7_row5_col2" class="data row5 col2" >-0.199335</td>
#       <td id="T_236a7_row5_col3" class="data row5 col3" >-0.183272</td>
#       <td id="T_236a7_row5_col4" class="data row5 col4" >-0.080189</td>
#       <td id="T_236a7_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # The Split

# %%
min_date = wfc.Date.min()
max_date = wfc.Date.max()
print("Min:", min_date, "Max:", max_date)
# Out:
# Min: 2000-01-03 00:00:00 Max: 2022-11-11 00:00:00

# %%
train_percent = .75
valid_percent = .12

time_between = max_date - min_date

train_cutoff = min_date + train_percent*time_between
valid_cutoff = min_date + (train_percent + valid_percent)*time_between

print("Training Cutoff Date: {:s}".format(str(train_cutoff)))
print("Validation Cutoff Date: {:s}".format(str(valid_cutoff)))
# Out:
# Training Cutoff Date: 2017-02-23 00:00:00
# Validation Cutoff Date: 2019-11-21 18:14:24

# %%
train_df = wfc[wfc.Date <= train_cutoff]
valid_df = wfc[(wfc.Date > train_cutoff) & (wfc.Date <= valid_cutoff)]
test_df = wfc[wfc.Date > valid_cutoff]

# %%
print("Dataset shape: {:s}".format(str(wfc.shape)))
print("Train dataset shape: {:s}".format(str(train_df.shape)))
print("Vaid dataset shape: {:s}".format(str(valid_df.shape)))
print("Test dataset shape: {:s}".format(str(test_df.shape)))
# Out:
# Dataset shape: (5754, 7)
# Train dataset shape: (4313, 7)
# Vaid dataset shape: (692, 7)
# Test dataset shape: (749, 7)

# %% [markdown]
# # Stock Price Graph

# %%
plotSeries(train_df.Date, train_df.Close, "Training Data")
plotSeries(valid_df.Date, valid_df.Close, "Validation Data")
plotSeries(test_df.Date, test_df.Close, "Test Data")
plt.legend(loc='upper left')

# %%
train_df.set_index(['Date'],inplace=True)
test_df.set_index(['Date'],inplace=True)
valid_df.set_index(['Date'],inplace=True)

# %%
trainNorm = train_df.Close.values.reshape(-1, 1)
testNorm = test_df.Close.values.reshape(-1, 1)
validNorm = valid_df.Close.values.reshape(-1, 1)

# %%
trainNorm.shape
# Out:
# (4313, 1)

# %% [markdown]
# ## Windowed Dataset

# %%
mse_arr=[]
Z = []

window = 50

# %%
X_train= []
Y_train=[]
X_valid= []
Y_valid=[]
X_test= []
Y_test=[]

for i in range(len(trainNorm) - (window)):
    X_train.append(trainNorm[i:i+window])
    Y_train.append(trainNorm[i+window])
    
for i in range(len(validNorm) - (window)):
    X_valid.append(validNorm[i:i+window])
    Y_valid.append(validNorm[i+window])
    
for i in range(len(testNorm) - (window)):
    X_test.append(testNorm[i:i+window])
    Y_test.append(testNorm[i+window])
    

X_train=np.asanyarray(X_train)
Y_train=np.asanyarray(Y_train)
X_valid=np.asanyarray(X_valid)
Y_valid=np.asanyarray(Y_valid)
X_test=np.asanyarray(X_test)
Y_test=np.asanyarray(Y_test)

Xtrain = X_train[:,:,:]  
Ytrain = Y_train[:]  
Xvalid = X_valid[:,:,:]  
Yvalid= Y_valid[:]  
Xtest = X_test[:,:,:]  
Ytest= Y_test[:]

# %% [markdown]
# # Model Building

# %%
tf.keras.backend.clear_session()
model = tf.keras.Sequential()

# %%
model.add(keras.layers.Conv1D(filters=16, kernel_size = 5,
                           strides=1, padding="causal",
                           activation="relu",
                           input_shape=[window, 1]),)
model.add(keras.layers.Conv1D(filters=32, kernel_size = 5,
                           strides=1, padding="causal",
                           activation="relu",
                           input_shape=[window, 1]),)
model.add(keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)))
model.add(keras.layers.Bidirectional(tf.keras.layers.LSTM(32)))
model.add(keras.layers.Dense(1))

# %% [markdown]
# ## Final Model Build

# %%
tf.keras.backend.clear_session()

# %%
model.compile(loss=tf.keras.losses.MeanSquaredError(),
              optimizer=Adam(1e-3),
              metrics=['mae'])

# %%
log_dir = "logs\\" + datetime.datetime.now().strftime("%d-%m-%Y_%H%M%S")

tensorboard_callback = [
#                         tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1),
#                         ModelCheckpoint(model_path, verbose=1, save_best_only=True),
#                         ReduceLROnPlateau(monitor= "val_mae", factor=0.1, patience=5, min_lr=1e-7, verbose=1),
                        ReduceLROnPlateau(monitor='val_mae', factor=0.3,patience=5, min_lr=1e-6, verbose=1),
#                         CSVLogger(csv_path),
                        TensorBoard(),
                        EarlyStopping(monitor= "val_mae", patience=10, restore_best_weights=True)
                       ]

# %%
history = model.fit(Xtrain, Ytrain,batch_size=128, epochs=500, verbose=1,validation_data=(Xvalid, Yvalid), callbacks=tensorboard_callback)
# Out:
# Epoch 1/500
# 34/34 [==============================] - 9s 57ms/step - loss: 969.5450 - mae: 29.3074 - val_loss: 2009.1980 - val_mae: 44.6013 - lr: 0.0010
# Epoch 2/500
# 34/34 [==============================] - 0s 9ms/step - loss: 601.4122 - mae: 22.2272 - val_loss: 1601.6149 - val_mae: 39.7706 - lr: 0.0010
# Epoch 3/500
# 34/34 [==============================] - 0s 10ms/step - loss: 454.8204 - mae: 18.6947 - val_loss: 1392.7893 - val_mae: 37.0523 - lr: 0.0010
# Epoch 4/500
# 34/34 [==============================] - 0s 9ms/step - loss: 369.8716 - mae: 16.3087 - val_loss: 1234.4355 - val_mae: 34.8499 - lr: 0.0010
# Epoch 5/500
# 34/34 [==============================] - 0s 9ms/step - loss: 306.4942 - mae: 14.2993 - val_loss: 1101.9620 - val_mae: 32.8944 - lr: 0.0010
# Epoch 6/500
# 34/34 [==============================] - 0s 9ms/step - loss: 257.2758 - mae: 12.5368 - val_loss: 988.4175 - val_mae: 31.1206 - lr: 0.0010
# Epoch 7/500
# 34/34 [==============================] - 0s 10ms/step - loss: 218.6555 - mae: 11.0674 - val_loss: 892.0734 - val_mae: 29.5322 - lr: 0.0010
# Epoch 8/500
# 34/34 [==============================] - 0s 10ms/step - loss: 188.7710 - mae: 9.9231 - val_loss: 810.1856 - val_mae: 28.1116 - lr: 0.0010
# Epoch 9/500
# 34/34 [==============================] - 0s 9ms/step - loss: 165.9603 - mae: 9.1146 - val_loss: 739.9286 - val_mae: 26.8329 - lr: 0.0010
500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.6703 - mae: 0.5438 - val_loss: 5.9570 - val_mae: 1.4541 - lr: 0.0010
# Epoch 90/500
# 34/34 [==============================] - 0s 8ms/step - loss: 0.6618 - mae: 0.5550 - val_loss: 6.1833 - val_mae: 1.5940 - lr: 0.0010
# Epoch 91/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.7840 - mae: 0.6362 - val_loss: 6.1918 - val_mae: 1.6355 - lr: 0.0010
# Epoch 92/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.6567 - mae: 0.5527 - val_loss: 5.6046 - val_mae: 1.4156 - lr: 0.0010
# Epoch 93/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.7722 - mae: 0.6304 - val_loss: 5.5170 - val_mae: 1.3830 - lr: 0.0010
# Epoch 94/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.7097 - mae: 0.5960 - val_loss: 5.7062 - val_mae: 1.5099 - lr: 0.0010
# Epoch 95/500
# 34/34 [==============================] - 0s 8ms/step - loss: 0.6678 - mae: 0.5691 - val_loss: 5.3456 - val_mae: 1.3619 - lr: 0.0010
# Epoch 96/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.6473 - mae: 0.5516 - val_loss: 5.2198 - val_mae: 1.3300 - lr: 0.0010
# Epoch 97/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.5603 - mae: 0.4919 - val_loss: 5.0322 - val_mae: 1.2740 - lr: 0.0010
# Epoch 98/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.6599 - mae: 0.5719 - val_loss: 5.1325 - val_mae: 1.3532 - lr: 0.0010
# Epoch 99/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.6361 - mae: 0.5563 - val_loss: 5.1489 - val_mae: 1.3995 - lr: 0.0010
# Epoch 100/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.6069 - mae: 0.5312 - val_loss: 4.9759 - val_mae: 1.3458 - lr: 0.0010
# Epoch 101/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.5808 - mae: 0.5182 - val_loss: 5.0139 - val_mae: 1.3846 - lr: 0.0010
# Epoch 102/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.5876 - mae: 0.5266 - val_loss: 4.6887 - val_mae: 1.2359 - lr: 0.0010
# Epoch 103/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.5991 - mae: 0.5417 - val_loss: 4.6191 - val_mae: 1.2181 - lr: 0.0010
# Epoch 104/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.5554 - mae: 0.5010 - val_loss: 4.6864 - val_mae: 1.2811 - lr: 0.0010
# Epoch 105/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.6593 - mae: 0.5794 - val_loss: 4.5321 - val_mae: 1.2269 - lr: 0.0010
# Epoch 106/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.5460 - mae: 0.4944 - val_loss: 4.4856 - val_mae: 1.2241 - lr: 0.0010
# Epoch 107/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.6681 - mae: 0.5843 - val_loss: 4.5291 - val_mae: 1.2582 - lr: 0.0010
# Epoch 108/500
# 29/34 [========================>.....] - ETA: 0s - loss: 0.8213 - mae: 0.6595
# Epoch 108: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 34/34 [==============================] - 0s 9ms/step - loss: 0.8241 - mae: 0.6639 - val_loss: 4.8739 - val_mae: 1.4468 - lr: 0.0010
# Epoch 109/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.6083 - mae: 0.5447 - val_loss: 4.4519 - val_mae: 1.2381 - lr: 3.0000e-04
# Epoch 110/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.5032 - mae: 0.4611 - val_loss: 4.3702 - val_mae: 1.2075 - lr: 3.0000e-04
# Epoch 111/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4886 - mae: 0.4533 - val_loss: 4.4113 - val_mae: 1.2367 - lr: 3.0000e-04
# Epoch 112/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.5170 - mae: 0.4796 - val_loss: 4.2611 - val_mae: 1.1592 - lr: 3.0000e-04
# Epoch 113/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4862 - mae: 0.4567 - val_loss: 4.2391 - val_mae: 1.1546 - lr: 3.0000e-04
# Epoch 114/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4917 - mae: 0.4579 - val_loss: 4.2117 - val_mae: 1.1464 - lr: 3.0000e-04
# Epoch 115/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4876 - mae: 0.4580 - val_loss: 4.1970 - val_mae: 1.1477 - lr: 3.0000e-04
# Epoch 116/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4973 - mae: 0.4679 - val_loss: 4.2428 - val_mae: 1.1870 - lr: 3.0000e-04
# Epoch 117/500
# 34/34 [==============================] - 0s 8ms/step - loss: 0.4999 - mae: 0.4686 - val_loss: 4.2330 - val_mae: 1.1843 - lr: 3.0000e-04
# Epoch 118/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4886 - mae: 0.4590 - val_loss: 4.1326 - val_mae: 1.1309 - lr: 3.0000e-04
# Epoch 119/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4812 - mae: 0.4520 - val_loss: 4.1507 - val_mae: 1.1494 - lr: 3.0000e-04
# Epoch 120/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4810 - mae: 0.4528 - val_loss: 4.1618 - val_mae: 1.1689 - lr: 3.0000e-04
# Epoch 121/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4776 - mae: 0.4499 - val_loss: 4.0805 - val_mae: 1.1211 - lr: 3.0000e-04
# Epoch 122/500
# 34/34 [==============================] - 0s 8ms/step - loss: 0.4932 - mae: 0.4650 - val_loss: 4.2688 - val_mae: 1.2487 - lr: 3.0000e-04
# Epoch 123/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.5081 - mae: 0.4803 - val_loss: 4.0446 - val_mae: 1.1203 - lr: 3.0000e-04
# Epoch 124/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4923 - mae: 0.4659 - val_loss: 4.0666 - val_mae: 1.1469 - lr: 3.0000e-04
# Epoch 125/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.5036 - mae: 0.4761 - val_loss: 4.0246 - val_mae: 1.1254 - lr: 3.0000e-04
# Epoch 126/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4798 - mae: 0.4603 - val_loss: 3.9928 - val_mae: 1.1137 - lr: 3.0000e-04
# Epoch 127/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4800 - mae: 0.4559 - val_loss: 3.9595 - val_mae: 1.1027 - lr: 3.0000e-04
# Epoch 128/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4839 - mae: 0.4615 - val_loss: 3.9383 - val_mae: 1.0995 - lr: 3.0000e-04
# Epoch 129/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4800 - mae: 0.4549 - val_loss: 3.9369 - val_mae: 1.1078 - lr: 3.0000e-04
# Epoch 130/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.5617 - mae: 0.5304 - val_loss: 4.0698 - val_mae: 1.2000 - lr: 3.0000e-04
# Epoch 131/500
# 34/34 [==============================] - 0s 8ms/step - loss: 0.4733 - mae: 0.4537 - val_loss: 3.9032 - val_mae: 1.1049 - lr: 3.0000e-04
# Epoch 132/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4780 - mae: 0.4571 - val_loss: 3.9026 - val_mae: 1.1140 - lr: 3.0000e-04
# Epoch 133/500
# 31/34 [==========================>...] - ETA: 0s - loss: 0.4898 - mae: 0.4712
# Epoch 133: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4923 - mae: 0.4704 - val_loss: 4.0823 - val_mae: 1.2287 - lr: 3.0000e-04
# Epoch 134/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4644 - mae: 0.4455 - val_loss: 3.8560 - val_mae: 1.0955 - lr: 9.0000e-05
# Epoch 135/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4568 - mae: 0.4400 - val_loss: 3.8457 - val_mae: 1.0912 - lr: 9.0000e-05
# Epoch 136/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4546 - mae: 0.4352 - val_loss: 3.8380 - val_mae: 1.0869 - lr: 9.0000e-05
# Epoch 137/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4564 - mae: 0.4372 - val_loss: 3.8383 - val_mae: 1.0922 - lr: 9.0000e-05
# Epoch 138/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4648 - mae: 0.4453 - val_loss: 3.8332 - val_mae: 1.0881 - lr: 9.0000e-05
# Epoch 139/500
# 34/34 [==============================] - 0s 8ms/step - loss: 0.4605 - mae: 0.4408 - val_loss: 3.8250 - val_mae: 1.0871 - lr: 9.0000e-05
# Epoch 140/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4564 - mae: 0.4380 - val_loss: 3.8076 - val_mae: 1.0786 - lr: 9.0000e-05
# Epoch 141/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4558 - mae: 0.4376 - val_loss: 3.8175 - val_mae: 1.0905 - lr: 9.0000e-05
# Epoch 142/500
# 34/34 [==============================] - 0s 8ms/step - loss: 0.4563 - mae: 0.4383 - val_loss: 3.7985 - val_mae: 1.0798 - lr: 9.0000e-05
# Epoch 143/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4577 - mae: 0.4415 - val_loss: 3.7894 - val_mae: 1.0783 - lr: 9.0000e-05
# Epoch 144/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4526 - mae: 0.4348 - val_loss: 3.7960 - val_mae: 1.0864 - lr: 9.0000e-05
# Epoch 145/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4513 - mae: 0.4343 - val_loss: 3.7747 - val_mae: 1.0736 - lr: 9.0000e-05
# Epoch 146/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4531 - mae: 0.4365 - val_loss: 3.8157 - val_mae: 1.1075 - lr: 9.0000e-05
# Epoch 147/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4538 - mae: 0.4375 - val_loss: 3.7806 - val_mae: 1.0873 - lr: 9.0000e-05
# Epoch 148/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4495 - mae: 0.4347 - val_loss: 3.7567 - val_mae: 1.0714 - lr: 9.0000e-05
# Epoch 149/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4525 - mae: 0.4367 - val_loss: 3.7544 - val_mae: 1.0749 - lr: 9.0000e-05
# Epoch 150/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4519 - mae: 0.4380 - val_loss: 3.7497 - val_mae: 1.0761 - lr: 9.0000e-05
# Epoch 151/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4502 - mae: 0.4340 - val_loss: 3.7278 - val_mae: 1.0664 - lr: 9.0000e-05
# Epoch 152/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4504 - mae: 0.4349 - val_loss: 3.7681 - val_mae: 1.0981 - lr: 9.0000e-05
# Epoch 153/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4534 - mae: 0.4393 - val_loss: 3.7177 - val_mae: 1.0649 - lr: 9.0000e-05
# Epoch 154/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4531 - mae: 0.4358 - val_loss: 3.7181 - val_mae: 1.0673 - lr: 9.0000e-05
# Epoch 155/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4499 - mae: 0.4360 - val_loss: 3.6989 - val_mae: 1.0617 - lr: 9.0000e-05
# Epoch 156/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4595 - mae: 0.4462 - val_loss: 3.6970 - val_mae: 1.0647 - lr: 9.0000e-05
# Epoch 157/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4592 - mae: 0.4415 - val_loss: 3.7120 - val_mae: 1.0793 - lr: 9.0000e-05
# Epoch 158/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4532 - mae: 0.4402 - val_loss: 3.6839 - val_mae: 1.0615 - lr: 9.0000e-05
# Epoch 159/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4534 - mae: 0.4380 - val_loss: 3.7126 - val_mae: 1.0889 - lr: 9.0000e-05
# Epoch 160/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4543 - mae: 0.4387 - val_loss: 3.7425 - val_mae: 1.1136 - lr: 9.0000e-05
# Epoch 161/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4553 - mae: 0.4442 - val_loss: 3.7414 - val_mae: 1.1106 - lr: 9.0000e-05
# Epoch 162/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4609 - mae: 0.4452 - val_loss: 3.6560 - val_mae: 1.0614 - lr: 9.0000e-05
# Epoch 163/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4487 - mae: 0.4346 - val_loss: 3.6391 - val_mae: 1.0524 - lr: 9.0000e-05
# Epoch 164/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4484 - mae: 0.4360 - val_loss: 3.6457 - val_mae: 1.0633 - lr: 9.0000e-05
# Epoch 165/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4478 - mae: 0.4337 - val_loss: 3.6345 - val_mae: 1.0591 - lr: 9.0000e-05
# Epoch 166/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4487 - mae: 0.4369 - val_loss: 3.6568 - val_mae: 1.0809 - lr: 9.0000e-05
# Epoch 167/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4525 - mae: 0.4387 - val_loss: 3.6798 - val_mae: 1.1000 - lr: 9.0000e-05
# Epoch 168/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4490 - mae: 0.4365 - val_loss: 3.5994 - val_mae: 1.0467 - lr: 9.0000e-05
# Epoch 169/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4434 - mae: 0.4304 - val_loss: 3.5889 - val_mae: 1.0459 - lr: 9.0000e-05
# Epoch 170/500
# 34/34 [==============================] - 0s 8ms/step - loss: 0.4481 - mae: 0.4349 - val_loss: 3.5804 - val_mae: 1.0460 - lr: 9.0000e-05
# Epoch 171/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4484 - mae: 0.4359 - val_loss: 3.6273 - val_mae: 1.0837 - lr: 9.0000e-05
# Epoch 172/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4475 - mae: 0.4350 - val_loss: 3.5687 - val_mae: 1.0467 - lr: 9.0000e-05
# Epoch 173/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4493 - mae: 0.4370 - val_loss: 3.5764 - val_mae: 1.0515 - lr: 9.0000e-05
# Epoch 174/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.4466 - mae: 0.4349
# Epoch 174: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4479 - mae: 0.4359 - val_loss: 3.5570 - val_mae: 1.0472 - lr: 9.0000e-05
# Epoch 175/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4396 - mae: 0.4288 - val_loss: 3.5446 - val_mae: 1.0405 - lr: 2.7000e-05
# Epoch 176/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4410 - mae: 0.4303 - val_loss: 3.5413 - val_mae: 1.0387 - lr: 2.7000e-05
# Epoch 177/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4407 - mae: 0.4295 - val_loss: 3.5401 - val_mae: 1.0405 - lr: 2.7000e-05
# Epoch 178/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4398 - mae: 0.4284 - val_loss: 3.5354 - val_mae: 1.0376 - lr: 2.7000e-05
# Epoch 179/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4400 - mae: 0.4282 - val_loss: 3.5358 - val_mae: 1.0380 - lr: 2.7000e-05
# Epoch 180/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4393 - mae: 0.4303 - val_loss: 3.5308 - val_mae: 1.0364 - lr: 2.7000e-05
# Epoch 181/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4385 - mae: 0.4276 - val_loss: 3.5258 - val_mae: 1.0353 - lr: 2.7000e-05
# Epoch 182/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4403 - mae: 0.4293 - val_loss: 3.5304 - val_mae: 1.0393 - lr: 2.7000e-05
# Epoch 183/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4396 - mae: 0.4285 - val_loss: 3.5204 - val_mae: 1.0349 - lr: 2.7000e-05
# Epoch 184/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4391 - mae: 0.4284 - val_loss: 3.5239 - val_mae: 1.0407 - lr: 2.7000e-05
# Epoch 185/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4378 - mae: 0.4281 - val_loss: 3.5297 - val_mae: 1.0428 - lr: 2.7000e-05
# Epoch 186/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4410 - mae: 0.4312 - val_loss: 3.5135 - val_mae: 1.0369 - lr: 2.7000e-05
# Epoch 187/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4385 - mae: 0.4276 - val_loss: 3.5143 - val_mae: 1.0389 - lr: 2.7000e-05
# Epoch 188/500
# 31/34 [==========================>...] - ETA: 0s - loss: 0.4383 - mae: 0.4275
# Epoch 188: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4374 - mae: 0.4279 - val_loss: 3.5099 - val_mae: 1.0356 - lr: 2.7000e-05
# Epoch 189/500
# 34/34 [==============================] - 0s 8ms/step - loss: 0.4376 - mae: 0.4274 - val_loss: 3.5108 - val_mae: 1.0391 - lr: 8.1000e-06
# Epoch 190/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4364 - mae: 0.4269 - val_loss: 3.5024 - val_mae: 1.0325 - lr: 8.1000e-06
# Epoch 191/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4360 - mae: 0.4262 - val_loss: 3.5018 - val_mae: 1.0324 - lr: 8.1000e-06
# Epoch 192/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4360 - mae: 0.4265 - val_loss: 3.5042 - val_mae: 1.0361 - lr: 8.1000e-06
# Epoch 193/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4365 - mae: 0.4269 - val_loss: 3.5014 - val_mae: 1.0342 - lr: 8.1000e-06
# Epoch 194/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4357 - mae: 0.4260 - val_loss: 3.4993 - val_mae: 1.0330 - lr: 8.1000e-06
# Epoch 195/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4357 - mae: 0.4259 - val_loss: 3.5075 - val_mae: 1.0404 - lr: 8.1000e-06
# Epoch 196/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4382 - mae: 0.4286 - val_loss: 3.4964 - val_mae: 1.0308 - lr: 8.1000e-06
# Epoch 197/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4358 - mae: 0.4261 - val_loss: 3.4994 - val_mae: 1.0355 - lr: 8.1000e-06
# Epoch 198/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4366 - mae: 0.4271 - val_loss: 3.4965 - val_mae: 1.0339 - lr: 8.1000e-06
# Epoch 199/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4365 - mae: 0.4268 - val_loss: 3.4964 - val_mae: 1.0346 - lr: 8.1000e-06
# Epoch 200/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4357 - mae: 0.4258 - val_loss: 3.4923 - val_mae: 1.0316 - lr: 8.1000e-06
# Epoch 201/500
# 30/34 [=========================>....] - ETA: 0s - loss: 0.4173 - mae: 0.4180
# Epoch 201: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4357 - mae: 0.4261 - val_loss: 3.4906 - val_mae: 1.0309 - lr: 8.1000e-06
# Epoch 202/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4352 - mae: 0.4255 - val_loss: 3.4901 - val_mae: 1.0307 - lr: 2.4300e-06
# Epoch 203/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4351 - mae: 0.4257 - val_loss: 3.4894 - val_mae: 1.0297 - lr: 2.4300e-06
# Epoch 204/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4351 - mae: 0.4256 - val_loss: 3.4906 - val_mae: 1.0319 - lr: 2.4300e-06
# Epoch 205/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4351 - mae: 0.4256 - val_loss: 3.4889 - val_mae: 1.0303 - lr: 2.4300e-06
# Epoch 206/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4351 - mae: 0.4255 - val_loss: 3.4883 - val_mae: 1.0299 - lr: 2.4300e-06
# Epoch 207/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4347 - mae: 0.4251 - val_loss: 3.4888 - val_mae: 1.0311 - lr: 2.4300e-06
# Epoch 208/500
# 29/34 [========================>.....] - ETA: 0s - loss: 0.4454 - mae: 0.4292
# Epoch 208: ReduceLROnPlateau reducing learning rate to 1e-06.
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4353 - mae: 0.4263 - val_loss: 3.4910 - val_mae: 1.0335 - lr: 2.4300e-06
# Epoch 209/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4347 - mae: 0.4252 - val_loss: 3.4873 - val_mae: 1.0297 - lr: 1.0000e-06
# Epoch 210/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4347 - mae: 0.4254 - val_loss: 3.4875 - val_mae: 1.0303 - lr: 1.0000e-06
# Epoch 211/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4347 - mae: 0.4254 - val_loss: 3.4873 - val_mae: 1.0302 - lr: 1.0000e-06
# Epoch 212/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4348 - mae: 0.4254 - val_loss: 3.4870 - val_mae: 1.0299 - lr: 1.0000e-06
# Epoch 213/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4347 - mae: 0.4253 - val_loss: 3.4873 - val_mae: 1.0305 - lr: 1.0000e-06
# Epoch 214/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4346 - mae: 0.4253 - val_loss: 3.4870 - val_mae: 1.0304 - lr: 1.0000e-06
# Epoch 215/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4347 - mae: 0.4254 - val_loss: 3.4867 - val_mae: 1.0303 - lr: 1.0000e-06
# Epoch 216/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4347 - mae: 0.4254 - val_loss: 3.4871 - val_mae: 1.0309 - lr: 1.0000e-06
# Epoch 217/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4346 - mae: 0.4253 - val_loss: 3.4866 - val_mae: 1.0306 - lr: 1.0000e-06
# Epoch 218/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4347 - mae: 0.4254 - val_loss: 3.4863 - val_mae: 1.0304 - lr: 1.0000e-06
# Epoch 219/500
# 34/34 [==============================] - 0s 9ms/step - loss: 0.4346 - mae: 0.4253 - val_loss: 3.4859 - val_mae: 1.0300 - lr: 1.0000e-06

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 5, 16)             96
#
#  conv1d_1 (Conv1D)           (None, 5, 32)             2592
#
#  bidirectional (Bidirectiona  (None, 5, 64)            16640
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 64)               24832
#  nal)
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 44,225
# Trainable params: 44,225
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Showing training and validation loss
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
loss_values50 = loss_values[0:150]
val_loss_values50 = val_loss_values[0:150]
epochs = range(1, len(loss_values50) + 1)
plt.plot(epochs, loss_values50, label='Training Loss')
plt.plot(epochs, val_loss_values50, label='Validation Loss')
plt.rc('font', size = 14)
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.xticks(epochs)
plt.xticks(np.arange(min(epochs), max(epochs)+1, 50.0))
#fig.savefig('test&validationlosscnn.png', dpi=300)
plt.show()

# %%
loss_values = history_dict['mae']
val_loss_values = history_dict['val_mae']
loss_values50 = loss_values[0:150]
val_loss_values50 = val_loss_values[0:150]
epochs = range(1, len(loss_values50) + 1)
plt.plot(epochs, loss_values50, label='Training MAE')
plt.plot(epochs, val_loss_values50, label='Validation MAE')
plt.rc('font', size = 14)
plt.title('Training and Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.xticks(epochs)
plt.xticks(np.arange(min(epochs), max(epochs)+1, 50.0))
#fig.savefig('test&validationlosscnn.png', dpi=300)
plt.show()

# %%
#Evaluating model
trainScore = model.evaluate(Xtrain, Ytrain, verbose=1)
validScore = model.evaluate(Xvalid, Yvalid, verbose=1)
testScore = model.evaluate(Xtest, Ytest, verbose=1)
# Out:
# 135/135 [==============================] - 0s 2ms/step - loss: 0.4346 - mae: 0.4254
# 22/22 [==============================] - 0s 2ms/step - loss: 3.4873 - mae: 1.0297
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1405 - mae: 0.7718

# %%
testScore, validScore, trainScore
# Out:
# ([1.1405446529388428, 0.7718019485473633],
#  [3.4872829914093018, 1.0296918153762817],
#  [0.43460845947265625, 0.4253634512424469])

# %%
preds = model.predict(Xtest)
# Out:
# 24/24 [==============================] - 2s 2ms/step

# %%
Xtest.shape
# Out:
# (744, 5, 1)

# %%
plt.title('MAE: {}'.format(testScore[1]))
plt.plot(Ytest, label='Real')
plt.plot(preds, label='Prediction')

plt.legend(loc="best")

#for saving figures
# plt.savefig('CPALL_graph.png')
plt.show()

# %%
#denormalizing datasets
# preds = scaler.inverse_transform(preds)
# Ytest = scaler.inverse_transform(Ytest)

# %%
#Show Train and Test Scores
print('Train MSE \t Train RMSE \t Train MAE \t Testscore RMSE \tTest MSE \tTest MAE')
print('%.9f \t %.9f \t %.9f \t %.9f \t \t %.9f \t %.9f' % (trainScore[0], math.sqrt(trainScore[0]),trainScore[1],math.sqrt(testScore[0]),testScore[0],testScore[1]))
# Out:
# Train MSE 	 Train RMSE 	 Train MAE 	 Testscore RMSE 	Test MSE 	Test MAE
# 0.434608459 	 0.659248405 	 0.425363451 	 1.067962852 	 	 1.140544653 	 0.771801949

# %%
print('MAE \t\t MAPE')
print('%.4f \t\t %.4f' % (mean_absolute_error(Ytest,preds),(np.mean(np.abs((Ytest - preds) / Ytest)) * 100)))
# Out:
# MAE 		 MAPE
# 0.7718 		 2.0326
