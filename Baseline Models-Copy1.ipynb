# %% [markdown]
# # The Packages

# %%
import numpy as np
import pandas as pd
import os
import gc
import datetime
import warnings

# %%
import statsmodels.api as sm
from datetime import date

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
import tensorflow as tf
import math 
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LSTM
from tensorflow.keras import losses
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.utils import plot_model

# %%
tf.__version__
# Out:
# '2.10.1'

# %%
# DATA VISUALIZATION
# ------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (20.0, 10.0)
sns.set_style("darkgrid")
sns.color_palette("mako", as_cmap=True)
import plotly.express as px

# %%
# CONFIGURATIONS
# ------------------------------------------------------
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.2f}'.format
warnings.filterwarnings('ignore')

# %% [markdown]
# # Utility Functions

# %%
def plotSeries(time, series, lab,form='-'):
    plt.plot(time, series, form, label=lab)
    plt.xlabel("Date")
    plt.ylabel("Close Price")
    plt.grid(True)

# %% [markdown]
# # The Data

# %%
wfc = pd.read_csv('Dataset/WFC Daily1.csv')

# %%
wfc.head()
# Out:
#          Date  Open  High   Low  Close  Adj Close    Volume
# 0  2000-01-03 20.16 20.19 19.00  19.56      10.44   9037000
# 1  2000-01-04 18.62 18.84 18.00  18.59       9.92  15237200
# 2  2000-01-05 18.50 18.88 18.03  18.41       9.82   8228200
# 3  2000-01-06 18.53 19.50 18.47  19.22      10.25   8326800
# 4  2000-01-07 19.62 19.84 19.28  19.56      10.44   7711200

# %%
wfc.Date.dtype
# Out:
# dtype('O')

# %%
wfc['Date'] = pd.to_datetime(wfc['Date'])
#wfc.set_index(['Date'],inplace=True)

# %%
wfc.head()
# Out:
#         Date  Open  High   Low  Close  Adj Close    Volume
# 0 2000-01-03 20.16 20.19 19.00  19.56      10.44   9037000
# 1 2000-01-04 18.62 18.84 18.00  18.59       9.92  15237200
# 2 2000-01-05 18.50 18.88 18.03  18.41       9.82   8228200
# 3 2000-01-06 18.53 19.50 18.47  19.22      10.25   8326800
# 4 2000-01-07 19.62 19.84 19.28  19.56      10.44   7711200

# %%
wfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5754 entries, 0 to 5753
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5754 non-null   datetime64[ns]
#  1   Open       5754 non-null   float64
#  2   High       5754 non-null   float64
#  3   Low        5754 non-null   float64
#  4   Close      5754 non-null   float64
#  5   Adj Close  5754 non-null   float64
#  6   Volume     5754 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 314.8 KB

# %%
wfc.describe()
# Out:
#          Open    High     Low   Close  Adj Close       Volume
# count 5754.00 5754.00 5754.00 5754.00    5754.00      5754.00
# mean    36.38   36.78   35.98   36.38      28.01  24313450.19
# std     11.74   11.77   11.73   11.75      12.85  26705062.78
# min      8.65    8.94    7.80    8.12       5.76   1774000.00
# 25%     26.71   27.20   26.25   26.74      18.01  10091200.00
# 50%     32.65   33.13   32.25   32.64      23.18  17086600.00
# 75%     47.75   48.19   47.33   47.79      41.58  29145250.00
# max     65.89   66.31   65.66   65.93      57.96 478736600.00

# %%
correlation = wfc.corr ()  
correlation. style.background_gradient ()
# Out:
# <style type="text/css">
# #T_b99d1_row0_col0, #T_b99d1_row0_col1, #T_b99d1_row0_col2, #T_b99d1_row0_col3, #T_b99d1_row1_col0, #T_b99d1_row1_col1, #T_b99d1_row1_col2, #T_b99d1_row1_col3, #T_b99d1_row2_col0, #T_b99d1_row2_col1, #T_b99d1_row2_col2, #T_b99d1_row2_col3, #T_b99d1_row3_col0, #T_b99d1_row3_col1, #T_b99d1_row3_col2, #T_b99d1_row3_col3, #T_b99d1_row4_col4, #T_b99d1_row5_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b99d1_row0_col4, #T_b99d1_row2_col4, #T_b99d1_row3_col4 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_b99d1_row0_col5, #T_b99d1_row3_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_b99d1_row1_col4, #T_b99d1_row4_col0, #T_b99d1_row4_col1, #T_b99d1_row4_col2, #T_b99d1_row4_col3 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_b99d1_row1_col5 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_b99d1_row2_col5, #T_b99d1_row5_col0, #T_b99d1_row5_col1, #T_b99d1_row5_col2, #T_b99d1_row5_col3, #T_b99d1_row5_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b99d1_row4_col5 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# </style>
# <table id="T_b99d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b99d1_level0_col0" class="col_heading level0 col0" >Open</th>
#       <th id="T_b99d1_level0_col1" class="col_heading level0 col1" >High</th>
#       <th id="T_b99d1_level0_col2" class="col_heading level0 col2" >Low</th>
#       <th id="T_b99d1_level0_col3" class="col_heading level0 col3" >Close</th>
#       <th id="T_b99d1_level0_col4" class="col_heading level0 col4" >Adj Close</th>
#       <th id="T_b99d1_level0_col5" class="col_heading level0 col5" >Volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b99d1_level0_row0" class="row_heading level0 row0" >Open</th>
#       <td id="T_b99d1_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b99d1_row0_col1" class="data row0 col1" >0.999324</td>
#       <td id="T_b99d1_row0_col2" class="data row0 col2" >0.999274</td>
#       <td id="T_b99d1_row0_col3" class="data row0 col3" >0.998754</td>
#       <td id="T_b99d1_row0_col4" class="data row0 col4" >0.965403</td>
#       <td id="T_b99d1_row0_col5" class="data row0 col5" >-0.184389</td>
#     </tr>
#     <tr>
#       <th id="T_b99d1_level0_row1" class="row_heading level0 row1" >High</th>
#       <td id="T_b99d1_row1_col0" class="data row1 col0" >0.999324</td>
#       <td id="T_b99d1_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b99d1_row1_col2" class="data row1 col2" >0.998796</td>
#       <td id="T_b99d1_row1_col3" class="data row1 col3" >0.999323</td>
#       <td id="T_b99d1_row1_col4" class="data row1 col4" >0.967945</td>
#       <td id="T_b99d1_row1_col5" class="data row1 col5" >-0.169457</td>
#     </tr>
#     <tr>
#       <th id="T_b99d1_level0_row2" class="row_heading level0 row2" >Low</th>
#       <td id="T_b99d1_row2_col0" class="data row2 col0" >0.999274</td>
#       <td id="T_b99d1_row2_col1" class="data row2 col1" >0.998796</td>
#       <td id="T_b99d1_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_b99d1_row2_col3" class="data row2 col3" >0.999303</td>
#       <td id="T_b99d1_row2_col4" class="data row2 col4" >0.963519</td>
#       <td id="T_b99d1_row2_col5" class="data row2 col5" >-0.199335</td>
#     </tr>
#     <tr>
#       <th id="T_b99d1_level0_row3" class="row_heading level0 row3" >Close</th>
#       <td id="T_b99d1_row3_col0" class="data row3 col0" >0.998754</td>
#       <td id="T_b99d1_row3_col1" class="data row3 col1" >0.999323</td>
#       <td id="T_b99d1_row3_col2" class="data row3 col2" >0.999303</td>
#       <td id="T_b99d1_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_b99d1_row3_col4" class="data row3 col4" >0.966149</td>
#       <td id="T_b99d1_row3_col5" class="data row3 col5" >-0.183272</td>
#     </tr>
#     <tr>
#       <th id="T_b99d1_level0_row4" class="row_heading level0 row4" >Adj Close</th>
#       <td id="T_b99d1_row4_col0" class="data row4 col0" >0.965403</td>
#       <td id="T_b99d1_row4_col1" class="data row4 col1" >0.967945</td>
#       <td id="T_b99d1_row4_col2" class="data row4 col2" >0.963519</td>
#       <td id="T_b99d1_row4_col3" class="data row4 col3" >0.966149</td>
#       <td id="T_b99d1_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_b99d1_row4_col5" class="data row4 col5" >-0.080189</td>
#     </tr>
#     <tr>
#       <th id="T_b99d1_level0_row5" class="row_heading level0 row5" >Volume</th>
#       <td id="T_b99d1_row5_col0" class="data row5 col0" >-0.184389</td>
#       <td id="T_b99d1_row5_col1" class="data row5 col1" >-0.169457</td>
#       <td id="T_b99d1_row5_col2" class="data row5 col2" >-0.199335</td>
#       <td id="T_b99d1_row5_col3" class="data row5 col3" >-0.183272</td>
#       <td id="T_b99d1_row5_col4" class="data row5 col4" >-0.080189</td>
#       <td id="T_b99d1_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # The Split

# %%
min_date = wfc.Date.min()
max_date = wfc.Date.max()
print("Min:", min_date, "Max:", max_date)
# Out:
# Min: 2000-01-03 00:00:00 Max: 2022-11-11 00:00:00

# %%
train_percent = .75
valid_percent = .12

time_between = max_date - min_date

train_cutoff = min_date + train_percent*time_between
valid_cutoff = min_date + (train_percent + valid_percent)*time_between

print("Training Cutoff Date: {:s}".format(str(train_cutoff)))
print("Validation Cutoff Date: {:s}".format(str(valid_cutoff)))
# Out:
# Training Cutoff Date: 2017-02-23 00:00:00
# Validation Cutoff Date: 2019-11-21 18:14:24

# %%
train_df = wfc[wfc.Date <= train_cutoff]
valid_df = wfc[(wfc.Date > train_cutoff) & (wfc.Date <= valid_cutoff)]
test_df = wfc[wfc.Date > valid_cutoff]

# %%
print("Dataset shape: {:s}".format(str(wfc.shape)))
print("Train dataset shape: {:s}".format(str(train_df.shape)))
print("Vaid dataset shape: {:s}".format(str(valid_df.shape)))
print("Test dataset shape: {:s}".format(str(test_df.shape)))
# Out:
# Dataset shape: (5754, 7)
# Train dataset shape: (4313, 7)
# Vaid dataset shape: (692, 7)
# Test dataset shape: (749, 7)

# %% [markdown]
# # Stock Price Graph

# %%
plotSeries(train_df.Date, train_df.Close, "Training Data")
plotSeries(valid_df.Date, valid_df.Close, "Validation Data")
plotSeries(test_df.Date, test_df.Close, "Test Data")
plt.legend(loc='upper left')

# %%
train_df.set_index(['Date'],inplace=True)
test_df.set_index(['Date'],inplace=True)
valid_df.set_index(['Date'],inplace=True)

# %%
trainNorm = train_df.Close.values.reshape(-1, 1)
testNorm = test_df.Close.values.reshape(-1, 1)
validNorm = valid_df.Close.values.reshape(-1, 1)

# %%
trainNorm.shape
# Out:
# (4313, 1)

# %% [markdown]
# ## Windowed Dataset

# %%
mse_arr=[]
Z = []

window = 15

# %%
X_train= []
Y_train=[]
X_valid= []
Y_valid=[]
X_test= []
Y_test=[]

for i in range(len(trainNorm) - (window)):
    X_train.append(trainNorm[i:i+window])
    Y_train.append(trainNorm[i+window])
    
for i in range(len(validNorm) - (window)):
    X_valid.append(validNorm[i:i+window])
    Y_valid.append(validNorm[i+window])
    
for i in range(len(testNorm) - (window)):
    X_test.append(testNorm[i:i+window])
    Y_test.append(testNorm[i+window])
    

X_train=np.asanyarray(X_train)
Y_train=np.asanyarray(Y_train)
X_valid=np.asanyarray(X_valid)
Y_valid=np.asanyarray(Y_valid)
X_test=np.asanyarray(X_test)
Y_test=np.asanyarray(Y_test)

Xtrain = X_train[:,:,:]  
Ytrain = Y_train[:]  
Xvalid = X_valid[:,:,:]  
Yvalid= Y_valid[:]  
Xtest = X_test[:,:,:]  
Ytest= Y_test[:]

# %% [markdown]
# # Model Building

# %%
tf.keras.backend.clear_session()
model = tf.keras.Sequential()

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1), input_shape = [None]),
    tf.keras.layers.SimpleRNN(40, return_sequences = True),
    tf.keras.layers.SimpleRNN(40),
    tf.keras.layers.Dense(1),
    tf.keras.layers.Lambda(lambda x: x*100.0)
])

model.add()
model.add(keras.layers.Dense(10, input_shape=[window], activation="relu"))
model.add(keras.layers.Dense(10, activation="relu"))
model.add(keras.layers.Dense(1))

# %%
model.compile(loss=tf.keras.losses.MeanSquaredError(),
              optimizer=Adam(1e-4),
              metrics=['mae'])

# %%
log_dir = "logs\\" + datetime.datetime.now().strftime("%d-%m-%Y_%H%M%S")

tensorboard_callback = [
#                         tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1),
#                         ModelCheckpoint(model_path, verbose=1, save_best_only=True),
#                         ReduceLROnPlateau(monitor= "val_mae", factor=0.1, patience=5, min_lr=1e-7, verbose=1),
                        ReduceLROnPlateau(monitor='val_mae', factor=0.2,patience=5, min_lr=1e-6, verbose=1),
#                         CSVLogger(csv_path),
                        TensorBoard(),
                        EarlyStopping(monitor= "val_mae", patience=10, restore_best_weights=True)
                       ]

# %%
history = model.fit(Xtrain, Ytrain,batch_size=128, epochs=100, verbose=1,validation_data=(Xvalid, Yvalid), callbacks=tensorboard_callback)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 2s 9ms/step - loss: 1289.3522 - mae: 34.2940 - val_loss: 2951.4617 - val_mae: 54.1360 - lr: 1.0000e-04
# Epoch 2/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1245.8158 - mae: 33.7082 - val_loss: 2853.1489 - val_mae: 53.2263 - lr: 1.0000e-04
# Epoch 3/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1206.4102 - mae: 33.1707 - val_loss: 2770.8962 - val_mae: 52.4534 - lr: 1.0000e-04
# Epoch 4/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1173.0864 - mae: 32.7064 - val_loss: 2694.6946 - val_mae: 51.7267 - lr: 1.0000e-04
# Epoch 5/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1139.9928 - mae: 32.2416 - val_loss: 2615.7664 - val_mae: 50.9630 - lr: 1.0000e-04
# Epoch 6/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1104.3986 - mae: 31.7318 - val_loss: 2527.8613 - val_mae: 50.0989 - lr: 1.0000e-04
# Epoch 7/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1064.2220 - mae: 31.1474 - val_loss: 2427.3665 - val_mae: 49.0923 - lr: 1.0000e-04
# Epoch 8/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1018.3738 - mae: 30.4669 - val_loss: 2313.2898 - val_mae: 47.9240 - lr: 1.0000e-04
# Epoch 9/100
# 34/34 [==============================] - 0s 4ms/step - loss: 966.4102 - mae: 29.6774 - val_loss: 2185.1702 - val_mae: 46.5770 - lr: 1.0000e-04
# Epoch 10/100
# 34/34 [==============================] - 0s 4ms/step - loss: 908.6343 - mae: 28.7746 - val_loss: 2044.9626 - val_mae: 45.0567 - lr: 1.0000e-04
# Epoch 11/100
# 34/34 [==============================] - 0s 4ms/step - loss: 845.9164 - mae: 27.7607 - val_loss: 1892.4221 - val_mae: 43.3422 - lr: 1.0000e-04
# Epoch 12/100
# 34/34 [==============================] - 0s 4ms/step - loss: 779.3170 - mae: 26.6414 - val_loss: 1734.3351 - val_mae: 41.4906 - lr: 1.0000e-04
# Epoch 13/100
# 34/34 [==============================] - 0s 4ms/step - loss: 709.8499 - mae: 25.4231 - val_loss: 1569.2723 - val_mae: 39.4646 - lr: 1.0000e-04
# Epoch 14/100
# 34/34 [==============================] - 0s 4ms/step - loss: 639.0372 - mae: 24.1157 - val_loss: 1403.3794 - val_mae: 37.3178 - lr: 1.0000e-04
# Epoch 15/100
# 34/34 [==============================] - 0s 5ms/step - loss: 567.8829 - mae: 22.7309 - val_loss: 1238.4271 - val_mae: 35.0530 - lr: 1.0000e-04
# Epoch 16/100
# 34/34 [==============================] - 0s 5ms/step - loss: 498.0778 - mae: 21.2835 - val_loss: 1078.5834 - val_mae: 32.7090 - lr: 1.0000e-04
# Epoch 17/100
# 34/34 [==============================] - 0s 4ms/step - loss: 430.6306 - mae: 19.7809 - val_loss: 924.2119 - val_mae: 30.2733 - lr: 1.0000e-04
# Epoch 18/100
# 34/34 [==============================] - 0s 4ms/step - loss: 366.7517 - mae: 18.2511 - val_loss: 779.4539 - val_mae: 27.7960 - lr: 1.0000e-04
# Epoch 19/100
# 34/34 [==============================] - 0s 4ms/step - loss: 307.3568 - mae: 16.6983 - val_loss: 647.8147 - val_mae: 25.3336 - lr: 1.0000e-04
# Epoch 20/100
# 34/34 [==============================] - 0s 5ms/step - loss: 253.2839 - mae: 15.1522 - val_loss: 528.5742 - val_mae: 22.8757 - lr: 1.0000e-04
# Epoch 21/100
# 34/34 [==============================] - 0s 4ms/step - loss: 205.4100 - mae: 13.6359 - val_loss: 425.1450 - val_mae: 20.5074 - lr: 1.0000e-04
# Epoch 22/100
# 34/34 [==============================] - 0s 4ms/step - loss: 164.5536 - mae: 12.1955 - val_loss: 338.0199 - val_mae: 18.2751 - lr: 1.0000e-04
# Epoch 23/100
# 34/34 [==============================] - 0s 4ms/step - loss: 129.9470 - mae: 10.8208 - val_loss: 264.0485 - val_mae: 16.1383 - lr: 1.0000e-04
# Epoch 24/100
# 34/34 [==============================] - 0s 4ms/step - loss: 100.7906 - mae: 9.5193 - val_loss: 202.6309 - val_mae: 14.1205 - lr: 1.0000e-04
# Epoch 25/100
# 34/34 [==============================] - 0s 4ms/step - loss: 76.9651 - mae: 8.3000 - val_loss: 152.8750 - val_mae: 12.2443 - lr: 1.0000e-04
# Epoch 26/100
# 34/34 [==============================] - 0s 4ms/step - loss: 57.6883 - mae: 7.1698 - val_loss: 113.5763 - val_mae: 10.5282 - lr: 1.0000e-04
# Epoch 27/100
# 34/34 [==============================] - 0s 5ms/step - loss: 42.5179 - mae: 6.1365 - val_loss: 82.3381 - val_mae: 8.9320 - lr: 1.0000e-04
# Epoch 28/100
# 34/34 [==============================] - 0s 5ms/step - loss: 30.8730 - mae: 5.2027 - val_loss: 59.0180 - val_mae: 7.5215 - lr: 1.0000e-04
# Epoch 29/100
# 34/34 [==============================] - 0s 5ms/step - loss: 22.0828 - mae: 4.3713 - val_loss: 41.7035 - val_mae: 6.2731 - lr: 1.0000e-04
# Epoch 30/100
# 34/34 [==============================] - 0s 5ms/step - loss: 15.6069 - mae: 3.6397 - val_loss: 29.0426 - val_mae: 5.1795 - lr: 1.0000e-04
# Epoch 31/100
# 34/34 [==============================] - 0s 5ms/step - loss: 10.9547 - mae: 3.0075 - val_loss: 20.0013 - val_mae: 4.2389 - lr: 1.0000e-04
# Epoch 32/100
# 34/34 [==============================] - 0s 5ms/step - loss: 7.6875 - mae: 2.4717 - val_loss: 13.9044 - val_mae: 3.4783 - lr: 1.0000e-04
# Epoch 33/100
# 34/34 [==============================] - 0s 5ms/step - loss: 5.4473 - mae: 2.0323 - val_loss: 9.7011 - val_mae: 2.8454 - lr: 1.0000e-04
# Epoch 34/100
# 34/34 [==============================] - 0s 5ms/step - loss: 3.9446 - mae: 1.6828 - val_loss: 6.8366 - val_mae: 2.3223 - lr: 1.0000e-04
# Epoch 35/100
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9486 - mae: 1.4073 - val_loss: 5.1398 - val_mae: 1.9506 - lr: 1.0000e-04
# Epoch 36/100
# 34/34 [==============================] - 0s 5ms/step - loss: 2.3066 - mae: 1.1981 - val_loss: 3.9566 - val_mae: 1.6641 - lr: 1.0000e-04
# Epoch 37/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.9037 - mae: 1.0477 - val_loss: 3.2641 - val_mae: 1.4750 - lr: 1.0000e-04
# Epoch 38/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.6572 - mae: 0.9433 - val_loss: 2.7864 - val_mae: 1.3421 - lr: 1.0000e-04
# Epoch 39/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.4992 - mae: 0.8716 - val_loss: 2.5551 - val_mae: 1.2731 - lr: 1.0000e-04
# Epoch 40/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.4106 - mae: 0.8296 - val_loss: 2.3944 - val_mae: 1.2216 - lr: 1.0000e-04
# Epoch 41/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3548 - mae: 0.7999 - val_loss: 2.3236 - val_mae: 1.1956 - lr: 1.0000e-04
# Epoch 42/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3266 - mae: 0.7850 - val_loss: 2.2811 - val_mae: 1.1789 - lr: 1.0000e-04
# Epoch 43/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3041 - mae: 0.7722 - val_loss: 2.2288 - val_mae: 1.1558 - lr: 1.0000e-04
# Epoch 44/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2886 - mae: 0.7640 - val_loss: 2.2165 - val_mae: 1.1479 - lr: 1.0000e-04
# Epoch 45/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.2839 - mae: 0.7607 - val_loss: 2.2091 - val_mae: 1.1436 - lr: 1.0000e-04
# Epoch 46/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.2811 - mae: 0.7591 - val_loss: 2.2071 - val_mae: 1.1419 - lr: 1.0000e-04
# Epoch 47/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2784 - mae: 0.7579 - val_loss: 2.2047 - val_mae: 1.1400 - lr: 1.0000e-04
# Epoch 48/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2766 - mae: 0.7568 - val_loss: 2.1968 - val_mae: 1.1366 - lr: 1.0000e-04
# Epoch 49/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2738 - mae: 0.7553 - val_loss: 2.1877 - val_mae: 1.1324 - lr: 1.0000e-04
# Epoch 50/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2710 - mae: 0.7537 - val_loss: 2.1846 - val_mae: 1.1294 - lr: 1.0000e-04
# Epoch 51/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2697 - mae: 0.7531 - val_loss: 2.1851 - val_mae: 1.1294 - lr: 1.0000e-04
# Epoch 52/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2691 - mae: 0.7528 - val_loss: 2.1779 - val_mae: 1.1268 - lr: 1.0000e-04
# Epoch 53/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2677 - mae: 0.7519 - val_loss: 2.1775 - val_mae: 1.1257 - lr: 1.0000e-04
# Epoch 54/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2671 - mae: 0.7521 - val_loss: 2.1730 - val_mae: 1.1254 - lr: 1.0000e-04
# Epoch 55/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2648 - mae: 0.7509 - val_loss: 2.1686 - val_mae: 1.1238 - lr: 1.0000e-04
# Epoch 56/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2636 - mae: 0.7507 - val_loss: 2.1630 - val_mae: 1.1227 - lr: 1.0000e-04
# Epoch 57/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2616 - mae: 0.7500 - val_loss: 2.1594 - val_mae: 1.1214 - lr: 1.0000e-04
# Epoch 58/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2604 - mae: 0.7495 - val_loss: 2.1583 - val_mae: 1.1211 - lr: 1.0000e-04
# Epoch 59/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2595 - mae: 0.7490 - val_loss: 2.1559 - val_mae: 1.1195 - lr: 1.0000e-04
# Epoch 60/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2594 - mae: 0.7489 - val_loss: 2.1550 - val_mae: 1.1192 - lr: 1.0000e-04
# Epoch 61/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2592 - mae: 0.7488 - val_loss: 2.1545 - val_mae: 1.1188 - lr: 1.0000e-04
# Epoch 62/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2589 - mae: 0.7488 - val_loss: 2.1561 - val_mae: 1.1197 - lr: 1.0000e-04
# Epoch 63/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.2583 - mae: 0.7486 - val_loss: 2.1526 - val_mae: 1.1182 - lr: 1.0000e-04
# Epoch 64/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.2581 - mae: 0.7485 - val_loss: 2.1514 - val_mae: 1.1180 - lr: 1.0000e-04
# Epoch 65/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2576 - mae: 0.7482 - val_loss: 2.1516 - val_mae: 1.1177 - lr: 1.0000e-04
# Epoch 66/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2575 - mae: 0.7482 - val_loss: 2.1523 - val_mae: 1.1177 - lr: 1.0000e-04
# Epoch 67/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2574 - mae: 0.7482 - val_loss: 2.1512 - val_mae: 1.1178 - lr: 1.0000e-04
# Epoch 68/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2569 - mae: 0.7481 - val_loss: 2.1525 - val_mae: 1.1182 - lr: 1.0000e-04
# Epoch 69/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2567 - mae: 0.7481 - val_loss: 2.1498 - val_mae: 1.1172 - lr: 1.0000e-04
# Epoch 70/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2561 - mae: 0.7481 - val_loss: 2.1519 - val_mae: 1.1187 - lr: 1.0000e-04
# Epoch 71/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2558 - mae: 0.7478 - val_loss: 2.1491 - val_mae: 1.1169 - lr: 1.0000e-04
# Epoch 72/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2552 - mae: 0.7475 - val_loss: 2.1478 - val_mae: 1.1163 - lr: 1.0000e-04
# Epoch 73/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2548 - mae: 0.7473 - val_loss: 2.1472 - val_mae: 1.1161 - lr: 1.0000e-04
# Epoch 74/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.2550 - mae: 0.7474 - val_loss: 2.1480 - val_mae: 1.1155 - lr: 1.0000e-04
# Epoch 75/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2543 - mae: 0.7472 - val_loss: 2.1498 - val_mae: 1.1169 - lr: 1.0000e-04
# Epoch 76/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.2540 - mae: 0.7472 - val_loss: 2.1478 - val_mae: 1.1164 - lr: 1.0000e-04
# Epoch 77/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2536 - mae: 0.7471 - val_loss: 2.1480 - val_mae: 1.1168 - lr: 1.0000e-04
# Epoch 78/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2538 - mae: 0.7475 - val_loss: 2.1478 - val_mae: 1.1173 - lr: 1.0000e-04
# Epoch 79/100
# 33/34 [============================>.] - ETA: 0s - loss: 1.2605 - mae: 0.7483
# Epoch 79: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2536 - mae: 0.7471 - val_loss: 2.1473 - val_mae: 1.1159 - lr: 1.0000e-04
# Epoch 80/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.2532 - mae: 0.7468 - val_loss: 2.1470 - val_mae: 1.1159 - lr: 2.0000e-05
# Epoch 81/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2530 - mae: 0.7468 - val_loss: 2.1477 - val_mae: 1.1165 - lr: 2.0000e-05
# Epoch 82/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.2530 - mae: 0.7469 - val_loss: 2.1480 - val_mae: 1.1166 - lr: 2.0000e-05
# Epoch 83/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.2528 - mae: 0.7469 - val_loss: 2.1482 - val_mae: 1.1167 - lr: 2.0000e-05
# Epoch 84/100
# 18/34 [==============>...............] - ETA: 0s - loss: 1.1785 - mae: 0.7316
# Epoch 84: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2528 - mae: 0.7469 - val_loss: 2.1480 - val_mae: 1.1166 - lr: 2.0000e-05

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                160
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 281
# Trainable params: 281
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Showing training and validation loss
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
loss_values50 = loss_values[0:150]
val_loss_values50 = val_loss_values[0:150]
epochs = range(1, len(loss_values50) + 1)
plt.plot(epochs, loss_values50, label='Training Loss')
plt.plot(epochs, val_loss_values50, label='Validation Loss')
plt.rc('font', size = 14)
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.xticks(epochs)
plt.xticks(np.arange(min(epochs), max(epochs)+1, 10.0))
#fig.savefig('test&validationlosscnn.png', dpi=300)
plt.show()

# %%
loss_values = history_dict['mae']
val_loss_values = history_dict['val_mae']
loss_values50 = loss_values[0:150]
val_loss_values50 = val_loss_values[0:150]
epochs = range(1, len(loss_values50) + 1)
plt.plot(epochs, loss_values50, label='Training MAE')
plt.plot(epochs, val_loss_values50, label='Validation MAE')
plt.rc('font', size = 14)
plt.title('Training and Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.xticks(epochs)
plt.xticks(np.arange(min(epochs), max(epochs)+1, 10.0))
#fig.savefig('test&validationlosscnn.png', dpi=300)
plt.show()

# %%
#Evaluating model
trainScore = model.evaluate(Xtrain, Ytrain, verbose=1)
validScore = model.evaluate(Xvalid, Yvalid, verbose=1)
testScore = model.evaluate(Xtest, Ytest, verbose=1)
# Out:
# 135/135 [==============================] - 0s 3ms/step - loss: 1.2541 - mae: 0.7469
# 22/22 [==============================] - 0s 2ms/step - loss: 2.1480 - mae: 1.1155
# 23/23 [==============================] - 0s 2ms/step - loss: 4.4413 - mae: 1.5439

# %%
testScore, validScore, trainScore
# Out:
# ([4.441291332244873, 1.5439351797103882],
#  [2.147989511489868, 1.1155074834823608],
#  [1.2541106939315796, 0.7469053268432617])

# %%
preds = model.predict(Xtest)
# Out:
# 23/23 [==============================] - 0s 1ms/step

# %%
Xtest.shape
# Out:
# (734, 15, 1)

# %%
plt.figure(figsize=(15,5))
plt.title('MSE: {}'.format(testScore[1]))
plt.plot(Ytest, label='Real')
plt.plot(preds, label='Prediction')

plt.legend(loc="best")

#for saving figures
# plt.savefig('CPALL_graph.png')
plt.show()

# %%
#denormalizing datasets
# preds = scaler.inverse_transform(preds)
# Ytest = scaler.inverse_transform(Ytest)

# %%
#Show Train and Test Scores
print('Train MSE \t Train RMSE \t Train MAE \t Testscore RMSE \tTest MSE \tTest MAE')
print('%.9f \t %.9f \t %.9f \t %.9f \t \t %.9f \t %.9f' % (trainScore[0], math.sqrt(trainScore[0]),trainScore[1],math.sqrt(testScore[0]),testScore[0],testScore[1]))
# Out:
# Train MSE 	 Train RMSE 	 Train MAE 	 Testscore RMSE 	Test MSE 	Test MAE
# 1.254110694 	 1.119870838 	 0.746905327 	 2.107437148 	 	 4.441291332 	 1.543935180

# %%
print('MAE \t\t MAPE')
print('%.4f \t\t %.4f' % (mean_absolute_error(Ytest,preds),(np.mean(np.abs((Ytest - preds) / Ytest)) * 100)))
# Out:
# MAE 		 MAPE
# 1.5439 		 4.1162
