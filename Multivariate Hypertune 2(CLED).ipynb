# %% [markdown]
# # The Packages

# %%
# Two models not trained with Eval metrics created

# %%
import numpy as np
import pandas as pd
import os
import gc
import datetime
import warnings

# %%
import statsmodels.api as sm
from datetime import date

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
import tensorflow as tf
import math 
# keras = tf.keras
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LSTM
from tensorflow.keras import losses
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.utils import plot_model

# %%
tf.__version__
# Out:
# '2.10.1'

# %%
# DATA VISUALIZATION
# ------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (20.0, 10.0)
sns.set_style("darkgrid")
sns.color_palette("mako", as_cmap=True)
import plotly.express as px

# %%
# CONFIGURATIONS
# ------------------------------------------------------
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.2f}'.format
warnings.filterwarnings('ignore')

# %% [markdown]
# # Utility Functions

# %%
def plotSeries(time, series, lab,form='-'):
    plt.plot(time, series, form, label=lab)
    plt.xlabel("Date")
    plt.ylabel("Close Price")
    plt.grid(True)

# %%
def plotEvaluation(testData, predData, columns):
    testDf = pd.DataFrame(testData, columns = columns)
    predDf = pd.DataFrame(predData, columns = columns)
    plt.figure(figsize=(15,5))
    plt.plot(testDf.Close, label='Real')
    plt.plot(predDf.Close, label='Prediction')

    plt.legend(loc="best")
    #for saving figures
    plt.show()

# %% [markdown]
# # The Data

# %%
wfc = pd.read_csv('Dataset/Treasury.csv')

# %%
wfc.head()
# Out:
#          Date  Close  Weekday  volumeChange  closeChange  EMA 10  EMA 20  \
# 0  2000-01-03  19.56        0         68.61        -4.95   19.56   19.56
# 1  2000-01-04  18.59        1        -46.00        -1.01   19.03   19.05
# 2  2000-01-05  18.41        2          1.20         4.41   18.78   18.82
# 3  2000-01-06  19.22        3         -7.39         1.79   18.92   18.93
# 4  2000-01-07  19.56        4         16.11        -3.19   19.11   19.08
#
#    EMA 50  EMA 100  ROC5  ROC10  ROC15  ROC20     DTB6    DGS5
# 0   19.56    19.56  0.00   0.00   0.00   0.00 50550.00 6050.00
# 1   19.07    19.07  0.00   0.00   0.00   0.00 50500.00 6040.00
# 2   18.84    18.85  0.00   0.00   0.00   0.00 50490.00 6051.00
# 3   18.94    18.94  0.00   0.00   0.00   0.00 50440.00 6046.00
# 4   19.07    19.07 -0.59   0.00   0.00   0.00 50420.00 6042.00

# %%
wfc.Date.dtype
# Out:
# dtype('O')

# %%
wfc['Date'] = pd.to_datetime(wfc['Date'])
#wfc.set_index(['Date'],inplace=True)

# %%
wfc.head()
# Out:
#         Date  Close  Weekday  volumeChange  closeChange  EMA 10  EMA 20  \
# 0 2000-01-03  19.56        0         68.61        -4.95   19.56   19.56
# 1 2000-01-04  18.59        1        -46.00        -1.01   19.03   19.05
# 2 2000-01-05  18.41        2          1.20         4.41   18.78   18.82
# 3 2000-01-06  19.22        3         -7.39         1.79   18.92   18.93
# 4 2000-01-07  19.56        4         16.11        -3.19   19.11   19.08
#
#    EMA 50  EMA 100  ROC5  ROC10  ROC15  ROC20     DTB6    DGS5
# 0   19.56    19.56  0.00   0.00   0.00   0.00 50550.00 6050.00
# 1   19.07    19.07  0.00   0.00   0.00   0.00 50500.00 6040.00
# 2   18.84    18.85  0.00   0.00   0.00   0.00 50490.00 6051.00
# 3   18.94    18.94  0.00   0.00   0.00   0.00 50440.00 6046.00
# 4   19.07    19.07 -0.59   0.00   0.00   0.00 50420.00 6042.00

# %%
wfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5754 entries, 0 to 5753
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5754 non-null   datetime64[ns]
#  1   Close         5754 non-null   float64
#  2   Weekday       5754 non-null   int64
#  3   volumeChange  5754 non-null   float64
#  4   closeChange   5754 non-null   float64
#  5   EMA 10        5754 non-null   float64
#  6   EMA 20        5754 non-null   float64
#  7   EMA 50        5754 non-null   float64
#  8   EMA 100       5754 non-null   float64
#  9   ROC5          5754 non-null   float64
#  10  ROC10         5754 non-null   float64
#  11  ROC15         5754 non-null   float64
#  12  ROC20         5754 non-null   float64
#  13  DTB6          5754 non-null   float64
#  14  DGS5          5754 non-null   float64
# dtypes: datetime64[ns](1), float64(13), int64(1)
# memory usage: 674.4 KB

# %%
wfc.describe()
# Out:
#         Close  Weekday  volumeChange  closeChange  EMA 10  EMA 20  EMA 50  \
# count 5754.00  5754.00       5754.00      5754.00 5754.00 5754.00 5754.00
# mean    36.38     2.02          5.93         0.04   36.36   36.34   36.27
# std     11.75     1.40         39.58         2.45   11.71   11.68   11.59
# min      8.12     0.00        -84.21       -23.82   10.68   12.45   15.86
# 25%     26.74     1.00        -18.62        -0.84   26.76   26.85   26.86
# 50%     32.64     2.00         -0.81         0.00   32.47   32.43   32.12
# 75%     47.79     3.00         20.93         0.86   47.87   47.96   48.12
# max     65.93     4.00        480.19        32.76   65.12   64.10   61.54
#
#        EMA 100    ROC5   ROC10   ROC15   ROC20     DTB6    DGS5
# count  5754.00 5754.00 5754.00 5754.00 5754.00  5754.00 5754.00
# mean     36.16    0.05    0.04    0.04    0.04  6689.76 2101.97
# std      11.45    0.99    0.65    0.52    0.43 13368.12 1528.92
# min      17.93  -10.67   -6.28   -4.60   -3.39     0.00    0.00
# 25%      27.03   -0.34   -0.22   -0.16   -0.13    14.00 1045.00
# 50%      31.70    0.04    0.04    0.04    0.04  1012.00 2031.00
# 75%      47.94    0.43    0.30    0.25    0.22  4096.00 3068.00
# max      59.00   11.66    7.05    5.18    3.79 60240.00 6083.00

# %%
correlation = wfc.corr ()  
correlation. style.background_gradient ()
# Out:
# <style type="text/css">
# #T_d95ea_row0_col0, #T_d95ea_row0_col4, #T_d95ea_row1_col1, #T_d95ea_row2_col2, #T_d95ea_row3_col3, #T_d95ea_row4_col0, #T_d95ea_row4_col4, #T_d95ea_row4_col5, #T_d95ea_row5_col4, #T_d95ea_row5_col5, #T_d95ea_row5_col6, #T_d95ea_row6_col5, #T_d95ea_row6_col6, #T_d95ea_row6_col7, #T_d95ea_row7_col6, #T_d95ea_row7_col7, #T_d95ea_row8_col8, #T_d95ea_row9_col9, #T_d95ea_row10_col10, #T_d95ea_row11_col11, #T_d95ea_row12_col12, #T_d95ea_row13_col13 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d95ea_row0_col1, #T_d95ea_row1_col10, #T_d95ea_row4_col1, #T_d95ea_row4_col11, #T_d95ea_row5_col1, #T_d95ea_row6_col1, #T_d95ea_row7_col1, #T_d95ea_row12_col2, #T_d95ea_row12_col9, #T_d95ea_row13_col2 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_d95ea_row0_col2, #T_d95ea_row4_col2, #T_d95ea_row5_col2, #T_d95ea_row6_col2, #T_d95ea_row7_col2, #T_d95ea_row8_col1, #T_d95ea_row9_col1, #T_d95ea_row10_col1, #T_d95ea_row11_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_d95ea_row0_col3, #T_d95ea_row1_col2, #T_d95ea_row2_col1, #T_d95ea_row6_col8, #T_d95ea_row6_col9, #T_d95ea_row7_col8, #T_d95ea_row7_col9, #T_d95ea_row7_col10, #T_d95ea_row7_col11, #T_d95ea_row7_col12, #T_d95ea_row7_col13, #T_d95ea_row12_col0, #T_d95ea_row12_col4, #T_d95ea_row12_col5, #T_d95ea_row12_col6, #T_d95ea_row12_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d95ea_row0_col5, #T_d95ea_row4_col6, #T_d95ea_row5_col0, #T_d95ea_row6_col4 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_d95ea_row0_col6, #T_d95ea_row5_col7, #T_d95ea_row6_col0, #T_d95ea_row7_col5 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_d95ea_row0_col7, #T_d95ea_row7_col0 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_d95ea_row0_col8 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_d95ea_row0_col9, #T_d95ea_row1_col11, #T_d95ea_row13_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_d95ea_row0_col10, #T_d95ea_row12_col11 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_d95ea_row0_col11 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_d95ea_row0_col12, #T_d95ea_row0_col13, #T_d95ea_row4_col12, #T_d95ea_row4_col13, #T_d95ea_row5_col3, #T_d95ea_row5_col12, #T_d95ea_row5_col13, #T_d95ea_row6_col3, #T_d95ea_row6_col10 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_d95ea_row1_col0, #T_d95ea_row1_col4, #T_d95ea_row1_col5, #T_d95ea_row2_col6, #T_d95ea_row8_col0 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_d95ea_row1_col3, #T_d95ea_row5_col9 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_d95ea_row1_col6, #T_d95ea_row2_col7, #T_d95ea_row3_col10 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_d95ea_row1_col7, #T_d95ea_row2_col12, #T_d95ea_row3_col12, #T_d95ea_row9_col0 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_d95ea_row1_col8, #T_d95ea_row5_col11, #T_d95ea_row8_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_d95ea_row1_col9, #T_d95ea_row13_col9 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_d95ea_row1_col12, #T_d95ea_row8_col12, #T_d95ea_row9_col12 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_d95ea_row1_col13 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_d95ea_row2_col0, #T_d95ea_row2_col4, #T_d95ea_row2_col5 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_d95ea_row2_col3, #T_d95ea_row4_col8, #T_d95ea_row6_col11, #T_d95ea_row7_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_d95ea_row2_col8 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_d95ea_row2_col9, #T_d95ea_row13_col8 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_d95ea_row2_col10, #T_d95ea_row3_col1, #T_d95ea_row11_col2 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_d95ea_row2_col11, #T_d95ea_row12_col1, #T_d95ea_row13_col10 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_d95ea_row2_col13, #T_d95ea_row3_col7, #T_d95ea_row3_col11, #T_d95ea_row11_col13 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_d95ea_row3_col0, #T_d95ea_row9_col4 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_d95ea_row3_col2, #T_d95ea_row9_col2, #T_d95ea_row10_col2, #T_d95ea_row12_col8 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_d95ea_row3_col4 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_d95ea_row3_col5, #T_d95ea_row3_col13, #T_d95ea_row10_col4 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_d95ea_row3_col6, #T_d95ea_row8_col13, #T_d95ea_row9_col13, #T_d95ea_row10_col13, #T_d95ea_row11_col4 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_d95ea_row3_col8 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_d95ea_row3_col9 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_d95ea_row4_col3, #T_d95ea_row5_col8, #T_d95ea_row6_col12, #T_d95ea_row6_col13 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_d95ea_row4_col7, #T_d95ea_row7_col4 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_d95ea_row4_col9 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_d95ea_row4_col10 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_d95ea_row5_col10, #T_d95ea_row12_col3 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_d95ea_row8_col3 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_d95ea_row8_col4 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_d95ea_row8_col5, #T_d95ea_row8_col7, #T_d95ea_row10_col3, #T_d95ea_row11_col5 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_d95ea_row8_col6, #T_d95ea_row10_col5 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_d95ea_row8_col9 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_d95ea_row8_col10 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_d95ea_row8_col11 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_d95ea_row9_col3 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_d95ea_row9_col5 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_d95ea_row9_col6 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_d95ea_row9_col7 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_d95ea_row9_col8 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_d95ea_row9_col10, #T_d95ea_row12_col13 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_d95ea_row9_col11 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_d95ea_row10_col0, #T_d95ea_row10_col12, #T_d95ea_row11_col0, #T_d95ea_row11_col12 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_d95ea_row10_col6 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_d95ea_row10_col7 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_d95ea_row10_col8 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_d95ea_row10_col9 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_d95ea_row10_col11, #T_d95ea_row11_col10 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_d95ea_row11_col3, #T_d95ea_row11_col6 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_d95ea_row11_col7 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_d95ea_row11_col8 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_d95ea_row11_col9 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_d95ea_row12_col10 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_d95ea_row13_col0, #T_d95ea_row13_col4, #T_d95ea_row13_col5, #T_d95ea_row13_col6, #T_d95ea_row13_col7 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_d95ea_row13_col3 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_d95ea_row13_col11 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_d95ea_row13_col12 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d95ea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d95ea_level0_col0" class="col_heading level0 col0" >Close</th>
#       <th id="T_d95ea_level0_col1" class="col_heading level0 col1" >Weekday</th>
#       <th id="T_d95ea_level0_col2" class="col_heading level0 col2" >volumeChange</th>
#       <th id="T_d95ea_level0_col3" class="col_heading level0 col3" >closeChange</th>
#       <th id="T_d95ea_level0_col4" class="col_heading level0 col4" >EMA 10</th>
#       <th id="T_d95ea_level0_col5" class

# %%
#Dropping Volume for Clearer Scale

# %% [markdown]
# # The Split

# %%
min_date = wfc.Date.min()
max_date = wfc.Date.max()
print("Min:", min_date, "Max:", max_date)
# Out:
# Min: 2000-01-03 00:00:00 Max: 2022-11-11 00:00:00

# %%
train_percent = .75
valid_percent = .12

time_between = max_date - min_date

train_cutoff = min_date + train_percent*time_between
valid_cutoff = min_date + (train_percent + valid_percent)*time_between

print("Training Cutoff Date: {:s}".format(str(train_cutoff)))
print("Validation Cutoff Date: {:s}".format(str(valid_cutoff)))
# Out:
# Training Cutoff Date: 2017-02-23 00:00:00
# Validation Cutoff Date: 2019-11-21 18:14:24

# %%
train_df = wfc[wfc.Date <= train_cutoff]
valid_df = wfc[(wfc.Date > train_cutoff) & (wfc.Date <= valid_cutoff)]
test_df = wfc[wfc.Date > valid_cutoff]

# %%
print("Dataset shape: {:s}".format(str(wfc.shape)))
print("Train dataset shape: {:s}".format(str(train_df.shape)))
print("Vaid dataset shape: {:s}".format(str(valid_df.shape)))
print("Test dataset shape: {:s}".format(str(test_df.shape)))
# Out:
# Dataset shape: (5754, 15)
# Train dataset shape: (4313, 15)
# Vaid dataset shape: (692, 15)
# Test dataset shape: (749, 15)

# %% [markdown]
# # Stock Price Graph

# %%
plotSeries(train_df.Date, train_df.Close, "Training Data")
plotSeries(valid_df.Date, valid_df.Close, "Validation Data")
plotSeries(test_df.Date, test_df.Close, "Test Data")
plt.legend(loc='upper left')

# %% [markdown]
# # Feature Engineering

# %%
train_df.set_index(['Date'],inplace=True)
test_df.set_index(['Date'],inplace=True)
valid_df.set_index(['Date'],inplace=True)

# %%
train_df.head()
# Out:
#             Close  Weekday  volumeChange  closeChange  EMA 10  EMA 20  EMA 50  \
# Date
# 2000-01-03  19.56        0         68.61        -4.95   19.56   19.56   19.56
# 2000-01-04  18.59        1        -46.00        -1.01   19.03   19.05   19.07
# 2000-01-05  18.41        2          1.20         4.41   18.78   18.82   18.84
# 2000-01-06  19.22        3         -7.39         1.79   18.92   18.93   18.94
# 2000-01-07  19.56        4         16.11        -3.19   19.11   19.08   19.07
#
#             EMA 100  ROC5  ROC10  ROC15  ROC20     DTB6    DGS5
# Date
# 2000-01-03    19.56  0.00   0.00   0.00   0.00 50550.00 6050.00
# 2000-01-04    19.07  0.00   0.00   0.00   0.00 50500.00 6040.00
# 2000-01-05    18.85  0.00   0.00   0.00   0.00 50490.00 6051.00
# 2000-01-06    18.94  0.00   0.00   0.00   0.00 50440.00 6046.00
# 2000-01-07    19.07 -0.59   0.00   0.00   0.00 50420.00 6042.00

# %%
scaler = MinMaxScaler()

trainNorm = scaler.fit_transform(train_df.values)
testNorm = scaler.transform(test_df.values)
validNorm = scaler.transform(valid_df.values)

trainNormDf = pd.DataFrame(trainNorm, columns=train_df.columns)
testNormDf = pd.DataFrame(testNorm, columns=test_df.columns)
validNormDf = pd.DataFrame(validNorm, columns=valid_df.columns)

# %%
def splitSequence(sequence, look_back, forecast_horizon):
    X, y = list(), list()
    for i in range(len(sequence)): 
        lag_end = i + look_back
        forecast_end = lag_end + forecast_horizon
        if forecast_end > len(sequence):
            break
        seq_x, seq_y = sequence[i:lag_end], sequence[lag_end:forecast_end]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
LOOK_BACK = 24
FORECAST_RANGE = 5
n_features = len(trainNormDf.columns)

# %%
#Add valid df
Xtrain, Ytrain = splitSequence(trainNormDf, look_back=LOOK_BACK, forecast_horizon=FORECAST_RANGE)
Xvalid, Yvalid = splitSequence(validNormDf, look_back=LOOK_BACK, forecast_horizon=FORECAST_RANGE)
Xtest, Ytest = splitSequence(testNormDf, look_back=LOOK_BACK, forecast_horizon=FORECAST_RANGE)

# %%
print(Xtrain.shape)
print(Ytrain.shape)
print(Xvalid.shape)
print(Yvalid.shape)
print(Xtest.shape)
print(Ytest.shape)
# Out:
# (4285, 24, 14)
# (4285, 5, 14)
# (664, 24, 14)
# (664, 5, 14)
# (721, 24, 14)
# (721, 5, 14)

# %%
def inverse_transform(y_test, yhat):
    y_test_reshaped = y_test.reshape(-1, y_test.shape[-1])
    yhat_reshaped = yhat.reshape(-1, yhat.shape[-1])
    yhat_inverse = scaler.inverse_transform(yhat_reshaped)
    y_test_inverse = scaler.inverse_transform(y_test_reshaped)
    return yhat_inverse, y_test_inverse

# %%
def plotMAPEperRange(testData, predData):
    y_test_inverse_time_step  = testData.reshape(int(testData.shape[0]/FORECAST_RANGE), \
                                                      FORECAST_RANGE, testData.shape[-1])
    yhat_inverse_time_step = predData.reshape(int(predData.shape[0]/FORECAST_RANGE), \
                                                  FORECAST_RANGE, predData.shape[-1])
    # yhat_inverse_time_step and y_test_inverse_time_step are both same dimension.
    time_step_list_yhat = [[] for i in range(FORECAST_RANGE)]
    time_step_list_y_test = [[] for i in range(FORECAST_RANGE)]
    for i in range(0, yhat_inverse_time_step.shape[0]):
        for j in range(0, yhat_inverse_time_step.shape[1]):
            time_step_list_yhat[j].append(list(yhat_inverse_time_step[i][j]))
            time_step_list_y_test[j].append(list(y_test_inverse_time_step[i][j]))
    yhat_time_step = np.array(time_step_list_yhat)
    yhat_time_step = yhat_time_step.reshape(yhat_time_step.shape[0], -1)
    y_test_time_step = np.array(time_step_list_y_test)
    y_test_time_step = y_test_time_step.reshape(y_test_time_step.shape[0], -1)
    # plotting
    mape_list = []
    for i in range(0, FORECAST_RANGE):
        mape = mape_(y_test_time_step[i], yhat_time_step[i])
        print(mape)
        mape_list.append(mape)
    plt.plot(range(0, FORECAST_RANGE), mape_list, marker='o')
    plt.xticks((range(0, FORECAST_RANGE)))
    plt.xlabel('Forecast Range')
    plt.ylabel('MAPE')

# %%
def evaluate_forecast(y_test_inverse, yhat_inverse):
    mse_ = tf.keras.losses.MeanSquaredError()
    mae_ = tf.keras.losses.MeanAbsoluteError()
    mape_ = tf.keras.losses.MeanAbsolutePercentageError()
    mae = mae_(y_test_inverse,yhat_inverse)
    print('mae:', mae)
    mse = mse_(y_test_inverse,yhat_inverse)
    print('mse:', mse)
    mape = mape_(y_test_inverse,yhat_inverse)
    print('mape:', mape)

# %%
mse_ = tf.keras.losses.MeanSquaredError()
mae_ = tf.keras.losses.MeanAbsoluteError()
mape_ = tf.keras.losses.MeanAbsolutePercentageError()
# mae = mae_(y_test_inverse,yhat_inverse)
# # print('mae:', mae)
# mse = mse_(y_test_inverse,yhat_inverse)
# # print('mse:', mse)
# mape = mape_(y_test_inverse,yhat_inverse)
# # print('mape:', mape)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, TimeDistributed, Conv1D, MaxPooling1D, Flatten, Bidirectional, Input, Flatten, Activation, Reshape, RepeatVector, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %% [markdown]
# ## CNN-LSTM Encoder-Decoder Model

# %%
tf.keras.backend.clear_session()
model_enc_dec_cnn = Sequential()

# %%
model_enc_dec_cnn.add(Conv1D(filters=32, kernel_size=9, activation='relu', input_shape=(LOOK_BACK, n_features)))
model_enc_dec_cnn.add(Conv1D(filters=32, kernel_size=11, activation='relu'))
model_enc_dec_cnn.add(MaxPooling1D(pool_size=2))
model_enc_dec_cnn.add(Flatten())
model_enc_dec_cnn.add(RepeatVector(FORECAST_RANGE))
model_enc_dec_cnn.add(LSTM(200, return_sequences=True))
model_enc_dec_cnn.add(TimeDistributed(Dense(100, activation='relu')))
model_enc_dec_cnn.add(TimeDistributed(Dense(n_features)))

# %%
# model_enc_dec_cnn.add(Conv1D(filters=64, kernel_size=9, activation='relu', input_shape=(LOOK_BACK, n_features)))
# model_enc_dec_cnn.add(Conv1D(filters=64, kernel_size=11, activation='relu'))
# model_enc_dec_cnn.add(MaxPooling1D(pool_size=2))
# model_enc_dec_cnn.add(Flatten())
# model_enc_dec_cnn.add(RepeatVector(FORECAST_RANGE))
# model_enc_dec_cnn.add(LSTM(200, return_sequences=True))
# model_enc_dec_cnn.add(TimeDistributed(Dense(100, activation='relu')))
# model_enc_dec_cnn.add(TimeDistributed(Dense(n_features)))

# %% [markdown]
# # Hypertuning LR

# %%
lrSchedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch:1e-8*10**(epoch/20))
earlyStop = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10, restore_best_weights=True)

# %%
optimizer = Adam(1e-3)
model_enc_dec_cnn.compile(loss=tf.keras.losses.MeanSquaredError(),
             optimizer = optimizer,
             metrics = ["mae"])

# %%
history = model_enc_dec_cnn.fit(Xtrain,Ytrain,batch_size=128, epochs=500, callbacks=[lrSchedule, earlyStop])
# Out:
# Epoch 1/500
# 34/34 [==============================] - 3s 15ms/step - loss: 0.2124 - mae: 0.4069 - lr: 1.0000e-08
# Epoch 2/500
# 34/34 [==============================] - 0s 15ms/step - loss: 0.2123 - mae: 0.4069 - lr: 1.1220e-08
# Epoch 3/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2123 - mae: 0.4069 - lr: 1.2589e-08
# Epoch 4/500
# 34/34 [==============================] - 1s 15ms/step - loss: 0.2123 - mae: 0.4068 - lr: 1.4125e-08
# Epoch 5/500
# 34/34 [==============================] - 0s 15ms/step - loss: 0.2123 - mae: 0.4068 - lr: 1.5849e-08
# Epoch 6/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2122 - mae: 0.4068 - lr: 1.7783e-08
# Epoch 7/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2122 - mae: 0.4067 - lr: 1.9953e-08
# Epoch 8/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2122 - mae: 0.4067 - lr: 2.2387e-08
# Epoch 9/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2121 - mae: 0.4066 - lr: 2.5119e-08
# Epoch 10/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2121 - mae: 0.4066 - lr: 2.8184e-08
# Epoch 11/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2120 - mae: 0.4065 - lr: 3.1623e-08
# Epoch 12/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2120 - mae: 0.4064 - lr: 3.5481e-08
# Epoch 13/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2119 - mae: 0.4064 - lr: 3.9811e-08
# Epoch 14/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2118 - mae: 0.4063 - lr: 4.4668e-08
# Epoch 15/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2117 - mae: 0.4062 - lr: 5.0119e-08
# Epoch 16/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2116 - mae: 0.4061 - lr: 5.6234e-08
# Epoch 17/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2115 - mae: 0.4059 - lr: 6.3096e-08
# Epoch 18/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2114 - mae: 0.4058 - lr: 7.0795e-08
# Epoch 19/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2113 - mae: 0.4057 - lr: 7.9433e-08
# Epoch 20/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2111 - mae: 0.4055 - lr: 8.9125e-08
# Epoch 21/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2110 - mae: 0.4053 - lr: 1.0000e-07
# Epoch 22/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2108 - mae: 0.4051 - lr: 1.1220e-07
# Epoch 23/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2106 - mae: 0.4048 - lr: 1.2589e-07
# Epoch 24/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2103 - mae: 0.4045 - lr: 1.4125e-07
# Epoch 25/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2100 - mae: 0.4042 - lr: 1.5849e-07
# Epoch 26/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.2097 - mae: 0.4039 - lr: 1.7783e-07
# Epoch 27/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.2094 - mae: 0.4035 - lr: 1.9953e-07
# Epoch 28/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2090 - mae: 0.4030 - lr: 2.2387e-07
# Epoch 29/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2086 - mae: 0.4026 - lr: 2.5119e-07
# Epoch 30/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2081 - mae: 0.4020 - lr: 2.8184e-07
# Epoch 31/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2076 - mae: 0.4014 - lr: 3.1623e-07
# Epoch 32/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2070 - mae: 0.4007 - lr: 3.5481e-07
# Epoch 33/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2064 - mae: 0.3999 - lr: 3.9811e-07
# Epoch 34/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2056 - mae: 0.3990 - lr: 4.4668e-07
# Epoch 35/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2048 - mae: 0.3980 - lr: 5.0119e-07
# Epoch 36/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2038 - mae: 0.3969 - lr: 5.6234e-07
# Epoch 37/500
# 34/34 [==============================] - 1s 15ms/step - loss: 0.2028 - mae: 0.3957 - lr: 6.3096e-07
# Epoch 38/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2016 - mae: 0.3943 - lr: 7.0795e-07
# Epoch 39/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2002 - mae: 0.3927 - lr: 7.9433e-07
# Epoch 40/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.1987 - mae: 0.3909 - lr: 8.9125e-07
# Epoch 41/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.1969 - mae: 0.3889 - lr: 1.0000e-06
# Epoch 42/500
# 34/34 [==============================] - 0s 15ms/step - loss: 0.1949 - mae: 0.3865 - lr: 1.1220e-06
# Epoch 43/500
# 34/34 [==============================] - 1s 15ms/step - loss: 0.1926 - mae: 0.3838 - lr: 1.2589e-06
# Epoch 44/500
# 34/34 [==============================] - 0s 15ms/step - loss: 0.1900 - mae: 0.3807 - lr: 1.4125e-06
# Epoch 45/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.1868 - mae: 0.3770 - lr: 1.5849e-06
# Epoch 46/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.1832 - mae: 0.3727 - lr: 1.7783e-06
# Epoch 47/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.1789 - mae: 0.3674 - lr: 1.9953e-06
# Epoch 48/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.1736 - mae: 0.3610 - lr: 2.2387e-06
# Epoch 49/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.1672 - mae: 0.3531 - lr: 2.5119e-06
# Epoch 50/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.1591 - mae: 0.3433 - lr: 2.8184e-06
# Epoch 51/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.1497 - mae: 0.3315 - lr: 3.1623e-06
# Epoch 52/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.1385 - mae: 0.3167 - lr: 3.5481e-06
# Epoch 53/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.1243 - mae: 0.2966 - lr: 3.9811e-06
# Epoch 54/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.1075 - mae: 0.2710 - lr: 4.4668e-06
# Epoch 55/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0905 - mae: 0.2425 - lr: 5.0119e-06
# Epoch 56/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0753 - mae: 0.2144 - lr: 5.6234e-06
# Epoch 57/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0638 - mae: 0.1915 - lr: 6.3096e-06
# Epoch 58/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0560 - mae: 0.1768 - lr: 7.0795e-06
# Epoch 59/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0504 - mae: 0.1669 - lr: 7.9433e-06
# Epoch 60/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0463 - mae: 0.1592 - lr: 8.9125e-06
# Epoch 61/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0424 - mae: 0.1511 - lr: 1.0000e-05
# Epoch 62/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0385 - mae: 0.1426 - lr: 1.1220e-05
# Epoch 63/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0347 - mae: 0.1334 - lr: 1.2589e-05
# Epoch 64/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0307 - mae: 0.1226 - lr: 1.4125e-05
# Epoch 65/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0267 - mae: 0.1111 - lr: 1.5849e-05
# Epoch 66/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0229 - mae: 0.0994 - lr: 1.7783e-05
# Epoch 67/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0195 - mae: 0.0890 - lr: 1.9953e-05
# Epoch 68/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0171 - mae: 0.0820 - lr: 2.2387e-05
# Epoch 69/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0155 - mae: 0.0765 - lr: 2.5119e-05
# Epoch 70/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0143 - mae: 0.0712 - lr: 2.8184e-05
# Epoch 71/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0133 - mae: 0.0660 - lr: 3.1623e-05
# Epoch 72/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0126 - mae: 0.0618 - lr: 3.5481e-05
# Epoch 73/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0121 - mae: 0.0586 - lr: 3.9811e-05
# Epoch 74/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0117 - mae: 0.0563 - lr: 4.4668e-05
# Epoch 75/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0114 - mae: 0.0546 - lr: 5.0119e-05
# Epoch 76/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0112 - mae: 0.0533 - lr: 5.6234e-05
# Epoch 77/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0110 - mae: 0.0520 - lr: 6.3096e-05
# Epoch 78/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0108 - mae: 0.0511 - lr: 7.0795e-05
# Epoch 79/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0106 - mae: 0.0501 - lr: 7.9433e-05
# Epoch 80/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0104 - mae: 0.0494 - lr: 8.9125e-05
# Epoch 81/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0101 - mae: 0.0488 - lr: 1.0000e-04
# Epoch 82/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0099 - mae: 0.0483 - lr: 1.1220e-04
# Epoch 83/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0097 - mae: 0.0478 - lr: 1.2589e-04
# Epoch 84/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0094 - mae: 0.0473 - lr: 1.4125e-04
# Epoch 85/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0092 - mae: 0.0474 - lr: 1.5849e-04
# Epoch 86/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0088 - mae: 0.0457 - lr: 1.7783e-04
# Epoch 87/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0085 - mae: 0.0449 - lr: 1.9953e-04
# Epoch 88/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0081 - mae: 0.0440 - lr: 2.2387e-04
# Epoch 89/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0075 - mae: 0.0435 - lr: 2.5119e-04
# Epoch 90/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0071 - mae: 0.0435 - lr: 2.8184e-04
# Epoch 91/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0068 - mae: 0.0415 - lr: 3.1623e-04
# Epoch 92/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0066 - mae: 0.0412 - lr: 3.5481e-04
# Epoch 93/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0064 - mae: 0.0408 - lr: 3.9811e-04
# Epoch 94/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0064 - mae: 0.0421 - lr: 4.4668e-04
# Epoch 95/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0062 - mae: 0.0410 - lr: 5.0119e-04
# Epoch 96/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0059 - mae: 0.0409 - lr: 5.6234e-04
# Epoch 97/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0058 - mae: 0.0409 - lr: 6.3096e-04
# Epoch 98/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0056 - mae: 0.0400 - lr: 7.0795e-04
# Epoch 99/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0055 - mae: 0.0403 - lr: 7.9433e-04
# Epoch 100/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0053 - mae: 0.0407 - lr: 8.9125e-04
# Epoch 101/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0052 - mae: 0.0408 - lr: 0.0010
# Epoch 102/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0049 - mae: 0.0375 - lr: 0.0011
# Epoch 103/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0049 - mae: 0.0389 - lr: 0.0013
# Epoch 104/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0047 - mae: 0.0376 - lr: 0.0014
# Epoch 105/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0047 - mae: 0.0378 - lr: 0.0016
# Epoch 106/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0049 - mae: 0.0402 - lr: 0.0018
# Epoch 107/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0047 - mae: 0.0390 - lr: 0.0020
# Epoch 108/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0045 - mae: 0.0372 - lr: 0.0022
# Epoch 109/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0062 - mae: 0.0506 - lr: 0.0025
# Epoch 110/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0043 - mae: 0.0365 - lr: 0.0028
# Epoch 111/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0041 - mae: 0.0348 - lr: 0.0032
# Epoch 112/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0040 - mae: 0.0355 - lr: 0.0035
# Epoch 113/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0040 - mae: 0.0363 - lr: 0.0040
# Epoch 114/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0040 - mae: 0.0358 - lr: 0.0045
# Epoch 115/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0039 - mae: 0.0376 - lr: 0.0050
# Epoch 116/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0038 - mae: 0.0367 - lr: 0.0056
# Epoch 117/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0038 - mae: 0.0362 - lr: 0.0063
# Epoch 118/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0045 - mae: 0.0429 - lr: 0.0071
# Epoch 119/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0037 - mae: 0.0356 - lr: 0.0079
# Epoch 120/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0070 - mae: 0.0548 - lr: 0.0089
# Epoch 121/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0040 - mae: 0.0371 - lr: 0.0100
# Epoch 122/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0041 - mae: 0.0386 - lr: 0.0112
# Epoch 123/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0039 - mae: 0.0364 - lr: 0.0126
# Epoch 124/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0036 - mae: 0.0343 - lr: 0.0141
# Epoch 125/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0038 - mae: 0.0366 - lr: 0.0158
# Epoch 126/500
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0051 - mae: 0.0445 - lr: 0.0178
# Epoch 127/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0046 - mae: 0.0424 - lr: 0.0200
# Epoch 128/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0053 - mae: 0.0474 - lr: 0.0224
# Epoch 129/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0057 - mae: 0.0480 - lr: 0.0251
# Epoch 130/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0044 - mae: 0.0396 - lr: 0.0282
# Epoch 131/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0058 - mae: 0.0503 - lr: 0.0316
# Epoch 132/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0046 - mae: 0.0417 - lr: 0.0355
# Epoch 133/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0758 - mae: 0.1876 - lr: 0.0398
# Epoch 134/500
# 34/34 [==============================] - 0s 13ms/step - loss: 0.0399 - mae: 0.1373 - lr: 0.0447

# %%
plt.figure(figsize=(20,8))
plt.semilogx(history.history["lr"], history.history["loss"])

# %%
end()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [80], line 1
# ----> 1 end()
#
# NameError: name 'end' is not defined

# %% [markdown]
# ## Final Model

# %%
model_enc_dec_cnn.compile(loss=tf.keras.losses.MeanSquaredError(),
              optimizer=Adam(1e-3),
              metrics=['mae'])

# %%
log_dir = "logs\\" + datetime.datetime.now().strftime("%d-%m-%Y_%H%M%S")
# model_path = ""
tensorboard_callback = [
#                         tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1),
#                         ModelCheckpoint(model_path, verbose=1, save_best_only=True),
                        ReduceLROnPlateau(monitor='val_mae', factor=0.3,patience=10, min_lr=1e-6, verbose=1),
#                         CSVLogger(csv_path),
                        TensorBoard(),
                        EarlyStopping(monitor= "val_mae", patience=10, restore_best_weights=True)
                       ]

# %%
history = model_enc_dec_cnn.fit(Xtrain, Ytrain,batch_size=128, epochs=100, verbose=1,validation_data=(Xvalid, Yvalid), \
                            callbacks=tensorboard_callback)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 3s 33ms/step - loss: 0.0541 - mae: 0.1629 - val_loss: 0.0180 - val_mae: 0.0947 - lr: 0.0010
# Epoch 2/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0131 - mae: 0.0634 - val_loss: 0.0111 - val_mae: 0.0551 - lr: 0.0010
# Epoch 3/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0115 - mae: 0.0541 - val_loss: 0.0106 - val_mae: 0.0507 - lr: 0.0010
# Epoch 4/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0109 - mae: 0.0506 - val_loss: 0.0102 - val_mae: 0.0482 - lr: 0.0010
# Epoch 5/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0104 - mae: 0.0488 - val_loss: 0.0096 - val_mae: 0.0474 - lr: 0.0010
# Epoch 6/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0095 - mae: 0.0476 - val_loss: 0.0088 - val_mae: 0.0494 - lr: 0.0010
# Epoch 7/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0085 - mae: 0.0458 - val_loss: 0.0076 - val_mae: 0.0455 - lr: 0.0010
# Epoch 8/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0074 - mae: 0.0437 - val_loss: 0.0065 - val_mae: 0.0427 - lr: 0.0010
# Epoch 9/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0067 - mae: 0.0422 - val_loss: 0.0064 - val_mae: 0.0457 - lr: 0.0010
# Epoch 10/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0063 - mae: 0.0407 - val_loss: 0.0065 - val_mae: 0.0448 - lr: 0.0010
# Epoch 11/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0059 - mae: 0.0395 - val_loss: 0.0054 - val_mae: 0.0400 - lr: 0.0010
# Epoch 12/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0055 - mae: 0.0386 - val_loss: 0.0054 - val_mae: 0.0414 - lr: 0.0010
# Epoch 13/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0053 - mae: 0.0379 - val_loss: 0.0050 - val_mae: 0.0380 - lr: 0.0010
# Epoch 14/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0050 - mae: 0.0371 - val_loss: 0.0048 - val_mae: 0.0385 - lr: 0.0010
# Epoch 15/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0048 - mae: 0.0366 - val_loss: 0.0048 - val_mae: 0.0402 - lr: 0.0010
# Epoch 16/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0047 - mae: 0.0360 - val_loss: 0.0043 - val_mae: 0.0348 - lr: 0.0010
# Epoch 17/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0045 - mae: 0.0345 - val_loss: 0.0041 - val_mae: 0.0352 - lr: 0.0010
# Epoch 18/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0044 - mae: 0.0343 - val_loss: 0.0039 - val_mae: 0.0347 - lr: 0.0010
# Epoch 19/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0042 - mae: 0.0336 - val_loss: 0.0041 - val_mae: 0.0380 - lr: 0.0010
# Epoch 20/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0043 - mae: 0.0340 - val_loss: 0.0042 - val_mae: 0.0372 - lr: 0.0010
# Epoch 21/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0042 - mae: 0.0338 - val_loss: 0.0038 - val_mae: 0.0341 - lr: 0.0010
# Epoch 22/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0041 - mae: 0.0327 - val_loss: 0.0043 - val_mae: 0.0408 - lr: 0.0010
# Epoch 23/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0041 - mae: 0.0329 - val_loss: 0.0036 - val_mae: 0.0329 - lr: 0.0010
# Epoch 24/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0040 - mae: 0.0326 - val_loss: 0.0036 - val_mae: 0.0323 - lr: 0.0010
# Epoch 25/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0039 - mae: 0.0310 - val_loss: 0.0038 - val_mae: 0.0340 - lr: 0.0010
# Epoch 26/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0039 - mae: 0.0320 - val_loss: 0.0037 - val_mae: 0.0337 - lr: 0.0010
# Epoch 27/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0039 - mae: 0.0315 - val_loss: 0.0035 - val_mae: 0.0312 - lr: 0.0010
# Epoch 28/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0037 - mae: 0.0305 - val_loss: 0.0034 - val_mae: 0.0318 - lr: 0.0010
# Epoch 29/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0037 - mae: 0.0307 - val_loss: 0.0037 - val_mae: 0.0337 - lr: 0.0010
# Epoch 30/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0037 - mae: 0.0308 - val_loss: 0.0037 - val_mae: 0.0348 - lr: 0.0010
# Epoch 31/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0037 - mae: 0.0306 - val_loss: 0.0035 - val_mae: 0.0320 - lr: 0.0010
# Epoch 32/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0036 - mae: 0.0306 - val_loss: 0.0038 - val_mae: 0.0366 - lr: 0.0010
# Epoch 33/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0035 - mae: 0.0298 - val_loss: 0.0034 - val_mae: 0.0336 - lr: 0.0010
# Epoch 34/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0036 - mae: 0.0306 - val_loss: 0.0034 - val_mae: 0.0320 - lr: 0.0010
# Epoch 35/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0035 - mae: 0.0298 - val_loss: 0.0038 - val_mae: 0.0340 - lr: 0.0010
# Epoch 36/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0035 - mae: 0.0295 - val_loss: 0.0037 - val_mae: 0.0354 - lr: 0.0010
# Epoch 37/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0034 - mae: 0.0295 - val_loss: 0.0031 - val_mae: 0.0304 - lr: 0.0010
# Epoch 38/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0033 - mae: 0.0296 - val_loss: 0.0034 - val_mae: 0.0336 - lr: 0.0010
# Epoch 39/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0033 - mae: 0.0297 - val_loss: 0.0032 - val_mae: 0.0315 - lr: 0.0010
# Epoch 40/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0033 - mae: 0.0291 - val_loss: 0.0031 - val_mae: 0.0305 - lr: 0.0010
# Epoch 41/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0032 - mae: 0.0292 - val_loss: 0.0032 - val_mae: 0.0322 - lr: 0.0010
# Epoch 42/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0032 - mae: 0.0288 - val_loss: 0.0032 - val_mae: 0.0312 - lr: 0.0010
# Epoch 43/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0032 - mae: 0.0288 - val_loss: 0.0033 - val_mae: 0.0324 - lr: 0.0010
# Epoch 44/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0032 - mae: 0.0290 - val_loss: 0.0032 - val_mae: 0.0307 - lr: 0.0010
# Epoch 45/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0031 - mae: 0.0280 - val_loss: 0.0029 - val_mae: 0.0274 - lr: 0.0010
# Epoch 46/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0031 - mae: 0.0280 - val_loss: 0.0028 - val_mae: 0.0286 - lr: 0.0010
# Epoch 47/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0031 - mae: 0.0279 - val_loss: 0.0029 - val_mae: 0.0291 - lr: 0.0010
# Epoch 48/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0031 - mae: 0.0290 - val_loss: 0.0032 - val_mae: 0.0338 - lr: 0.0010
# Epoch 49/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0030 - mae: 0.0286 - val_loss: 0.0030 - val_mae: 0.0306 - lr: 0.0010
# Epoch 50/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0030 - mae: 0.0276 - val_loss: 0.0027 - val_mae: 0.0273 - lr: 0.0010
# Epoch 51/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0029 - mae: 0.0272 - val_loss: 0.0030 - val_mae: 0.0308 - lr: 0.0010
# Epoch 52/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0030 - mae: 0.0282 - val_loss: 0.0033 - val_mae: 0.0328 - lr: 0.0010
# Epoch 53/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0030 - mae: 0.0282 - val_loss: 0.0028 - val_mae: 0.0286 - lr: 0.0010
# Epoch 54/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0029 - mae: 0.0281 - val_loss: 0.0031 - val_mae: 0.0341 - lr: 0.0010
# Epoch 55/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0028 - mae: 0.0264
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0028 - mae: 0.0264 - val_loss: 0.0028 - val_mae: 0.0297 - lr: 0.0010
# Epoch 56/100
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0027 - mae: 0.0251 - val_loss: 0.0026 - val_mae: 0.0263 - lr: 3.0000e-04
# Epoch 57/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0027 - mae: 0.0249 - val_loss: 0.0026 - val_mae: 0.0269 - lr: 3.0000e-04
# Epoch 58/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0026 - mae: 0.0248 - val_loss: 0.0026 - val_mae: 0.0267 - lr: 3.0000e-04
# Epoch 59/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0026 - mae: 0.0248 - val_loss: 0.0026 - val_mae: 0.0274 - lr: 3.0000e-04
# Epoch 60/100
# 34/34 [==============================] - 0s 15ms/step - loss: 0.0026 - mae: 0.0246 - val_loss: 0.0028 - val_mae: 0.0278 - lr: 3.0000e-04
# Epoch 61/100
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0027 - mae: 0.0251 - val_loss: 0.0028 - val_mae: 0.0291 - lr: 3.0000e-04
# Epoch 62/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0026 - mae: 0.0250 - val_loss: 0.0027 - val_mae: 0.0269 - lr: 3.0000e-04
# Epoch 63/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0026 - mae: 0.0246 - val_loss: 0.0026 - val_mae: 0.0267 - lr: 3.0000e-04
# Epoch 64/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0026 - mae: 0.0249 - val_loss: 0.0025 - val_mae: 0.0256 - lr: 3.0000e-04
# Epoch 65/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0026 - mae: 0.0250 - val_loss: 0.0028 - val_mae: 0.0281 - lr: 3.0000e-04
# Epoch 66/100
# 34/34 [==============================] - 0s 15ms/step - loss: 0.0026 - mae: 0.0248 - val_loss: 0.0026 - val_mae: 0.0259 - lr: 3.0000e-04
# Epoch 67/100
# 34/34 [==============================] - 0s 15ms/step - loss: 0.0026 - mae: 0.0246 - val_loss: 0.0025 - val_mae: 0.0255 - lr: 3.0000e-04
# Epoch 68/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0026 - mae: 0.0247 - val_loss: 0.0026 - val_mae: 0.0277 - lr: 3.0000e-04
# Epoch 69/100
# 34/34 [==============================] - 0s 15ms/step - loss: 0.0026 - mae: 0.0248 - val_loss: 0.0027 - val_mae: 0.0286 - lr: 3.0000e-04
# Epoch 70/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0026 - mae: 0.0247 - val_loss: 0.0027 - val_mae: 0.0267 - lr: 3.0000e-04
# Epoch 71/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0026 - mae: 0.0253 - val_loss: 0.0026 - val_mae: 0.0261 - lr: 3.0000e-04
# Epoch 72/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0026 - mae: 0.0246 - val_loss: 0.0026 - val_mae: 0.0264 - lr: 3.0000e-04
# Epoch 73/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0025 - mae: 0.0246 - val_loss: 0.0025 - val_mae: 0.0256 - lr: 3.0000e-04
# Epoch 74/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0025 - mae: 0.0246
# Epoch 74: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0026 - mae: 0.0246 - val_loss: 0.0025 - val_mae: 0.0263 - lr: 3.0000e-04
# Epoch 75/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0025 - mae: 0.0240 - val_loss: 0.0025 - val_mae: 0.0256 - lr: 9.0000e-05
# Epoch 76/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0025 - mae: 0.0238 - val_loss: 0.0025 - val_mae: 0.0252 - lr: 9.0000e-05
# Epoch 77/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0025 - mae: 0.0239 - val_loss: 0.0026 - val_mae: 0.0259 - lr: 9.0000e-05
# Epoch 78/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0025 - mae: 0.0240 - val_loss: 0.0025 - val_mae: 0.0253 - lr: 9.0000e-05
# Epoch 79/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0025 - mae: 0.0239 - val_loss: 0.0026 - val_mae: 0.0261 - lr: 9.0000e-05
# Epoch 80/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0025 - mae: 0.0238 - val_loss: 0.0025 - val_mae: 0.0254 - lr: 9.0000e-05
# Epoch 81/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0025 - mae: 0.0238 - val_loss: 0.0026 - val_mae: 0.0261 - lr: 9.0000e-05
# Epoch 82/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.0025 - mae: 0.0239 - val_loss: 0.0025 - val_mae: 0.0256 - lr: 9.0000e-05
# Epoch 83/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0025 - mae: 0.0239 - val_loss: 0.0025 - val_mae: 0.0256 - lr: 9.0000e-05
# Epoch 84/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0025 - mae: 0.0238 - val_loss: 0.0025 - val_mae: 0.0252 - lr: 9.0000e-05
# Epoch 85/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0025 - mae: 0.0239 - val_loss: 0.0025 - val_mae: 0.0261 - lr: 9.0000e-05
# Epoch 86/100
# 33/34 [============================>.] - ETA: 0s - loss: 0.0025 - mae: 0.0238
# Epoch 86: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 34/34 [==============================] - 1s 16ms/step - loss: 0.0025 - mae: 0.0238 - val_loss: 0.0025 - val_mae: 0.0253 - lr: 9.0000e-05

# %%
trainScore = model_enc_dec_cnn.evaluate(Xtrain, Ytrain, verbose=1)
validScore = model_enc_dec_cnn.evaluate(Xvalid, Yvalid, verbose=1)
testScore = model_enc_dec_cnn.evaluate(Xtest, Ytest, verbose=1)
# Out:
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0025 - mae: 0.0236
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0025 - mae: 0.0252
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0031 - mae: 0.0315

# %%
testScore, validScore, trainScore
# Out:
# ([0.0031177580822259188, 0.03147946670651436],
#  [0.002479875460267067, 0.025174325332045555],
#  [0.002485390519723296, 0.02355453185737133])

# %%
yhat = model_enc_dec_cnn.predict(Xtest, verbose=0)

# %%
predData, testData = inverse_transform(Ytest, yhat)
evaluate_forecast(testData, predData)
# Out:
# mae: tf.Tensor(69.22498, shape=(), dtype=float32)
# mse: tf.Tensor(69578.43, shape=(), dtype=float32)
# mape: tf.Tensor(1060575300.0, shape=(), dtype=float32)

# %%
plotEvaluation(testData, predData, columns = testNormDf.columns)

# %%
def displayMetricsByColumn(testData, predData, columns, i):

    print('->', columns[i])
    mae = mae_(testData[:,i],predData[:,i])
    print('mae:', mae)
    mse = mse_(testData[:,i],predData[:,i])
    print('mse:', mse)
    mape = mape_(testData[:,i],predData[:,i])
    print('mape:', mape)

# %%
displayMetricsByColumn(testData, predData, train_df.columns, 0)
# Out:
# -> Close
# mae: tf.Tensor(1.5947953, shape=(), dtype=float32)
# mse: tf.Tensor(4.749989, shape=(), dtype=float32)
# mape: tf.Tensor(4.251893, shape=(), dtype=float32)

# %% [markdown]
# # WIP

# %%
testData[:20,1]
# Out:
# array([0., 1., 3., 4., 0., 1., 3., 4., 0., 1., 3., 4., 0., 1., 2., 4., 0.,
#        1., 2., 3.])

# %%
predData[:20,1]
# Out:
# array([ 1.4567952 ,  0.5019933 ,  1.6319777 ,  2.7164838 ,  3.5205853 ,
#         0.9840292 ,  1.9893045 ,  2.8717055 ,  3.7692933 , -0.18146878,
#         2.0229142 ,  3.2139382 ,  3.2034192 ,  0.32537907,  1.0651436 ,
#         3.327101  ,  1.896903  ,  0.3314529 ,  1.4299685 ,  2.384157  ],
#       dtype=float32)

# %%
Ytest.shape
# Out:
# (721, 5, 14)

# %%
testData.shape
# Out:
# (3605, 14)

# %%
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.metrics import mean_absolute_percentage_error as MAPE

# %%
key = 0
testFore1, testFore2, testFore3, testFore4, testFore5 = list(), list(), list(), list(), list()
predFore1, predFore2, predFore3, predFore4, predFore5 = list(), list(), list(), list(), list()
for i in range(testData.shape[0]): #testData.shape(0)
    remainder = i%5
    if remainder == 0:
        testFore1.append(testData[i][key])
        predFore1.append(predData[i][key])
    elif remainder == 1:
        testFore2.append(testData[i][key])
        predFore2.append(predData[i][key])
    elif remainder == 2:
        testFore3.append(testData[i][key])
        predFore3.append(predData[i][key])
    elif remainder == 3:
        testFore4.append(testData[i][key])
        predFore4.append(predData[i][key])
    elif remainder == 4:
        testFore5.append(testData[i][key])
        predFore5.append(predData[i][key])

# %%
len(testFore1), len(testFore5), len(predFore1), len(predFore5)
# Out:
# (721, 721, 721, 721)

# %%
evalDict = {"testData1" : testFore1, "testData2" : testFore2, "testData3": testFore3, "testData4" : testFore4, \
                  "testData5" : testFore5, "predData1" : predFore1, "predData2" : predFore2, "predData3": predFore3, \
                  "predData4" : predFore4, "predData5" : predFore5}

# %%
evaluationDf = pd.DataFrame(evalDict)
evaluationDf.head()
# Out:
#    testData1  testData2  testData3  testData4  testData5  predData1  \
# 0      53.60      53.80      53.75      53.42      53.10      53.62
# 1      53.80      53.75      53.42      53.10      52.66      54.02
# 2      53.75      53.42      53.10      52.66      52.82      53.57
# 3      53.42      53.10      52.66      52.82      52.73      52.76
# 4      53.10      52.66      52.82      52.73      52.50      52.80
#
#    predData2  predData3  predData4  predData5
# 0      52.75      52.85      52.77      53.19
# 1      53.51      53.41      53.57      53.46
# 2      54.09      54.18      53.34      53.22
# 3      53.23      52.40      52.34      52.87
# 4      51.28      51.93      51.94      52.56

# %%
MAPE(evaluationDf.testData1, evaluationDf.predData1)
# Out:
# 0.03491685116070775

# %%
MAPE(evaluationDf.testData2, evaluationDf.predData2)
# Out:
# 0.039184920082866406

# %%
MAPE(evaluationDf.testData3, evaluationDf.predData3)
# Out:
# 0.042462599238363374

# %%
MAPE(evaluationDf.testData4, evaluationDf.predData4)
# Out:
# 0.04594954728914293

# %%
MAPE(evaluationDf.testData5, evaluationDf.predData5)
# Out:
# 0.0500807030749525

# %%
plt.figure(figsize=(12,5))
plt.plot(evaluationDf.testData1, label='Real')
plt.plot(evaluationDf.predData1, label='Prediction')

plt.legend(loc="best")
#for saving figures
plt.savefig('media/CnnLstmEnDe.png')
plt.show()

# %%
def average():
    s = (MAPE(evaluationDf.testData1, evaluationDf.predData1) + MAPE(evaluationDf.testData2, evaluationDf.predData2) + \
    MAPE(evaluationDf.testData3, evaluationDf.predData3) + MAPE(evaluationDf.testData4, evaluationDf.predData4) + \
    MAPE(evaluationDf.testData5, evaluationDf.predData5))/5
    print(s)

# %%
average()
# Out:
# 0.04251892416920659

# %%
n_features
# Out:
# 14
