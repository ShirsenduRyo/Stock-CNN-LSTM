# %% [markdown]
# # The Packages

# %%
import numpy as np
import pandas as pd
import os
import gc
import datetime
import warnings

# %%
import statsmodels.api as sm
from datetime import date

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
import tensorflow as tf
import math 
# keras = tf.keras
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LSTM
from tensorflow.keras import losses
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.utils import plot_model

# %%
tf.__version__
# Out:
# '2.10.1'

# %%
# DATA VISUALIZATION
# ------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (20.0, 10.0)
sns.set_style("darkgrid")
sns.color_palette("mako", as_cmap=True)
import plotly.express as px

# %%
# CONFIGURATIONS
# ------------------------------------------------------
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.2f}'.format
warnings.filterwarnings('ignore')

# %% [markdown]
# # Utility Functions

# %%
def plotSeries(time, series, lab,form='-'):
    plt.plot(time, series, form, label=lab)
    plt.xlabel("Date")
    plt.ylabel("Close Price")
    plt.grid(True)

# %%
def plotEvaluation(testData, predData, columns):
    testDf = pd.DataFrame(testData, columns = columns)
    predDf = pd.DataFrame(predData, columns = columns)
    plt.figure(figsize=(15,5))
    plt.plot(testDf.Close, label='Real')
    plt.plot(predDf.Close, label='Prediction')

    plt.legend(loc="best")
    #for saving figures
    plt.show()

# %% [markdown]
# # The Data

# %%
wfc = pd.read_csv('Dataset/Treasury.csv')

# %%
wfc.head()
# Out:
#          Date  Close  Weekday  volumeChange  closeChange  EMA 10  EMA 20  \
# 0  2000-01-03  19.56        0         68.61        -4.95   19.56   19.56
# 1  2000-01-04  18.59        1        -46.00        -1.01   19.03   19.05
# 2  2000-01-05  18.41        2          1.20         4.41   18.78   18.82
# 3  2000-01-06  19.22        3         -7.39         1.79   18.92   18.93
# 4  2000-01-07  19.56        4         16.11        -3.19   19.11   19.08
#
#    EMA 50  EMA 100  ROC5  ROC10  ROC15  ROC20     DTB6    DGS5
# 0   19.56    19.56  0.00   0.00   0.00   0.00 50550.00 6050.00
# 1   19.07    19.07  0.00   0.00   0.00   0.00 50500.00 6040.00
# 2   18.84    18.85  0.00   0.00   0.00   0.00 50490.00 6051.00
# 3   18.94    18.94  0.00   0.00   0.00   0.00 50440.00 6046.00
# 4   19.07    19.07 -0.59   0.00   0.00   0.00 50420.00 6042.00

# %%
wfc.Date.dtype
# Out:
# dtype('O')

# %%
wfc['Date'] = pd.to_datetime(wfc['Date'])
#wfc.set_index(['Date'],inplace=True)

# %%
wfc.head()
# Out:
#         Date  Close  Weekday  volumeChange  closeChange  EMA 10  EMA 20  \
# 0 2000-01-03  19.56        0         68.61        -4.95   19.56   19.56
# 1 2000-01-04  18.59        1        -46.00        -1.01   19.03   19.05
# 2 2000-01-05  18.41        2          1.20         4.41   18.78   18.82
# 3 2000-01-06  19.22        3         -7.39         1.79   18.92   18.93
# 4 2000-01-07  19.56        4         16.11        -3.19   19.11   19.08
#
#    EMA 50  EMA 100  ROC5  ROC10  ROC15  ROC20     DTB6    DGS5
# 0   19.56    19.56  0.00   0.00   0.00   0.00 50550.00 6050.00
# 1   19.07    19.07  0.00   0.00   0.00   0.00 50500.00 6040.00
# 2   18.84    18.85  0.00   0.00   0.00   0.00 50490.00 6051.00
# 3   18.94    18.94  0.00   0.00   0.00   0.00 50440.00 6046.00
# 4   19.07    19.07 -0.59   0.00   0.00   0.00 50420.00 6042.00

# %%
wfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5754 entries, 0 to 5753
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5754 non-null   datetime64[ns]
#  1   Close         5754 non-null   float64
#  2   Weekday       5754 non-null   int64
#  3   volumeChange  5754 non-null   float64
#  4   closeChange   5754 non-null   float64
#  5   EMA 10        5754 non-null   float64
#  6   EMA 20        5754 non-null   float64
#  7   EMA 50        5754 non-null   float64
#  8   EMA 100       5754 non-null   float64
#  9   ROC5          5754 non-null   float64
#  10  ROC10         5754 non-null   float64
#  11  ROC15         5754 non-null   float64
#  12  ROC20         5754 non-null   float64
#  13  DTB6          5754 non-null   float64
#  14  DGS5          5754 non-null   float64
# dtypes: datetime64[ns](1), float64(13), int64(1)
# memory usage: 674.4 KB

# %%
wfc.describe()
# Out:
#         Close  Weekday  volumeChange  closeChange  EMA 10  EMA 20  EMA 50  \
# count 5754.00  5754.00       5754.00      5754.00 5754.00 5754.00 5754.00
# mean    36.38     2.02          5.93         0.04   36.36   36.34   36.27
# std     11.75     1.40         39.58         2.45   11.71   11.68   11.59
# min      8.12     0.00        -84.21       -23.82   10.68   12.45   15.86
# 25%     26.74     1.00        -18.62        -0.84   26.76   26.85   26.86
# 50%     32.64     2.00         -0.81         0.00   32.47   32.43   32.12
# 75%     47.79     3.00         20.93         0.86   47.87   47.96   48.12
# max     65.93     4.00        480.19        32.76   65.12   64.10   61.54
#
#        EMA 100    ROC5   ROC10   ROC15   ROC20     DTB6    DGS5
# count  5754.00 5754.00 5754.00 5754.00 5754.00  5754.00 5754.00
# mean     36.16    0.05    0.04    0.04    0.04  6689.76 2101.97
# std      11.45    0.99    0.65    0.52    0.43 13368.12 1528.92
# min      17.93  -10.67   -6.28   -4.60   -3.39     0.00    0.00
# 25%      27.03   -0.34   -0.22   -0.16   -0.13    14.00 1045.00
# 50%      31.70    0.04    0.04    0.04    0.04  1012.00 2031.00
# 75%      47.94    0.43    0.30    0.25    0.22  4096.00 3068.00
# max      59.00   11.66    7.05    5.18    3.79 60240.00 6083.00

# %%
correlation = wfc.corr ()  
correlation. style.background_gradient ()
# Out:
# <style type="text/css">
# #T_04855_row0_col0, #T_04855_row0_col4, #T_04855_row1_col1, #T_04855_row2_col2, #T_04855_row3_col3, #T_04855_row4_col0, #T_04855_row4_col4, #T_04855_row4_col5, #T_04855_row5_col4, #T_04855_row5_col5, #T_04855_row5_col6, #T_04855_row6_col5, #T_04855_row6_col6, #T_04855_row6_col7, #T_04855_row7_col6, #T_04855_row7_col7, #T_04855_row8_col8, #T_04855_row9_col9, #T_04855_row10_col10, #T_04855_row11_col11, #T_04855_row12_col12, #T_04855_row13_col13 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_04855_row0_col1, #T_04855_row1_col10, #T_04855_row4_col1, #T_04855_row4_col11, #T_04855_row5_col1, #T_04855_row6_col1, #T_04855_row7_col1, #T_04855_row12_col2, #T_04855_row12_col9, #T_04855_row13_col2 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_04855_row0_col2, #T_04855_row4_col2, #T_04855_row5_col2, #T_04855_row6_col2, #T_04855_row7_col2, #T_04855_row8_col1, #T_04855_row9_col1, #T_04855_row10_col1, #T_04855_row11_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_04855_row0_col3, #T_04855_row1_col2, #T_04855_row2_col1, #T_04855_row6_col8, #T_04855_row6_col9, #T_04855_row7_col8, #T_04855_row7_col9, #T_04855_row7_col10, #T_04855_row7_col11, #T_04855_row7_col12, #T_04855_row7_col13, #T_04855_row12_col0, #T_04855_row12_col4, #T_04855_row12_col5, #T_04855_row12_col6, #T_04855_row12_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_04855_row0_col5, #T_04855_row4_col6, #T_04855_row5_col0, #T_04855_row6_col4 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_04855_row0_col6, #T_04855_row5_col7, #T_04855_row6_col0, #T_04855_row7_col5 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_04855_row0_col7, #T_04855_row7_col0 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_04855_row0_col8 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_04855_row0_col9, #T_04855_row1_col11, #T_04855_row13_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_04855_row0_col10, #T_04855_row12_col11 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_04855_row0_col11 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_04855_row0_col12, #T_04855_row0_col13, #T_04855_row4_col12, #T_04855_row4_col13, #T_04855_row5_col3, #T_04855_row5_col12, #T_04855_row5_col13, #T_04855_row6_col3, #T_04855_row6_col10 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_04855_row1_col0, #T_04855_row1_col4, #T_04855_row1_col5, #T_04855_row2_col6, #T_04855_row8_col0 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_04855_row1_col3, #T_04855_row5_col9 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_04855_row1_col6, #T_04855_row2_col7, #T_04855_row3_col10 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_04855_row1_col7, #T_04855_row2_col12, #T_04855_row3_col12, #T_04855_row9_col0 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_04855_row1_col8, #T_04855_row5_col11, #T_04855_row8_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_04855_row1_col9, #T_04855_row13_col9 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_04855_row1_col12, #T_04855_row8_col12, #T_04855_row9_col12 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_04855_row1_col13 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_04855_row2_col0, #T_04855_row2_col4, #T_04855_row2_col5 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_04855_row2_col3, #T_04855_row4_col8, #T_04855_row6_col11, #T_04855_row7_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_04855_row2_col8 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_04855_row2_col9, #T_04855_row13_col8 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_04855_row2_col10, #T_04855_row3_col1, #T_04855_row11_col2 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_04855_row2_col11, #T_04855_row12_col1, #T_04855_row13_col10 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_04855_row2_col13, #T_04855_row3_col7, #T_04855_row3_col11, #T_04855_row11_col13 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_04855_row3_col0, #T_04855_row9_col4 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_04855_row3_col2, #T_04855_row9_col2, #T_04855_row10_col2, #T_04855_row12_col8 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_04855_row3_col4 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_04855_row3_col5, #T_04855_row3_col13, #T_04855_row10_col4 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_04855_row3_col6, #T_04855_row8_col13, #T_04855_row9_col13, #T_04855_row10_col13, #T_04855_row11_col4 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_04855_row3_col8 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_04855_row3_col9 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_04855_row4_col3, #T_04855_row5_col8, #T_04855_row6_col12, #T_04855_row6_col13 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_04855_row4_col7, #T_04855_row7_col4 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_04855_row4_col9 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_04855_row4_col10 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_04855_row5_col10, #T_04855_row12_col3 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_04855_row8_col3 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_04855_row8_col4 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_04855_row8_col5, #T_04855_row8_col7, #T_04855_row10_col3, #T_04855_row11_col5 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_04855_row8_col6, #T_04855_row10_col5 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_04855_row8_col9 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_04855_row8_col10 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_04855_row8_col11 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_04855_row9_col3 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_04855_row9_col5 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_04855_row9_col6 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_04855_row9_col7 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_04855_row9_col8 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_04855_row9_col10, #T_04855_row12_col13 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_04855_row9_col11 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_04855_row10_col0, #T_04855_row10_col12, #T_04855_row11_col0, #T_04855_row11_col12 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_04855_row10_col6 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_04855_row10_col7 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_04855_row10_col8 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_04855_row10_col9 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_04855_row10_col11, #T_04855_row11_col10 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_04855_row11_col3, #T_04855_row11_col6 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_04855_row11_col7 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_04855_row11_col8 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_04855_row11_col9 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_04855_row12_col10 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_04855_row13_col0, #T_04855_row13_col4, #T_04855_row13_col5, #T_04855_row13_col6, #T_04855_row13_col7 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_04855_row13_col3 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_04855_row13_col11 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_04855_row13_col12 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_04855">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04855_level0_col0" class="col_heading level0 col0" >Close</th>
#       <th id="T_04855_level0_col1" class="col_heading level0 col1" >Weekday</th>
#       <th id="T_04855_level0_col2" class="col_heading level0 col2" >volumeChange</th>
#       <th id="T_04855_level0_col3" class="col_heading level0 col3" >closeChange</th>
#       <th id="T_04855_level0_col4" class="col_heading level0 col4" >EMA 10</th>
#       <th id="T_04855_level0_col5" class

# %% [markdown]
# # The Split

# %%
min_date = wfc.Date.min()
max_date = wfc.Date.max()
print("Min:", min_date, "Max:", max_date)
# Out:
# Min: 2000-01-03 00:00:00 Max: 2022-11-11 00:00:00

# %%
train_percent = .75
valid_percent = .12

time_between = max_date - min_date

train_cutoff = min_date + train_percent*time_between
valid_cutoff = min_date + (train_percent + valid_percent)*time_between

print("Training Cutoff Date: {:s}".format(str(train_cutoff)))
print("Validation Cutoff Date: {:s}".format(str(valid_cutoff)))
# Out:
# Training Cutoff Date: 2017-02-23 00:00:00
# Validation Cutoff Date: 2019-11-21 18:14:24

# %%
train_df = wfc[wfc.Date <= train_cutoff]
valid_df = wfc[(wfc.Date > train_cutoff) & (wfc.Date <= valid_cutoff)]
test_df = wfc[wfc.Date > valid_cutoff]

# %%
print("Dataset shape: {:s}".format(str(wfc.shape)))
print("Train dataset shape: {:s}".format(str(train_df.shape)))
print("Vaid dataset shape: {:s}".format(str(valid_df.shape)))
print("Test dataset shape: {:s}".format(str(test_df.shape)))
# Out:
# Dataset shape: (5754, 15)
# Train dataset shape: (4313, 15)
# Vaid dataset shape: (692, 15)
# Test dataset shape: (749, 15)

# %% [markdown]
# # Stock Price Graph

# %%
plotSeries(train_df.Date, train_df.Close, "Training Data")
plotSeries(valid_df.Date, valid_df.Close, "Validation Data")
plotSeries(test_df.Date, test_df.Close, "Test Data")
plt.legend(loc='upper left')

# %%
train_df.set_index(['Date'],inplace=True)
test_df.set_index(['Date'],inplace=True)
valid_df.set_index(['Date'],inplace=True)

# %%
scaler = MinMaxScaler()

trainNorm = scaler.fit_transform(train_df.values)
testNorm = scaler.transform(test_df.values)
validNorm = scaler.transform(valid_df.values)

trainNormDf = pd.DataFrame(trainNorm, columns=train_df.columns)
testNormDf = pd.DataFrame(testNorm, columns=test_df.columns)
validNormDf = pd.DataFrame(validNorm, columns=valid_df.columns)

# %%
trainNormDf.head(2)
# Out:
#    Close  Weekday  volumeChange  closeChange  EMA 10  EMA 20  EMA 50  EMA 100  \
# 0   0.23     0.00          0.27         0.33    0.19    0.16    0.09     0.04
# 1   0.21     0.25          0.07         0.40    0.18    0.15    0.08     0.03
#
#    ROC5  ROC10  ROC15  ROC20  DTB6  DGS5
# 0  0.48   0.47   0.47   0.47  0.84  0.99
# 1  0.48   0.47   0.47   0.47  0.84  0.99

# %%
def splitSequence(sequence, look_back, forecast_horizon):
    X, y = list(), list()
    for i in range(len(sequence)): 
        lag_end = i + look_back
        forecast_end = lag_end + forecast_horizon
        if forecast_end > len(sequence):
            break
        seq_x, seq_y = sequence[i:lag_end], sequence[lag_end:forecast_end]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
LOOK_BACK = 24
FORECAST_RANGE = 4
n_features = len(trainNormDf.columns)

# %%
#Add valid df
X_train, y_train = splitSequence(trainNormDf, look_back=LOOK_BACK, forecast_horizon=FORECAST_RANGE)
X_test, y_test = splitSequence(testNormDf, look_back=LOOK_BACK, forecast_horizon=FORECAST_RANGE)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (4286, 24, 14)
# (4286, 4, 14)
# (722, 24, 14)
# (722, 4, 14)

# %%
def inverse_transform(y_test, yhat):
    y_test_reshaped = y_test.reshape(-1, y_test.shape[-1])
    yhat_reshaped = yhat.reshape(-1, yhat.shape[-1])
    yhat_inverse = scaler.inverse_transform(yhat_reshaped)
    y_test_inverse = scaler.inverse_transform(y_test_reshaped)
    return yhat_inverse, y_test_inverse

# %%
def evaluate_forecast(y_test_inverse, yhat_inverse):
    mse_ = tf.keras.losses.MeanSquaredError()
    mae_ = tf.keras.losses.MeanAbsoluteError()
    mape_ = tf.keras.losses.MeanAbsolutePercentageError()
    mae = mae_(y_test_inverse,yhat_inverse)
    print('mae:', mae)
    mse = mse_(y_test_inverse,yhat_inverse)
    print('mse:', mse)
    mape = mape_(y_test_inverse,yhat_inverse)
    print('mape:', mape)

# %%
mse_ = tf.keras.losses.MeanSquaredError()
mae_ = tf.keras.losses.MeanAbsoluteError()
mape_ = tf.keras.losses.MeanAbsolutePercentageError()
# mae = mae_(y_test_inverse,yhat_inverse)
# # print('mae:', mae)
# mse = mse_(y_test_inverse,yhat_inverse)
# # print('mse:', mse)
# mape = mape_(y_test_inverse,yhat_inverse)
# # print('mape:', mape)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, TimeDistributed, Conv1D, MaxPooling1D, Flatten, Bidirectional, Input, Flatten, Activation, Reshape, RepeatVector, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %% [markdown]
# # Encoder Decoder Model

# %%
tf.keras.backend.clear_session()
model_enc_dec = tf.keras.Sequential()

# %%
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since
# it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
model_enc_dec.add(LSTM(100, input_shape=(LOOK_BACK, n_features)))
model_enc_dec.add(RepeatVector(FORECAST_RANGE))
model_enc_dec.add(LSTM(100, return_sequences=True))
model_enc_dec.add(TimeDistributed(Dense(n_features)))
model_enc_dec.compile(optimizer='adam', loss='mse')

# %%
# plot_model(model=model_enc_dec, show_shapes=True)

# %%
checkpoint_filepath = ''
# checkpoint_callback = ModelCheckpoint(
#  filepath=checkpoint_filepath,
#  save_weights_only=False,
#  monitor='val_loss',
#  mode='min',
#  save_best_only=True)
early_stopping_callback = EarlyStopping(
 monitor='val_loss',
 min_delta=0.005,
 patience=10,
 mode='min'
)
rlrop_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.2, mode='min', patience=3, min_lr=0.001)

# %%
epochs = 50
batch_size = 32
validation = 0.1

# %%
history = model_enc_dec.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=validation, \
                            callbacks=[early_stopping_callback, rlrop_callback])
# Out:
# Epoch 1/50
# 121/121 [==============================] - 8s 28ms/step - loss: 0.0259 - val_loss: 0.0109 - lr: 0.0010
# Epoch 2/50
# 121/121 [==============================] - 2s 21ms/step - loss: 0.0108 - val_loss: 0.0101 - lr: 0.0010
# Epoch 3/50
# 121/121 [==============================] - 3s 23ms/step - loss: 0.0104 - val_loss: 0.0099 - lr: 0.0010
# Epoch 4/50
# 121/121 [==============================] - 3s 23ms/step - loss: 0.0101 - val_loss: 0.0099 - lr: 0.0010
# Epoch 5/50
# 121/121 [==============================] - 3s 23ms/step - loss: 0.0099 - val_loss: 0.0095 - lr: 0.0010
# Epoch 6/50
# 121/121 [==============================] - 3s 22ms/step - loss: 0.0096 - val_loss: 0.0094 - lr: 0.0010
# Epoch 7/50
# 121/121 [==============================] - 3s 22ms/step - loss: 0.0083 - val_loss: 0.0071 - lr: 0.0010
# Epoch 8/50
# 121/121 [==============================] - 3s 23ms/step - loss: 0.0068 - val_loss: 0.0060 - lr: 0.0010
# Epoch 9/50
# 121/121 [==============================] - 3s 21ms/step - loss: 0.0056 - val_loss: 0.0045 - lr: 0.0010
# Epoch 10/50
# 121/121 [==============================] - 3s 23ms/step - loss: 0.0044 - val_loss: 0.0037 - lr: 0.0010
# Epoch 11/50
# 121/121 [==============================] - 3s 22ms/step - loss: 0.0038 - val_loss: 0.0036 - lr: 0.0010
# Epoch 12/50
# 121/121 [==============================] - 3s 22ms/step - loss: 0.0035 - val_loss: 0.0030 - lr: 0.0010
# Epoch 13/50
# 121/121 [==============================] - 3s 22ms/step - loss: 0.0033 - val_loss: 0.0033 - lr: 0.0010
# Epoch 14/50
# 121/121 [==============================] - 3s 22ms/step - loss: 0.0032 - val_loss: 0.0027 - lr: 0.0010
# Epoch 15/50
# 121/121 [==============================] - 3s 23ms/step - loss: 0.0031 - val_loss: 0.0025 - lr: 0.0010
# Epoch 16/50
# 121/121 [==============================] - 3s 23ms/step - loss: 0.0030 - val_loss: 0.0025 - lr: 0.0010
# Epoch 17/50
# 121/121 [==============================] - 3s 21ms/step - loss: 0.0029 - val_loss: 0.0024 - lr: 0.0010
# Epoch 18/50
# 121/121 [==============================] - 3s 22ms/step - loss: 0.0029 - val_loss: 0.0024 - lr: 0.0010
# Epoch 19/50
# 121/121 [==============================] - 4s 33ms/step - loss: 0.0028 - val_loss: 0.0023 - lr: 0.0010

# %%
yhat = model_enc_dec.predict(X_test, verbose=0)

# %%
predData, testData = inverse_transform(y_test, yhat)
evaluate_forecast(testData, predData)
# Out:
# mae: tf.Tensor(65.97659, shape=(), dtype=float32)
# mse: tf.Tensor(67042.56, shape=(), dtype=float32)
# mape: tf.Tensor(1351440800.0, shape=(), dtype=float32)

# %%
plotEvaluation(testData, predData, columns = testNormDf.columns)

# %% [markdown]
# ## CNN-LSTM Encoder-Decoder Model

# %%
tf.keras.backend.clear_session()
model_enc_dec_cnn = Sequential()

# %%
model_enc_dec_cnn.add(Conv1D(filters=64, kernel_size=9, activation='relu', input_shape=(LOOK_BACK, n_features)))
model_enc_dec_cnn.add(Conv1D(filters=64, kernel_size=11, activation='relu'))
model_enc_dec_cnn.add(MaxPooling1D(pool_size=2))
model_enc_dec_cnn.add(Flatten())
model_enc_dec_cnn.add(RepeatVector(FORECAST_RANGE))
model_enc_dec_cnn.add(LSTM(200, return_sequences=True))
model_enc_dec_cnn.add(TimeDistributed(Dense(100, activation='relu')))
model_enc_dec_cnn.add(TimeDistributed(Dense(n_features)))
model_enc_dec_cnn.compile(loss='mse', optimizer='adam')

# %%
history = model_enc_dec_cnn.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=validation, \
                            callbacks=[early_stopping_callback, rlrop_callback])
# Out:
# Epoch 1/50
# 121/121 [==============================] - 4s 14ms/step - loss: 0.0214 - val_loss: 0.0103 - lr: 0.0010
# Epoch 2/50
# 121/121 [==============================] - 1s 9ms/step - loss: 0.0091 - val_loss: 0.0075 - lr: 0.0010
# Epoch 3/50
# 121/121 [==============================] - 1s 10ms/step - loss: 0.0070 - val_loss: 0.0057 - lr: 0.0010
# Epoch 4/50
# 121/121 [==============================] - 1s 10ms/step - loss: 0.0058 - val_loss: 0.0053 - lr: 0.0010
# Epoch 5/50
# 121/121 [==============================] - 1s 10ms/step - loss: 0.0050 - val_loss: 0.0045 - lr: 0.0010
# Epoch 6/50
# 121/121 [==============================] - 1s 10ms/step - loss: 0.0046 - val_loss: 0.0045 - lr: 0.0010
# Epoch 7/50
# 121/121 [==============================] - 1s 10ms/step - loss: 0.0044 - val_loss: 0.0037 - lr: 0.0010
# Epoch 8/50
# 121/121 [==============================] - 1s 9ms/step - loss: 0.0041 - val_loss: 0.0040 - lr: 0.0010
# Epoch 9/50
# 121/121 [==============================] - 1s 9ms/step - loss: 0.0038 - val_loss: 0.0037 - lr: 0.0010
# Epoch 10/50
# 121/121 [==============================] - 1s 9ms/step - loss: 0.0037 - val_loss: 0.0031 - lr: 0.0010
# Epoch 11/50
# 121/121 [==============================] - 1s 9ms/step - loss: 0.0035 - val_loss: 0.0031 - lr: 0.0010
# Epoch 12/50
# 121/121 [==============================] - 1s 9ms/step - loss: 0.0034 - val_loss: 0.0034 - lr: 0.0010
# Epoch 13/50
# 121/121 [==============================] - 1s 9ms/step - loss: 0.0032 - val_loss: 0.0033 - lr: 0.0010
# Epoch 14/50
# 121/121 [==============================] - 1s 9ms/step - loss: 0.0032 - val_loss: 0.0039 - lr: 0.0010
# Epoch 15/50
# 121/121 [==============================] - 1s 9ms/step - loss: 0.0031 - val_loss: 0.0029 - lr: 0.0010

# %%
yhat = model_enc_dec_cnn.predict(X_test, verbose=0)

# %%
predData, testData = inverse_transform(y_test, yhat)
evaluate_forecast(testData, predData)
# Out:
# mae: tf.Tensor(101.446175, shape=(), dtype=float32)
# mse: tf.Tensor(127198.734, shape=(), dtype=float32)
# mape: tf.Tensor(1473062500.0, shape=(), dtype=float32)

# %%
plotEvaluation(testData, predData, columns = testNormDf.columns)

# %% [markdown]
# ## Model Vector Output

# %%
input_layer = Input(shape=(LOOK_BACK, n_features)) 
conv = Conv1D(filters=4, kernel_size=7, activation='relu')(input_layer)
conv = Conv1D(filters=6, kernel_size=11, activation='relu')(conv)
lstm = LSTM(100, return_sequences=True)(conv)
dropout = Dropout(0.2)(lstm)
lstm = LSTM(100)(dropout)
dense = Dense(FORECAST_RANGE*n_features, activation='relu')(lstm)
output_layer = Reshape((FORECAST_RANGE,n_features))(dense)
model_vector_output = Model([input_layer], [output_layer])
model_vector_output.compile(optimizer='adam', loss='mse')

# %%
history = model_vector_output.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=validation, \
                            callbacks=[early_stopping_callback, rlrop_callback])
# Out:
# Epoch 1/50
# 121/121 [==============================] - 6s 18ms/step - loss: 0.0490 - val_loss: 0.0249 - lr: 0.0010
# Epoch 2/50
# 121/121 [==============================] - 1s 11ms/step - loss: 0.0274 - val_loss: 0.0236 - lr: 0.0010
# Epoch 3/50
# 121/121 [==============================] - 1s 11ms/step - loss: 0.0259 - val_loss: 0.0236 - lr: 0.0010
# Epoch 4/50
# 121/121 [==============================] - 1s 11ms/step - loss: 0.0253 - val_loss: 0.0222 - lr: 0.0010
# Epoch 5/50
# 121/121 [==============================] - 1s 11ms/step - loss: 0.0237 - val_loss: 0.0207 - lr: 0.0010
# Epoch 6/50
# 121/121 [==============================] - 1s 11ms/step - loss: 0.0187 - val_loss: 0.0169 - lr: 0.0010
# Epoch 7/50
# 121/121 [==============================] - 1s 11ms/step - loss: 0.0171 - val_loss: 0.0160 - lr: 0.0010
# Epoch 8/50
# 121/121 [==============================] - 1s 11ms/step - loss: 0.0165 - val_loss: 0.0148 - lr: 0.0010
# Epoch 9/50
# 121/121 [==============================] - 1s 11ms/step - loss: 0.0156 - val_loss: 0.0148 - lr: 0.0010
# Epoch 10/50
# 121/121 [==============================] - 1s 11ms/step - loss: 0.0153 - val_loss: 0.0142 - lr: 0.0010
# Epoch 11/50
# 121/121 [==============================] - 1s 11ms/step - loss: 0.0151 - val_loss: 0.0139 - lr: 0.0010
# Epoch 12/50
# 121/121 [==============================] - 1s 11ms/step - loss: 0.0149 - val_loss: 0.0135 - lr: 0.0010
# Epoch 13/50
# 121/121 [==============================] - 1s 11ms/step - loss: 0.0146 - val_loss: 0.0133 - lr: 0.0010
# Epoch 14/50
# 121/121 [==============================] - 1s 12ms/step - loss: 0.0143 - val_loss: 0.0132 - lr: 0.0010
# Epoch 15/50
# 121/121 [==============================] - 1s 11ms/step - loss: 0.0139 - val_loss: 0.0128 - lr: 0.0010
# Epoch 16/50
# 121/121 [==============================] - 1s 11ms/step - loss: 0.0138 - val_loss: 0.0124 - lr: 0.0010

# %%
yhat = model_vector_output.predict(X_test, verbose=0)

# %%
predData, testData = inverse_transform(y_test, yhat)
evaluate_forecast(testData, predData)
# Out:
# mae: tf.Tensor(70.73833, shape=(), dtype=float32)
# mse: tf.Tensor(118319.414, shape=(), dtype=float32)
# mape: tf.Tensor(695860100.0, shape=(), dtype=float32)

# %%
plotEvaluation(testData, predData, columns = testNormDf.columns)

# %% [markdown]
# ## Multihead CNN LSTM Model

# %%
input_layer = Input(shape=(LOOK_BACK, n_features)) 
head_list = []
for i in range(0, n_features):
    conv_layer_head = Conv1D(filters=4, kernel_size=7, activation='relu')(input_layer)
    conv_layer_head_2 = Conv1D(filters=6, kernel_size=11, activation='relu')(conv_layer_head)
    conv_layer_flatten = Flatten()(conv_layer_head_2)
    head_list.append(conv_layer_flatten)

concat_cnn = Concatenate(axis=1)(head_list)
reshape = Reshape((head_list[0].shape[1], n_features))(concat_cnn)
lstm = LSTM(100)(reshape)
repeat = RepeatVector(FORECAST_RANGE)(lstm)
lstm_2 = LSTM(100, return_sequences=True)(repeat)
dropout = Dropout(0.2)(lstm_2)
dense = Dense(n_features, activation='linear')(dropout)
multi_head_cnn_lstm_model = Model(inputs=input_layer, outputs=dense)
multi_head_cnn_lstm_model.compile(optimizer='adam', loss='mse')

# %%
history = multi_head_cnn_lstm_model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=validation, \
                            callbacks=[early_stopping_callback, rlrop_callback])
# Out:
# Epoch 1/50
# 121/121 [==============================] - 10s 38ms/step - loss: 0.0371 - val_loss: 0.0127 - lr: 0.0010
# Epoch 2/50
# 121/121 [==============================] - 4s 30ms/step - loss: 0.0150 - val_loss: 0.0104 - lr: 0.0010
# Epoch 3/50
# 121/121 [==============================] - 4s 30ms/step - loss: 0.0135 - val_loss: 0.0112 - lr: 0.0010
# Epoch 4/50
# 121/121 [==============================] - 4s 30ms/step - loss: 0.0126 - val_loss: 0.0101 - lr: 0.0010
# Epoch 5/50
# 121/121 [==============================] - 4s 30ms/step - loss: 0.0119 - val_loss: 0.0095 - lr: 0.0010
# Epoch 6/50
# 121/121 [==============================] - 4s 30ms/step - loss: 0.0109 - val_loss: 0.0081 - lr: 0.0010
# Epoch 7/50
# 121/121 [==============================] - 4s 29ms/step - loss: 0.0097 - val_loss: 0.0075 - lr: 0.0010
# Epoch 8/50
# 121/121 [==============================] - 3s 29ms/step - loss: 0.0088 - val_loss: 0.0066 - lr: 0.0010
# Epoch 9/50
# 121/121 [==============================] - 3s 29ms/step - loss: 0.0080 - val_loss: 0.0059 - lr: 0.0010
# Epoch 10/50
# 121/121 [==============================] - 4s 31ms/step - loss: 0.0073 - val_loss: 0.0063 - lr: 0.0010
# Epoch 11/50
# 121/121 [==============================] - 4s 29ms/step - loss: 0.0069 - val_loss: 0.0056 - lr: 0.0010
# Epoch 12/50
# 121/121 [==============================] - 4s 29ms/step - loss: 0.0063 - val_loss: 0.0050 - lr: 0.0010
# Epoch 13/50
# 121/121 [==============================] - 3s 29ms/step - loss: 0.0060 - val_loss: 0.0045 - lr: 0.0010
# Epoch 14/50
# 121/121 [==============================] - 3s 28ms/step - loss: 0.0058 - val_loss: 0.0050 - lr: 0.0010
# Epoch 15/50
# 121/121 [==============================] - 3s 29ms/step - loss: 0.0056 - val_loss: 0.0043 - lr: 0.0010
# Epoch 16/50
# 121/121 [==============================] - 3s 29ms/step - loss: 0.0054 - val_loss: 0.0038 - lr: 0.0010
# Epoch 17/50
# 121/121 [==============================] - 3s 29ms/step - loss: 0.0052 - val_loss: 0.0040 - lr: 0.0010

# %%
yhat = multi_head_cnn_lstm_model.predict(X_test, verbose=0)

# %%
predData, testData = inverse_transform(y_test, yhat)
evaluate_forecast(testData, predData)
# Out:
# mae: tf.Tensor(112.73169, shape=(), dtype=float32)
# mse: tf.Tensor(189503.38, shape=(), dtype=float32)
# mape: tf.Tensor(975701950.0, shape=(), dtype=float32)

# %%
plotEvaluation(testData, predData, columns = testNormDf.columns)

# %% [markdown]
# ## Ploting The Evaluation

# %%
y_test_inverse_time_step  = testData.reshape(int(testData.shape[0]/FORECAST_RANGE), \
                                                  FORECAST_RANGE, testData.shape[-1])
yhat_inverse_time_step = predData.reshape(int(predData.shape[0]/FORECAST_RANGE), \
                                              FORECAST_RANGE, predData.shape[-1])
# yhat_inverse_time_step and y_test_inverse_time_step are both same dimension.
time_step_list_yhat = [[] for i in range(FORECAST_RANGE)]
time_step_list_y_test = [[] for i in range(FORECAST_RANGE)]
for i in range(0, yhat_inverse_time_step.shape[0]):
    for j in range(0, yhat_inverse_time_step.shape[1]):
        time_step_list_yhat[j].append(list(yhat_inverse_time_step[i][j]))
        time_step_list_y_test[j].append(list(y_test_inverse_time_step[i][j]))
yhat_time_step = np.array(time_step_list_yhat)
yhat_time_step = yhat_time_step.reshape(yhat_time_step.shape[0], -1)
y_test_time_step = np.array(time_step_list_y_test)
y_test_time_step = y_test_time_step.reshape(y_test_time_step.shape[0], -1)
# plotting
mape_list = []
for i in range(0, FORECAST_RANGE):
    mape = mape_(y_test_time_step[i], yhat_time_step[i])
    mape_list.append(mape)
plt.plot(range(0, FORECAST_RANGE), mape_list, marker='o')
plt.xticks((range(0, FORECAST_RANGE)))
plt.xlabel('Forecast Range')
plt.ylabel('MAPE')
# Out:
# Text(0, 0.5, 'MAPE')

# %%
for i in range(0, n_features):
    print('->', i)
    mae = mae_(y_test_inverse[:,i],yhat_inverse[:,i])
    print('mae:', mae)
    mse = mse_(y_test_inverse[:,i],yhat_inverse[:,i])
    print('mse:', mse)
    mape = mape_(y_test_inverse[:,i],yhat_inverse[:,i])
    print('mape:', mape)
# Out:
# -> 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [61], line 3
#       1 for i in range(0, n_features):
#       2     print('->', i)
# ----> 3     mae = mae_(y_test_inverse[:,i],yhat_inverse[:,i])
#       4     print('mae:', mae)
#       5     mse = mse_(y_test_inverse[:,i],yhat_inverse[:,i])
#
# NameError: name 'y_test_inverse' is not defined
