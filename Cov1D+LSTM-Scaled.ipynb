# %% [markdown]
# # The Packages

# %%
import numpy as np
import pandas as pd
import os
import gc
import datetime
import warnings

# %%
import statsmodels.api as sm
from datetime import date

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
import tensorflow as tf
import math 
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LSTM
from tensorflow.keras import losses
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.utils import plot_model

# %%
tf.__version__
# Out:
# '2.10.1'

# %%
# DATA VISUALIZATION
# ------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (20.0, 10.0)
sns.set_style("darkgrid")
sns.color_palette("mako", as_cmap=True)
import plotly.express as px

# %%
# CONFIGURATIONS
# ------------------------------------------------------
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.2f}'.format
warnings.filterwarnings('ignore')

# %% [markdown]
# # Utility Functions

# %%
def plotSeries(time, series, lab,form='-'):
    plt.plot(time, series, form, label=lab)
    plt.xlabel("Date")
    plt.ylabel("Close Price")
    plt.grid(True)

# %% [markdown]
# # The Data

# %%
wfc = pd.read_csv('Dataset/WFC Daily1.csv')

# %%
wfc.head()
# Out:
#          Date  Open  High   Low  Close  Adj Close    Volume
# 0  2000-01-03 20.16 20.19 19.00  19.56      10.44   9037000
# 1  2000-01-04 18.62 18.84 18.00  18.59       9.92  15237200
# 2  2000-01-05 18.50 18.88 18.03  18.41       9.82   8228200
# 3  2000-01-06 18.53 19.50 18.47  19.22      10.25   8326800
# 4  2000-01-07 19.62 19.84 19.28  19.56      10.44   7711200

# %%
wfc.Date.dtype
# Out:
# dtype('O')

# %%
wfc['Date'] = pd.to_datetime(wfc['Date'])
#wfc.set_index(['Date'],inplace=True)

# %%
wfc.head()
# Out:
#         Date  Open  High   Low  Close  Adj Close    Volume
# 0 2000-01-03 20.16 20.19 19.00  19.56      10.44   9037000
# 1 2000-01-04 18.62 18.84 18.00  18.59       9.92  15237200
# 2 2000-01-05 18.50 18.88 18.03  18.41       9.82   8228200
# 3 2000-01-06 18.53 19.50 18.47  19.22      10.25   8326800
# 4 2000-01-07 19.62 19.84 19.28  19.56      10.44   7711200

# %%
wfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5754 entries, 0 to 5753
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5754 non-null   datetime64[ns]
#  1   Open       5754 non-null   float64
#  2   High       5754 non-null   float64
#  3   Low        5754 non-null   float64
#  4   Close      5754 non-null   float64
#  5   Adj Close  5754 non-null   float64
#  6   Volume     5754 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 314.8 KB

# %%
wfc.describe()
# Out:
#          Open    High     Low   Close  Adj Close       Volume
# count 5754.00 5754.00 5754.00 5754.00    5754.00      5754.00
# mean    36.38   36.78   35.98   36.38      28.01  24313450.19
# std     11.74   11.77   11.73   11.75      12.85  26705062.78
# min      8.65    8.94    7.80    8.12       5.76   1774000.00
# 25%     26.71   27.20   26.25   26.74      18.01  10091200.00
# 50%     32.65   33.13   32.25   32.64      23.18  17086600.00
# 75%     47.75   48.19   47.33   47.79      41.58  29145250.00
# max     65.89   66.31   65.66   65.93      57.96 478736600.00

# %%
correlation = wfc.corr ()  
correlation. style.background_gradient ()
# Out:
# <style type="text/css">
# #T_9458b_row0_col0, #T_9458b_row0_col1, #T_9458b_row0_col2, #T_9458b_row0_col3, #T_9458b_row1_col0, #T_9458b_row1_col1, #T_9458b_row1_col2, #T_9458b_row1_col3, #T_9458b_row2_col0, #T_9458b_row2_col1, #T_9458b_row2_col2, #T_9458b_row2_col3, #T_9458b_row3_col0, #T_9458b_row3_col1, #T_9458b_row3_col2, #T_9458b_row3_col3, #T_9458b_row4_col4, #T_9458b_row5_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9458b_row0_col4, #T_9458b_row2_col4, #T_9458b_row3_col4 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_9458b_row0_col5, #T_9458b_row3_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_9458b_row1_col4, #T_9458b_row4_col0, #T_9458b_row4_col1, #T_9458b_row4_col2, #T_9458b_row4_col3 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_9458b_row1_col5 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_9458b_row2_col5, #T_9458b_row5_col0, #T_9458b_row5_col1, #T_9458b_row5_col2, #T_9458b_row5_col3, #T_9458b_row5_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_9458b_row4_col5 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# </style>
# <table id="T_9458b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9458b_level0_col0" class="col_heading level0 col0" >Open</th>
#       <th id="T_9458b_level0_col1" class="col_heading level0 col1" >High</th>
#       <th id="T_9458b_level0_col2" class="col_heading level0 col2" >Low</th>
#       <th id="T_9458b_level0_col3" class="col_heading level0 col3" >Close</th>
#       <th id="T_9458b_level0_col4" class="col_heading level0 col4" >Adj Close</th>
#       <th id="T_9458b_level0_col5" class="col_heading level0 col5" >Volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9458b_level0_row0" class="row_heading level0 row0" >Open</th>
#       <td id="T_9458b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_9458b_row0_col1" class="data row0 col1" >0.999324</td>
#       <td id="T_9458b_row0_col2" class="data row0 col2" >0.999274</td>
#       <td id="T_9458b_row0_col3" class="data row0 col3" >0.998754</td>
#       <td id="T_9458b_row0_col4" class="data row0 col4" >0.965403</td>
#       <td id="T_9458b_row0_col5" class="data row0 col5" >-0.184389</td>
#     </tr>
#     <tr>
#       <th id="T_9458b_level0_row1" class="row_heading level0 row1" >High</th>
#       <td id="T_9458b_row1_col0" class="data row1 col0" >0.999324</td>
#       <td id="T_9458b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_9458b_row1_col2" class="data row1 col2" >0.998796</td>
#       <td id="T_9458b_row1_col3" class="data row1 col3" >0.999323</td>
#       <td id="T_9458b_row1_col4" class="data row1 col4" >0.967945</td>
#       <td id="T_9458b_row1_col5" class="data row1 col5" >-0.169457</td>
#     </tr>
#     <tr>
#       <th id="T_9458b_level0_row2" class="row_heading level0 row2" >Low</th>
#       <td id="T_9458b_row2_col0" class="data row2 col0" >0.999274</td>
#       <td id="T_9458b_row2_col1" class="data row2 col1" >0.998796</td>
#       <td id="T_9458b_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_9458b_row2_col3" class="data row2 col3" >0.999303</td>
#       <td id="T_9458b_row2_col4" class="data row2 col4" >0.963519</td>
#       <td id="T_9458b_row2_col5" class="data row2 col5" >-0.199335</td>
#     </tr>
#     <tr>
#       <th id="T_9458b_level0_row3" class="row_heading level0 row3" >Close</th>
#       <td id="T_9458b_row3_col0" class="data row3 col0" >0.998754</td>
#       <td id="T_9458b_row3_col1" class="data row3 col1" >0.999323</td>
#       <td id="T_9458b_row3_col2" class="data row3 col2" >0.999303</td>
#       <td id="T_9458b_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_9458b_row3_col4" class="data row3 col4" >0.966149</td>
#       <td id="T_9458b_row3_col5" class="data row3 col5" >-0.183272</td>
#     </tr>
#     <tr>
#       <th id="T_9458b_level0_row4" class="row_heading level0 row4" >Adj Close</th>
#       <td id="T_9458b_row4_col0" class="data row4 col0" >0.965403</td>
#       <td id="T_9458b_row4_col1" class="data row4 col1" >0.967945</td>
#       <td id="T_9458b_row4_col2" class="data row4 col2" >0.963519</td>
#       <td id="T_9458b_row4_col3" class="data row4 col3" >0.966149</td>
#       <td id="T_9458b_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_9458b_row4_col5" class="data row4 col5" >-0.080189</td>
#     </tr>
#     <tr>
#       <th id="T_9458b_level0_row5" class="row_heading level0 row5" >Volume</th>
#       <td id="T_9458b_row5_col0" class="data row5 col0" >-0.184389</td>
#       <td id="T_9458b_row5_col1" class="data row5 col1" >-0.169457</td>
#       <td id="T_9458b_row5_col2" class="data row5 col2" >-0.199335</td>
#       <td id="T_9458b_row5_col3" class="data row5 col3" >-0.183272</td>
#       <td id="T_9458b_row5_col4" class="data row5 col4" >-0.080189</td>
#       <td id="T_9458b_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # The Split

# %%
min_date = wfc.Date.min()
max_date = wfc.Date.max()
print("Min:", min_date, "Max:", max_date)
# Out:
# Min: 2000-01-03 00:00:00 Max: 2022-11-11 00:00:00

# %%
train_percent = .75
valid_percent = .12

time_between = max_date - min_date

train_cutoff = min_date + train_percent*time_between
valid_cutoff = min_date + (train_percent + valid_percent)*time_between

print("Training Cutoff Date: {:s}".format(str(train_cutoff)))
print("Validation Cutoff Date: {:s}".format(str(valid_cutoff)))
# Out:
# Training Cutoff Date: 2017-02-23 00:00:00
# Validation Cutoff Date: 2019-11-21 18:14:24

# %%
train_df = wfc[wfc.Date <= train_cutoff]
valid_df = wfc[(wfc.Date > train_cutoff) & (wfc.Date <= valid_cutoff)]
test_df = wfc[wfc.Date > valid_cutoff]

# %%
print("Dataset shape: {:s}".format(str(wfc.shape)))
print("Train dataset shape: {:s}".format(str(train_df.shape)))
print("Vaid dataset shape: {:s}".format(str(valid_df.shape)))
print("Test dataset shape: {:s}".format(str(test_df.shape)))
# Out:
# Dataset shape: (5754, 7)
# Train dataset shape: (4313, 7)
# Vaid dataset shape: (692, 7)
# Test dataset shape: (749, 7)

# %% [markdown]
# # Stock Price Graph

# %%
plotSeries(train_df.Date, train_df.Close, "Training Data")
plotSeries(valid_df.Date, valid_df.Close, "Validation Data")
plotSeries(test_df.Date, test_df.Close, "Test Data")
plt.legend(loc='upper left')

# %%
train_df.set_index(['Date'],inplace=True)
test_df.set_index(['Date'],inplace=True)
valid_df.set_index(['Date'],inplace=True)

# %%
scaler = MinMaxScaler()

trainNorm = scaler.fit_transform(train_df.Close.values.reshape(-1, 1))
testNorm = scaler.transform(test_df.Close.values.reshape(-1, 1))
validNorm = scaler.transform(valid_df.Close.values.reshape(-1, 1))

# %%
trainNorm.shape
# Out:
# (4313, 1)

# %% [markdown]
# ## Windowed Dataset

# %%
mse_arr=[]
Z = []

window = 4

# %%
X_train= []
Y_train=[]
X_valid= []
Y_valid=[]
X_test= []
Y_test=[]

for i in range(len(trainNorm) - (window)):
    X_train.append(trainNorm[i:i+window])
    Y_train.append(trainNorm[i+window])
    
for i in range(len(validNorm) - (window)):
    X_valid.append(validNorm[i:i+window])
    Y_valid.append(validNorm[i+window])
    
for i in range(len(testNorm) - (window)):
    X_test.append(testNorm[i:i+window])
    Y_test.append(testNorm[i+window])
    

X_train=np.asanyarray(X_train)
Y_train=np.asanyarray(Y_train)
X_valid=np.asanyarray(X_valid)
Y_valid=np.asanyarray(Y_valid)
X_test=np.asanyarray(X_test)
Y_test=np.asanyarray(Y_test)

Xtrain = X_train[:,:,:]  
Ytrain = Y_train[:]  
Xvalid = X_valid[:,:,:]  
Yvalid= Y_valid[:]  
Xtest = X_test[:,:,:]  
Ytest= Y_test[:]

# %% [markdown]
# # Model Building

# %%
tf.keras.backend.clear_session()
model = tf.keras.Sequential()

# %%
model.add(keras.layers.Conv1D(filters=32, kernel_size = 5,
                           strides=1, padding="causal",
                           activation="relu",
                           input_shape=[window, 1]),)
model.add(keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)))
model.add(keras.layers.Bidirectional(tf.keras.layers.LSTM(32)))
model.add(keras.layers.Dense(1))

# %% [markdown]
# ## Final Model Build

# %%
tf.keras.backend.clear_session()

# %%
model.compile(loss=tf.keras.losses.MeanSquaredError(),
              optimizer=Adam(1e-3),
              metrics=['mae'])

# %%
log_dir = "logs\\" + datetime.datetime.now().strftime("%d-%m-%Y_%H%M%S")

tensorboard_callback = [
#                         tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1),
#                         ModelCheckpoint(model_path, verbose=1, save_best_only=True),
#                         ReduceLROnPlateau(monitor= "val_mae", factor=0.1, patience=5, min_lr=1e-7, verbose=1),
                        ReduceLROnPlateau(monitor='val_mae', factor=0.3,patience=5, min_lr=1e-6, verbose=1),
#                         CSVLogger(csv_path),
                        TensorBoard(),
                        EarlyStopping(monitor= "val_mae", patience=10, restore_best_weights=True)
                       ]

# %%
history = model.fit(Xtrain, Ytrain,batch_size=128, epochs=500, verbose=1,validation_data=(Xvalid, Yvalid), callbacks=tensorboard_callback)
# Out:
# Epoch 1/500
# 34/34 [==============================] - 17s 99ms/step - loss: 0.0761 - mae: 0.2027 - val_loss: 0.0572 - val_mae: 0.2349 - lr: 0.0010
# Epoch 2/500
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0055 - mae: 0.0575 - val_loss: 0.0047 - val_mae: 0.0648 - lr: 0.0010
# Epoch 3/500
# 34/34 [==============================] - 1s 17ms/step - loss: 6.2543e-04 - mae: 0.0181 - val_loss: 9.2778e-04 - val_mae: 0.0231 - lr: 0.0010
# Epoch 4/500
# 34/34 [==============================] - 1s 17ms/step - loss: 3.4128e-04 - mae: 0.0125 - val_loss: 5.4437e-04 - val_mae: 0.0168 - lr: 0.0010
# Epoch 5/500
# 34/34 [==============================] - 1s 16ms/step - loss: 3.2725e-04 - mae: 0.0121 - val_loss: 5.6821e-04 - val_mae: 0.0172 - lr: 0.0010
# Epoch 6/500
# 34/34 [==============================] - 1s 17ms/step - loss: 3.2621e-04 - mae: 0.0121 - val_loss: 5.2758e-04 - val_mae: 0.0165 - lr: 0.0010
# Epoch 7/500
# 34/34 [==============================] - 1s 16ms/step - loss: 3.2288e-04 - mae: 0.0120 - val_loss: 5.0500e-04 - val_mae: 0.0162 - lr: 0.0010
# Epoch 8/500
# 34/34 [==============================] - 1s 17ms/step - loss: 3.1624e-04 - mae: 0.0118 - val_loss: 4.9447e-04 - val_mae: 0.0161 - lr: 0.0010
# Epoch 9/500
# 34/34 [==============================] - 1s 16ms/step - loss: 3.1982e-04 - mae: 0.0120 - val_loss: 5.0848e-04 - val_mae: 0.0162 - lr: 0.0010
# Epoch 10/500
# 34/34 [==============================] - 1s 16ms/step - loss: 3.1905e-04 - mae: 0.0120 - val_loss: 5.4771e-04 - val_mae: 0.0169 - lr: 0.0010
# Epoch 11/500
# 34/34 [==============================] - 1s 17ms/step - loss: 3.1442e-04 - mae: 0.0119 - val_loss: 4.8920e-04 - val_mae: 0.0159 - lr: 0.0010
# Epoch 12/500
# 34/34 [==============================] - 1s 15ms/step - loss: 3.0912e-04 - mae: 0.0117 - val_loss: 4.7283e-04 - val_mae: 0.0157 - lr: 0.0010
# Epoch 13/500
# 34/34 [==============================] - 1s 15ms/step - loss: 3.0518e-04 - mae: 0.0117 - val_loss: 4.6575e-04 - val_mae: 0.0158 - lr: 0.0010
# Epoch 14/500
# 34/34 [==============================] - 1s 15ms/step - loss: 3.0766e-04 - mae: 0.0118 - val_loss: 5.3457e-04 - val_mae: 0.0167 - lr: 0.0010
# Epoch 15/500
# 34/34 [==============================] - 1s 15ms/step - loss: 3.0028e-04 - mae: 0.0116 - val_loss: 4.5947e-04 - val_mae: 0.0155 - lr: 0.0010
# Epoch 16/500
# 34/34 [==============================] - 1s 15ms/step - loss: 3.0608e-04 - mae: 0.0118 - val_loss: 4.9033e-04 - val_mae: 0.0159 - lr: 0.0010
# Epoch 17/500
# 34/34 [==============================] - 1s 16ms/step - loss: 2.9722e-04 - mae: 0.0115 - val_loss: 4.5575e-04 - val_mae: 0.0154 - lr: 0.0010
# Epoch 18/500
# 34/34 [==============================] - 1s 16ms/step - loss: 2.9109e-04 - mae: 0.0113 - val_loss: 4.9351e-04 - val_mae: 0.0161 - lr: 0.0010
# Epoch 19/500
# 34/34 [==============================] - 1s 16ms/step - loss: 2.9203e-04 - mae: 0.0114 - val_loss: 4.3048e-04 - val_mae: 0.0150 - lr: 0.0010
# Epoch 20/500
# 34/34 [==============================] - 1s 16ms/step - loss: 2.8296e-04 - mae: 0.0112 - val_loss: 4.1733e-04 - val_mae: 0.0150 - lr: 0.0010
# Epoch 21/500
# 34/34 [==============================] - 1s 17ms/step - loss: 2.8012e-04 - mae: 0.0111 - val_loss: 4.2221e-04 - val_mae: 0.0148 - lr: 0.0010
# Epoch 22/500
# 34/34 [==============================] - 1s 17ms/step - loss: 2.7940e-04 - mae: 0.0112 - val_loss: 4.1652e-04 - val_mae: 0.0147 - lr: 0.0010
# Epoch 23/500
# 34/34 [==============================] - 1s 17ms/step - loss: 2.7609e-04 - mae: 0.0111 - val_loss: 3.9262e-04 - val_mae: 0.0145 - lr: 0.0010
# Epoch 24/500
# 34/34 [==============================] - 1s 16ms/step - loss: 2.6963e-04 - mae: 0.0109 - val_loss: 4.6919e-04 - val_mae: 0.0158 - lr: 0.0010
# Epoch 25/500
# 34/34 [==============================] - 1s 15ms/step - loss: 2.7047e-04 - mae: 0.0110 - val_loss: 3.9651e-04 - val_mae: 0.0150 - lr: 0.0010
# Epoch 26/500
# 34/34 [==============================] - 0s 14ms/step - loss: 2.6935e-04 - mae: 0.0110 - val_loss: 3.8238e-04 - val_mae: 0.0141 - lr: 0.0010
# Epoch 27/500
# 34/34 [==============================] - 0s 15ms/step - loss: 2.5843e-04 - mae: 0.0107 - val_loss: 3.6408e-04 - val_mae: 0.0138 - lr: 0.0010
# Epoch 28/500
# 34/34 [==============================] - 0s 15ms/step - loss: 2.6074e-04 - mae: 0.0108 - val_loss: 4.0826e-04 - val_mae: 0.0147 - lr: 0.0010
# Epoch 29/500
# 34/34 [==============================] - 1s 15ms/step - loss: 2.5358e-04 - mae: 0.0107 - val_loss: 3.7131e-04 - val_mae: 0.0139 - lr: 0.0010
# Epoch 30/500
# 34/34 [==============================] - 1s 15ms/step - loss: 2.5155e-04 - mae: 0.0105 - val_loss: 3.2991e-04 - val_mae: 0.0131 - lr: 0.0010
# Epoch 31/500
# 34/34 [==============================] - 0s 14ms/step - loss: 2.4211e-04 - mae: 0.0104 - val_loss: 3.8575e-04 - val_mae: 0.0144 - lr: 0.0010
# Epoch 32/500
# 34/34 [==============================] - 1s 15ms/step - loss: 2.4636e-04 - mae: 0.0106 - val_loss: 3.1634e-04 - val_mae: 0.0128 - lr: 0.0010
# Epoch 33/500
# 34/34 [==============================] - 1s 15ms/step - loss: 2.3249e-04 - mae: 0.0101 - val_loss: 2.9470e-04 - val_mae: 0.0126 - lr: 0.0010
# Epoch 34/500
# 34/34 [==============================] - 1s 16ms/step - loss: 2.3171e-04 - mae: 0.0102 - val_loss: 3.1289e-04 - val_mae: 0.0134 - lr: 0.0010
# Epoch 35/500
# 34/34 [==============================] - 1s 16ms/step - loss: 2.2434e-04 - mae: 0.0100 - val_loss: 2.8284e-04 - val_mae: 0.0125 - lr: 0.0010
# Epoch 36/500
# 34/34 [==============================] - 1s 15ms/step - loss: 2.1510e-04 - mae: 0.0097 - val_loss: 2.6106e-04 - val_mae: 0.0119 - lr: 0.0010
# Epoch 37/500
# 34/34 [==============================] - 0s 14ms/step - loss: 2.0956e-04 - mae: 0.0095 - val_loss: 2.4257e-04 - val_mae: 0.0113 - lr: 0.0010
# Epoch 38/500
# 34/34 [==============================] - 0s 14ms/step - loss: 2.0953e-04 - mae: 0.0096 - val_loss: 2.8291e-04 - val_mae: 0.0124 - lr: 0.0010
# Epoch 39/500
# 34/34 [==============================] - 0s 14ms/step - loss: 1.9989e-04 - mae: 0.0093 - val_loss: 2.5183e-04 - val_mae: 0.0116 - lr: 0.0010
# Epoch 40/500
# 34/34 [==============================] - 1s 15ms/step - loss: 2.0387e-04 - mae: 0.0095 - val_loss: 2.5823e-04 - val_mae: 0.0118 - lr: 0.0010
# Epoch 41/500
# 34/34 [==============================] - 1s 16ms/step - loss: 2.1144e-04 - mae: 0.0098 - val_loss: 2.7152e-04 - val_mae: 0.0129 - lr: 0.0010
# Epoch 42/500
# 31/34 [==========================>...] - ETA: 0s - loss: 2.1511e-04 - mae: 0.0100
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 34/34 [==============================] - 1s 16ms/step - loss: 2.1771e-04 - mae: 0.0102 - val_loss: 2.6012e-04 - val_mae: 0.0125 - lr: 0.0010
# Epoch 43/500
# 34/34 [==============================] - 1s 16ms/step - loss: 1.8938e-04 - mae: 0.0090 - val_loss: 2.0644e-04 - val_mae: 0.0104 - lr: 3.0000e-04
# Epoch 44/500
# 34/34 [==============================] - 1s 16ms/step - loss: 1.8694e-04 - mae: 0.0089 - val_loss: 2.1022e-04 - val_mae: 0.0105 - lr: 3.0000e-04
# Epoch 45/500
# 34/34 [==============================] - 1s 15ms/step - loss: 1.8940e-04 - mae: 0.0090 - val_loss: 2.4238e-04 - val_mae: 0.0115 - lr: 3.0000e-04
# Epoch 46/500
# 34/34 [==============================] - 1s 15ms/step - loss: 1.8651e-04 - mae: 0.0089 - val_loss: 2.0215e-04 - val_mae: 0.0103 - lr: 3.0000e-04
# Epoch 47/500
# 34/34 [==============================] - 0s 15ms/step - loss: 1.8465e-04 - mae: 0.0088 - val_loss: 2.0190e-04 - val_mae: 0.0103 - lr: 3.0000e-04
# Epoch 48/500
# 34/34 [==============================] - 1s 15ms/step - loss: 1.8379e-04 - mae: 0.0088 - val_loss: 1.9999e-04 - val_mae: 0.0103 - lr: 3.0000e-04
# Epoch 49/500
# 34/34 [==============================] - 1s 15ms/step - loss: 1.9251e-04 - mae: 0.0091 - val_loss: 2.3212e-04 - val_mae: 0.0116 - lr: 3.0000e-04
# Epoch 50/500
# 34/34 [==============================] - 1s 16ms/step - loss: 1.8390e-04 - mae: 0.0088 - val_loss: 2.2528e-04 - val_mae: 0.0111 - lr: 3.0000e-04
# Epoch 51/500
# 34/34 [==============================] - ETA: 0s - loss: 1.8933e-04 - mae: 0.0091
# Epoch 51: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 34/34 [==============================] - 1s 16ms/step - loss: 1.8933e-04 - mae: 0.0091 - val_loss: 2.0243e-04 - val_mae: 0.0104 - lr: 3.0000e-04
# Epoch 52/500
# 34/34 [==============================] - 1s 16ms/step - loss: 1.8260e-04 - mae: 0.0088 - val_loss: 1.9977e-04 - val_mae: 0.0103 - lr: 9.0000e-05
# Epoch 53/500
# 34/34 [==============================] - 1s 16ms/step - loss: 1.8234e-04 - mae: 0.0087 - val_loss: 1.9677e-04 - val_mae: 0.0102 - lr: 9.0000e-05
# Epoch 54/500
# 34/34 [==============================] - 1s 16ms/step - loss: 1.8100e-04 - mae: 0.0087 - val_loss: 2.0008e-04 - val_mae: 0.0103 - lr: 9.0000e-05
# Epoch 55/500
# 34/34 [==============================] - 1s 16ms/step - loss: 1.8096e-04 - mae: 0.0087 - val_loss: 1.9914e-04 - val_mae: 0.0103 - lr: 9.0000e-05
# Epoch 56/500
# 34/34 [==============================] - 1s 16ms/step - loss: 1.8217e-04 - mae: 0.0088 - val_loss: 1.9971e-04 - val_mae: 0.0103 - lr: 9.0000e-05
# Epoch 57/500
# 34/34 [==============================] - 1s 16ms/step - loss: 1.8121e-04 - mae: 0.0087 - val_loss: 2.1057e-04 - val_mae: 0.0108 - lr: 9.0000e-05
# Epoch 58/500
# 31/34 [==========================>...] - ETA: 0s - loss: 1.7860e-04 - mae: 0.0087
# Epoch 58: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 34/34 [==============================] - 1s 15ms/step - loss: 1.8086e-04 - mae: 0.0087 - val_loss: 1.9571e-04 - val_mae: 0.0102 - lr: 9.0000e-05
# Epoch 59/500
# 34/34 [==============================] - 0s 15ms/step - loss: 1.8019e-04 - mae: 0.0087 - val_loss: 1.9621e-04 - val_mae: 0.0102 - lr: 2.7000e-05
# Epoch 60/500
# 34/34 [==============================] - 0s 14ms/step - loss: 1.8024e-04 - mae: 0.0087 - val_loss: 1.9516e-04 - val_mae: 0.0102 - lr: 2.7000e-05
# Epoch 61/500
# 34/34 [==============================] - 0s 15ms/step - loss: 1.7983e-04 - mae: 0.0087 - val_loss: 1.9504e-04 - val_mae: 0.0102 - lr: 2.7000e-05
# Epoch 62/500
# 34/34 [==============================] - 1s 16ms/step - loss: 1.7988e-04 - mae: 0.0087 - val_loss: 1.9501e-04 - val_mae: 0.0102 - lr: 2.7000e-05
# Epoch 63/500
# 34/34 [==============================] - ETA: 0s - loss: 1.7989e-04 - mae: 0.0087
# Epoch 63: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 34/34 [==============================] - 1s 16ms/step - loss: 1.7989e-04 - mae: 0.0087 - val_loss: 1.9603e-04 - val_mae: 0.0102 - lr: 2.7000e-05
# Epoch 64/500
# 34/34 [==============================] - 0s 14ms/step - loss: 1.7990e-04 - mae: 0.0087 - val_loss: 1.9505e-04 - val_mae: 0.0102 - lr: 8.1000e-06
# Epoch 65/500
# 34/34 [==============================] - 1s 15ms/step - loss: 1.7971e-04 - mae: 0.0086 - val_loss: 1.9493e-04 - val_mae: 0.0102 - lr: 8.1000e-06
# Epoch 66/500
# 34/34 [==============================] - 0s 15ms/step - loss: 1.7961e-04 - mae: 0.0086 - val_loss: 1.9523e-04 - val_mae: 0.0102 - lr: 8.1000e-06
# Epoch 67/500
# 34/34 [==============================] - 0s 14ms/step - loss: 1.7974e-04 - mae: 0.0086 - val_loss: 1.9498e-04 - val_mae: 0.0102 - lr: 8.1000e-06
# Epoch 68/500
# 33/34 [============================>.] - ETA: 0s - loss: 1.8070e-04 - mae: 0.0087
# Epoch 68: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 34/34 [==============================] - 1s 16ms/step - loss: 1.7958e-04 - mae: 0.0086 - val_loss: 1.9494e-04 - val_mae: 0.0102 - lr: 8.1000e-06
# Epoch 69/500
# 34/34 [==============================] - 1s 16ms/step - loss: 1.7954e-04 - mae: 0.0086 - val_loss: 1.9477e-04 - val_mae: 0.0101 - lr: 2.4300e-06
# Epoch 70/500
# 34/34 [==============================] - 1s 15ms/step - loss: 1.7953e-04 - mae: 0.0086 - val_loss: 1.9482e-04 - val_mae: 0.0101 - lr: 2.4300e-06
# Epoch 71/500
# 34/34 [==============================] - 0s 15ms/step - loss: 1.7950e-04 - mae: 0.0086 - val_loss: 1.9475e-04 - val_mae: 0.0101 - lr: 2.4300e-06
# Epoch 72/500
# 34/34 [==============================] - 0s 14ms/step - loss: 1.7950e-04 - mae: 0.0086 - val_loss: 1.9477e-04 - val_mae: 0.0101 - lr: 2.4300e-06
# Epoch 73/500
# 34/34 [==============================] - ETA: 0s - loss: 1.7953e-04 - mae: 0.0086
# Epoch 73: ReduceLROnPlateau reducing learning rate to 1e-06.
# 34/34 [==============================] - 0s 14ms/step - loss: 1.7953e-04 - mae: 0.0086 - val_loss: 1.9477e-04 - val_mae: 0.0101 - lr: 2.4300e-06
# Epoch 74/500
# 34/34 [==============================] - 1s 15ms/step - loss: 1.7949e-04 - mae: 0.0086 - val_loss: 1.9475e-04 - val_mae: 0.0101 - lr: 1.0000e-06
# Epoch 75/500
# 34/34 [==============================] - 0s 15ms/step - loss: 1.7948e-04 - mae: 0.0086 - val_loss: 1.9476e-04 - val_mae: 0.0101 - lr: 1.0000e-06
# Epoch 76/500
# 34/34 [==============================] - 0s 14ms/step - loss: 1.7948e-04 - mae: 0.0086 - val_loss: 1.9475e-04 - val_mae: 0.0101 - lr: 1.0000e-06
# Epoch 77/500
# 34/34 [==============================] - 0s 15ms/step - loss: 1.7951e-04 - mae: 0.0086 - val_loss: 1.9475e-04 - val_mae: 0.0101 - lr: 1.0000e-06
# Epoch 78/500
# 34/34 [==============================] - 0s 15ms/step - loss: 1.7952e-04 - mae: 0.0086 - val_loss: 1.9475e-04 - val_mae: 0.0101 - lr: 1.0000e-06
# Epoch 79/500
# 34/34 [==============================] - 1s 16ms/step - loss: 1.7949e-04 - mae: 0.0086 - val_loss: 1.9475e-04 - val_mae: 0.0101 - lr: 1.0000e-06

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 4, 32)             192
#
#  bidirectional (Bidirectiona  (None, 4, 64)            16640
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 64)               24832
#  nal)
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 41,729
# Trainable params: 41,729
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Showing training and validation loss
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
loss_values50 = loss_values[0:150]
val_loss_values50 = val_loss_values[0:150]
epochs = range(1, len(loss_values50) + 1)
plt.plot(epochs, loss_values50, label='Training Loss')
plt.plot(epochs, val_loss_values50, label='Validation Loss')
plt.rc('font', size = 14)
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.xticks(epochs)
plt.xticks(np.arange(min(epochs), max(epochs)+1, 50.0))
#fig.savefig('test&validationlosscnn.png', dpi=300)
plt.show()

# %%
loss_values = history_dict['mae']
val_loss_values = history_dict['val_mae']
loss_values50 = loss_values[0:150]
val_loss_values50 = val_loss_values[0:150]
epochs = range(1, len(loss_values50) + 1)
plt.plot(epochs, loss_values50, label='Training MAE')
plt.plot(epochs, val_loss_values50, label='Validation MAE')
plt.rc('font', size = 14)
plt.title('Training and Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.xticks(epochs)
plt.xticks(np.arange(min(epochs), max(epochs)+1, 50.0))
#fig.savefig('test&validationlosscnn.png', dpi=300)
plt.show()

# %%
#Evaluating model
trainScore = model.evaluate(Xtrain, Ytrain, verbose=1)
validScore = model.evaluate(Xvalid, Yvalid, verbose=1)
testScore = model.evaluate(Xtest, Ytest, verbose=1)
# Out:
# 135/135 [==============================] - 1s 6ms/step - loss: 1.7949e-04 - mae: 0.0086
# 22/22 [==============================] - 0s 6ms/step - loss: 1.9477e-04 - mae: 0.0101
# 24/24 [==============================] - 0s 6ms/step - loss: 4.3694e-04 - mae: 0.0153

# %%
testScore, validScore, trainScore
# Out:
# ([0.00043694497435353696, 0.015297616831958294],
#  [0.00019477156456559896, 0.010146106593310833],
#  [0.00017949369794223458, 0.00863912794739008])

# %%
preds = model.predict(Xtest)
# Out:
# 24/24 [==============================] - 2s 8ms/step

# %%
Xtest.shape
# Out:
# (745, 4, 1)

# %%
plt.title('MAE: {}'.format(testScore[1]))
plt.plot(Ytest, label='Real')
plt.plot(preds, label='Prediction')

plt.legend(loc="best")

#for saving figures
# plt.savefig('CPALL_graph.png')
plt.show()

# %%
#Show Train and Test Scores
print('Train MSE \t Train RMSE \t Train MAE \t Testscore RMSE \tTest MSE \tTest MAE')
print('%.9f \t %.9f \t %.9f \t %.9f \t \t %.9f \t %.9f' % (trainScore[0], math.sqrt(trainScore[0]),trainScore[1],math.sqrt(testScore[0]),testScore[0],testScore[1]))
# Out:
# Train MSE 	 Train RMSE 	 Train MAE 	 Testscore RMSE 	Test MSE 	Test MAE
# 0.000179494 	 0.013397526 	 0.008639128 	 0.020903229 	 	 0.000436945 	 0.015297617

# %%
#denormalizing datasets
preds = scaler.inverse_transform(preds)
Ytest = scaler.inverse_transform(Ytest)

# %%
print('MAE \t\t MAPE')
print('%.4f \t\t %.4f' % (mean_absolute_error(Ytest,preds),(np.mean(np.abs((Ytest - preds) / Ytest)) * 100)))
# Out:
# MAE 		 MAPE
# 0.7715 		 2.0639
