# %% [markdown]
# # The Packages

# %%
import numpy as np
import pandas as pd
import os
import gc
import datetime
import warnings

# %%
import statsmodels.api as sm
from datetime import date

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
import tensorflow as tf
import math 
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LSTM
from tensorflow.keras import losses
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.utils import plot_model

# %%
tf.__version__
# Out:
# '2.10.1'

# %%
# DATA VISUALIZATION
# ------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (20.0, 10.0)
sns.set_style("darkgrid")
sns.color_palette("mako", as_cmap=True)
import plotly.express as px

# %%
# CONFIGURATIONS
# ------------------------------------------------------
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.2f}'.format
warnings.filterwarnings('ignore')

# %% [markdown]
# # Utility Functions

# %%
def plotSeries(time, series, lab,form='-'):
    plt.plot(time, series, form, label=lab)
    plt.xlabel("Date")
    plt.ylabel("Close Price")
    plt.grid(True)

# %% [markdown]
# # The Data

# %%
wfc = pd.read_csv('Dataset/WFC Daily1.csv')

# %%
wfc.head()
# Out:
#          Date  Open  High   Low  Close  Adj Close    Volume
# 0  2000-01-03 20.16 20.19 19.00  19.56      10.44   9037000
# 1  2000-01-04 18.62 18.84 18.00  18.59       9.92  15237200
# 2  2000-01-05 18.50 18.88 18.03  18.41       9.82   8228200
# 3  2000-01-06 18.53 19.50 18.47  19.22      10.25   8326800
# 4  2000-01-07 19.62 19.84 19.28  19.56      10.44   7711200

# %%
wfc.Date.dtype
# Out:
# dtype('O')

# %%
wfc['Date'] = pd.to_datetime(wfc['Date'])
#wfc.set_index(['Date'],inplace=True)

# %%
wfc.head()
# Out:
#         Date  Open  High   Low  Close  Adj Close    Volume
# 0 2000-01-03 20.16 20.19 19.00  19.56      10.44   9037000
# 1 2000-01-04 18.62 18.84 18.00  18.59       9.92  15237200
# 2 2000-01-05 18.50 18.88 18.03  18.41       9.82   8228200
# 3 2000-01-06 18.53 19.50 18.47  19.22      10.25   8326800
# 4 2000-01-07 19.62 19.84 19.28  19.56      10.44   7711200

# %%
wfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5754 entries, 0 to 5753
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5754 non-null   datetime64[ns]
#  1   Open       5754 non-null   float64
#  2   High       5754 non-null   float64
#  3   Low        5754 non-null   float64
#  4   Close      5754 non-null   float64
#  5   Adj Close  5754 non-null   float64
#  6   Volume     5754 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 314.8 KB

# %%
wfc.describe()
# Out:
#          Open    High     Low   Close  Adj Close       Volume
# count 5754.00 5754.00 5754.00 5754.00    5754.00      5754.00
# mean    36.38   36.78   35.98   36.38      28.01  24313450.19
# std     11.74   11.77   11.73   11.75      12.85  26705062.78
# min      8.65    8.94    7.80    8.12       5.76   1774000.00
# 25%     26.71   27.20   26.25   26.74      18.01  10091200.00
# 50%     32.65   33.13   32.25   32.64      23.18  17086600.00
# 75%     47.75   48.19   47.33   47.79      41.58  29145250.00
# max     65.89   66.31   65.66   65.93      57.96 478736600.00

# %%
correlation = wfc.corr ()  
correlation. style.background_gradient ()
# Out:
# <style type="text/css">
# #T_b1108_row0_col0, #T_b1108_row0_col1, #T_b1108_row0_col2, #T_b1108_row0_col3, #T_b1108_row1_col0, #T_b1108_row1_col1, #T_b1108_row1_col2, #T_b1108_row1_col3, #T_b1108_row2_col0, #T_b1108_row2_col1, #T_b1108_row2_col2, #T_b1108_row2_col3, #T_b1108_row3_col0, #T_b1108_row3_col1, #T_b1108_row3_col2, #T_b1108_row3_col3, #T_b1108_row4_col4, #T_b1108_row5_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b1108_row0_col4, #T_b1108_row2_col4, #T_b1108_row3_col4 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_b1108_row0_col5, #T_b1108_row3_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_b1108_row1_col4, #T_b1108_row4_col0, #T_b1108_row4_col1, #T_b1108_row4_col2, #T_b1108_row4_col3 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_b1108_row1_col5 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_b1108_row2_col5, #T_b1108_row5_col0, #T_b1108_row5_col1, #T_b1108_row5_col2, #T_b1108_row5_col3, #T_b1108_row5_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b1108_row4_col5 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# </style>
# <table id="T_b1108">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1108_level0_col0" class="col_heading level0 col0" >Open</th>
#       <th id="T_b1108_level0_col1" class="col_heading level0 col1" >High</th>
#       <th id="T_b1108_level0_col2" class="col_heading level0 col2" >Low</th>
#       <th id="T_b1108_level0_col3" class="col_heading level0 col3" >Close</th>
#       <th id="T_b1108_level0_col4" class="col_heading level0 col4" >Adj Close</th>
#       <th id="T_b1108_level0_col5" class="col_heading level0 col5" >Volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1108_level0_row0" class="row_heading level0 row0" >Open</th>
#       <td id="T_b1108_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b1108_row0_col1" class="data row0 col1" >0.999324</td>
#       <td id="T_b1108_row0_col2" class="data row0 col2" >0.999274</td>
#       <td id="T_b1108_row0_col3" class="data row0 col3" >0.998754</td>
#       <td id="T_b1108_row0_col4" class="data row0 col4" >0.965403</td>
#       <td id="T_b1108_row0_col5" class="data row0 col5" >-0.184389</td>
#     </tr>
#     <tr>
#       <th id="T_b1108_level0_row1" class="row_heading level0 row1" >High</th>
#       <td id="T_b1108_row1_col0" class="data row1 col0" >0.999324</td>
#       <td id="T_b1108_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b1108_row1_col2" class="data row1 col2" >0.998796</td>
#       <td id="T_b1108_row1_col3" class="data row1 col3" >0.999323</td>
#       <td id="T_b1108_row1_col4" class="data row1 col4" >0.967945</td>
#       <td id="T_b1108_row1_col5" class="data row1 col5" >-0.169457</td>
#     </tr>
#     <tr>
#       <th id="T_b1108_level0_row2" class="row_heading level0 row2" >Low</th>
#       <td id="T_b1108_row2_col0" class="data row2 col0" >0.999274</td>
#       <td id="T_b1108_row2_col1" class="data row2 col1" >0.998796</td>
#       <td id="T_b1108_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_b1108_row2_col3" class="data row2 col3" >0.999303</td>
#       <td id="T_b1108_row2_col4" class="data row2 col4" >0.963519</td>
#       <td id="T_b1108_row2_col5" class="data row2 col5" >-0.199335</td>
#     </tr>
#     <tr>
#       <th id="T_b1108_level0_row3" class="row_heading level0 row3" >Close</th>
#       <td id="T_b1108_row3_col0" class="data row3 col0" >0.998754</td>
#       <td id="T_b1108_row3_col1" class="data row3 col1" >0.999323</td>
#       <td id="T_b1108_row3_col2" class="data row3 col2" >0.999303</td>
#       <td id="T_b1108_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_b1108_row3_col4" class="data row3 col4" >0.966149</td>
#       <td id="T_b1108_row3_col5" class="data row3 col5" >-0.183272</td>
#     </tr>
#     <tr>
#       <th id="T_b1108_level0_row4" class="row_heading level0 row4" >Adj Close</th>
#       <td id="T_b1108_row4_col0" class="data row4 col0" >0.965403</td>
#       <td id="T_b1108_row4_col1" class="data row4 col1" >0.967945</td>
#       <td id="T_b1108_row4_col2" class="data row4 col2" >0.963519</td>
#       <td id="T_b1108_row4_col3" class="data row4 col3" >0.966149</td>
#       <td id="T_b1108_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_b1108_row4_col5" class="data row4 col5" >-0.080189</td>
#     </tr>
#     <tr>
#       <th id="T_b1108_level0_row5" class="row_heading level0 row5" >Volume</th>
#       <td id="T_b1108_row5_col0" class="data row5 col0" >-0.184389</td>
#       <td id="T_b1108_row5_col1" class="data row5 col1" >-0.169457</td>
#       <td id="T_b1108_row5_col2" class="data row5 col2" >-0.199335</td>
#       <td id="T_b1108_row5_col3" class="data row5 col3" >-0.183272</td>
#       <td id="T_b1108_row5_col4" class="data row5 col4" >-0.080189</td>
#       <td id="T_b1108_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # The Split

# %%
min_date = wfc.Date.min()
max_date = wfc.Date.max()
print("Min:", min_date, "Max:", max_date)
# Out:
# Min: 2000-01-03 00:00:00 Max: 2022-11-11 00:00:00

# %%
train_percent = .75
valid_percent = .12

time_between = max_date - min_date

train_cutoff = min_date + train_percent*time_between
valid_cutoff = min_date + (train_percent + valid_percent)*time_between

print("Training Cutoff Date: {:s}".format(str(train_cutoff)))
print("Validation Cutoff Date: {:s}".format(str(valid_cutoff)))
# Out:
# Training Cutoff Date: 2017-02-23 00:00:00
# Validation Cutoff Date: 2019-11-21 18:14:24

# %%
train_df = wfc[wfc.Date <= train_cutoff]
valid_df = wfc[(wfc.Date > train_cutoff) & (wfc.Date <= valid_cutoff)]
test_df = wfc[wfc.Date > valid_cutoff]

# %%
print("Dataset shape: {:s}".format(str(wfc.shape)))
print("Train dataset shape: {:s}".format(str(train_df.shape)))
print("Vaid dataset shape: {:s}".format(str(valid_df.shape)))
print("Test dataset shape: {:s}".format(str(test_df.shape)))
# Out:
# Dataset shape: (5754, 7)
# Train dataset shape: (4313, 7)
# Vaid dataset shape: (692, 7)
# Test dataset shape: (749, 7)

# %% [markdown]
# # Stock Price Graph

# %%
plotSeries(train_df.Date, train_df.Close, "Training Data")
plotSeries(valid_df.Date, valid_df.Close, "Validation Data")
plotSeries(test_df.Date, test_df.Close, "Test Data")
plt.legend(loc='upper left')

# %%
train_df.set_index(['Date'],inplace=True)
test_df.set_index(['Date'],inplace=True)
valid_df.set_index(['Date'],inplace=True)

# %%
trainNorm = train_df.Close.values.reshape(-1, 1)
testNorm = test_df.Close.values.reshape(-1, 1)
validNorm = valid_df.Close.values.reshape(-1, 1)

# %%
trainNorm.shape
# Out:
# (4313, 1)

# %% [markdown]
# ## Windowed Dataset

# %%
mse_arr=[]
Z = []

window = 15

# %%
X_train= []
Y_train=[]
X_valid= []
Y_valid=[]
X_test= []
Y_test=[]

for i in range(len(trainNorm) - (window)):
    X_train.append(trainNorm[i:i+window])
    Y_train.append(trainNorm[i+window])
    
for i in range(len(validNorm) - (window)):
    X_valid.append(validNorm[i:i+window])
    Y_valid.append(validNorm[i+window])
    
for i in range(len(testNorm) - (window)):
    X_test.append(testNorm[i:i+window])
    Y_test.append(testNorm[i+window])
    

X_train=np.asanyarray(X_train)
Y_train=np.asanyarray(Y_train)
X_valid=np.asanyarray(X_valid)
Y_valid=np.asanyarray(Y_valid)
X_test=np.asanyarray(X_test)
Y_test=np.asanyarray(Y_test)

Xtrain = X_train[:,:,:]  
Ytrain = Y_train[:]  
Xvalid = X_valid[:,:,:]  
Yvalid= Y_valid[:]  
Xtest = X_test[:,:,:]  
Ytest= Y_test[:]

# %% [markdown]
# # Model Building

# %%
tf.keras.backend.clear_session()
model = tf.keras.Sequential()

# %%
model.add(keras.layers.Dense(10, input_shape=[window], activation="relu"))
model.add(keras.layers.Dense(10, activation="relu"))
model.add(keras.layers.Dense(1))

# %%
model.compile(loss=tf.keras.losses.MeanSquaredError(),
              optimizer=Adam(1e-4),
              metrics=['mae'])

# %%
log_dir = "logs\\" + datetime.datetime.now().strftime("%d-%m-%Y_%H%M%S")

tensorboard_callback = [
#                         tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1),
#                         ModelCheckpoint(model_path, verbose=1, save_best_only=True),
#                         ReduceLROnPlateau(monitor= "val_mae", factor=0.1, patience=5, min_lr=1e-7, verbose=1),
                        ReduceLROnPlateau(monitor='val_mae', factor=0.2,patience=5, min_lr=1e-6, verbose=1),
#                         CSVLogger(csv_path),
                        TensorBoard(),
                        EarlyStopping(monitor= "val_mae", patience=10, restore_best_weights=True)
                       ]

# %%
history = model.fit(Xtrain, Ytrain,batch_size=128, epochs=100, verbose=1,validation_data=(Xvalid, Yvalid), callbacks=tensorboard_callback)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 3s 11ms/step - loss: 773.3255 - mae: 26.5463 - val_loss: 1723.3479 - val_mae: 41.3584 - lr: 1.0000e-04
# Epoch 2/100
# 34/34 [==============================] - 0s 5ms/step - loss: 711.5085 - mae: 25.4636 - val_loss: 1579.4365 - val_mae: 39.5919 - lr: 1.0000e-04
# Epoch 3/100
# 34/34 [==============================] - 0s 6ms/step - loss: 649.3206 - mae: 24.3237 - val_loss: 1433.5525 - val_mae: 37.7170 - lr: 1.0000e-04
# Epoch 4/100
# 34/34 [==============================] - 0s 5ms/step - loss: 582.0355 - mae: 23.0166 - val_loss: 1260.9408 - val_mae: 35.3712 - lr: 1.0000e-04
# Epoch 5/100
# 34/34 [==============================] - 0s 5ms/step - loss: 507.3062 - mae: 21.4891 - val_loss: 1091.2960 - val_mae: 32.9026 - lr: 1.0000e-04
# Epoch 6/100
# 34/34 [==============================] - 0s 5ms/step - loss: 411.4244 - mae: 19.3066 - val_loss: 689.3776 - val_mae: 26.1155 - lr: 1.0000e-04
# Epoch 7/100
# 34/34 [==============================] - 0s 5ms/step - loss: 205.1181 - mae: 13.5358 - val_loss: 294.4603 - val_mae: 17.0201 - lr: 1.0000e-04
# Epoch 8/100
# 34/34 [==============================] - 0s 5ms/step - loss: 88.4910 - mae: 8.8302 - val_loss: 123.2666 - val_mae: 10.9306 - lr: 1.0000e-04
# Epoch 9/100
# 34/34 [==============================] - 0s 5ms/step - loss: 35.4252 - mae: 5.5122 - val_loss: 42.5301 - val_mae: 6.2613 - lr: 1.0000e-04
# Epoch 10/100
# 34/34 [==============================] - 0s 5ms/step - loss: 12.0747 - mae: 3.0918 - val_loss: 13.0930 - val_mae: 3.2322 - lr: 1.0000e-04
# Epoch 11/100
# 34/34 [==============================] - 0s 5ms/step - loss: 4.3892 - mae: 1.7006 - val_loss: 5.0780 - val_mae: 1.8599 - lr: 1.0000e-04
# Epoch 12/100
# 34/34 [==============================] - 0s 5ms/step - loss: 2.3550 - mae: 1.1176 - val_loss: 3.3403 - val_mae: 1.4831 - lr: 1.0000e-04
# Epoch 13/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.9260 - mae: 0.9526 - val_loss: 3.0661 - val_mae: 1.4090 - lr: 1.0000e-04
# Epoch 14/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.8352 - mae: 0.9179 - val_loss: 3.0342 - val_mae: 1.3953 - lr: 1.0000e-04
# Epoch 15/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.8045 - mae: 0.9080 - val_loss: 2.9994 - val_mae: 1.3842 - lr: 1.0000e-04
# Epoch 16/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.7845 - mae: 0.9015 - val_loss: 2.9729 - val_mae: 1.3747 - lr: 1.0000e-04
# Epoch 17/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.7644 - mae: 0.8948 - val_loss: 2.9180 - val_mae: 1.3619 - lr: 1.0000e-04
# Epoch 18/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.7392 - mae: 0.8869 - val_loss: 2.8642 - val_mae: 1.3446 - lr: 1.0000e-04
# Epoch 19/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.7086 - mae: 0.8764 - val_loss: 2.7710 - val_mae: 1.3189 - lr: 1.0000e-04
# Epoch 20/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.6709 - mae: 0.8619 - val_loss: 2.6503 - val_mae: 1.2829 - lr: 1.0000e-04
# Epoch 21/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.6247 - mae: 0.8434 - val_loss: 2.5417 - val_mae: 1.2516 - lr: 1.0000e-04
# Epoch 22/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.5846 - mae: 0.8275 - val_loss: 2.4559 - val_mae: 1.2261 - lr: 1.0000e-04
# Epoch 23/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.5559 - mae: 0.8175 - val_loss: 2.3984 - val_mae: 1.2131 - lr: 1.0000e-04
# Epoch 24/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.5334 - mae: 0.8107 - val_loss: 2.3741 - val_mae: 1.2043 - lr: 1.0000e-04
# Epoch 25/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.5172 - mae: 0.8066 - val_loss: 2.3475 - val_mae: 1.1990 - lr: 1.0000e-04
# Epoch 26/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.5018 - mae: 0.8027 - val_loss: 2.3433 - val_mae: 1.1955 - lr: 1.0000e-04
# Epoch 27/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.4894 - mae: 0.7998 - val_loss: 2.3290 - val_mae: 1.1934 - lr: 1.0000e-04
# Epoch 28/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.4801 - mae: 0.7982 - val_loss: 2.3284 - val_mae: 1.1930 - lr: 1.0000e-04
# Epoch 29/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.4722 - mae: 0.7960 - val_loss: 2.3269 - val_mae: 1.1907 - lr: 1.0000e-04
# Epoch 30/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.4638 - mae: 0.7940 - val_loss: 2.3215 - val_mae: 1.1898 - lr: 1.0000e-04
# Epoch 31/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.4556 - mae: 0.7919 - val_loss: 2.3136 - val_mae: 1.1893 - lr: 1.0000e-04
# Epoch 32/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.4483 - mae: 0.7907 - val_loss: 2.3197 - val_mae: 1.1886 - lr: 1.0000e-04
# Epoch 33/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.4437 - mae: 0.7894 - val_loss: 2.3088 - val_mae: 1.1880 - lr: 1.0000e-04
# Epoch 34/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.4369 - mae: 0.7880 - val_loss: 2.3156 - val_mae: 1.1875 - lr: 1.0000e-04
# Epoch 35/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.4321 - mae: 0.7868 - val_loss: 2.3249 - val_mae: 1.1879 - lr: 1.0000e-04
# Epoch 36/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.4267 - mae: 0.7858 - val_loss: 2.3161 - val_mae: 1.1862 - lr: 1.0000e-04
# Epoch 37/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.4214 - mae: 0.7840 - val_loss: 2.3258 - val_mae: 1.1869 - lr: 1.0000e-04
# Epoch 38/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.4171 - mae: 0.7841 - val_loss: 2.3116 - val_mae: 1.1846 - lr: 1.0000e-04
# Epoch 39/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.4121 - mae: 0.7822 - val_loss: 2.3177 - val_mae: 1.1854 - lr: 1.0000e-04
# Epoch 40/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.4073 - mae: 0.7811 - val_loss: 2.3189 - val_mae: 1.1860 - lr: 1.0000e-04
# Epoch 41/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.4029 - mae: 0.7807 - val_loss: 2.3068 - val_mae: 1.1841 - lr: 1.0000e-04
# Epoch 42/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3980 - mae: 0.7790 - val_loss: 2.3092 - val_mae: 1.1841 - lr: 1.0000e-04
# Epoch 43/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3947 - mae: 0.7788 - val_loss: 2.3026 - val_mae: 1.1837 - lr: 1.0000e-04
# Epoch 44/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3912 - mae: 0.7779 - val_loss: 2.3142 - val_mae: 1.1816 - lr: 1.0000e-04
# Epoch 45/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3877 - mae: 0.7769 - val_loss: 2.3029 - val_mae: 1.1825 - lr: 1.0000e-04
# Epoch 46/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3838 - mae: 0.7761 - val_loss: 2.2975 - val_mae: 1.1801 - lr: 1.0000e-04
# Epoch 47/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3803 - mae: 0.7748 - val_loss: 2.2966 - val_mae: 1.1796 - lr: 1.0000e-04
# Epoch 48/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3772 - mae: 0.7742 - val_loss: 2.2962 - val_mae: 1.1779 - lr: 1.0000e-04
# Epoch 49/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3744 - mae: 0.7734 - val_loss: 2.3026 - val_mae: 1.1807 - lr: 1.0000e-04
# Epoch 50/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3708 - mae: 0.7733 - val_loss: 2.2969 - val_mae: 1.1802 - lr: 1.0000e-04
# Epoch 51/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3683 - mae: 0.7727 - val_loss: 2.2904 - val_mae: 1.1787 - lr: 1.0000e-04
# Epoch 52/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3654 - mae: 0.7715 - val_loss: 2.2864 - val_mae: 1.1782 - lr: 1.0000e-04
# Epoch 53/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3628 - mae: 0.7704 - val_loss: 2.2835 - val_mae: 1.1759 - lr: 1.0000e-04
# Epoch 54/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3607 - mae: 0.7708 - val_loss: 2.2814 - val_mae: 1.1753 - lr: 1.0000e-04
# Epoch 55/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3579 - mae: 0.7697 - val_loss: 2.2821 - val_mae: 1.1777 - lr: 1.0000e-04
# Epoch 56/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3550 - mae: 0.7694 - val_loss: 2.2974 - val_mae: 1.1754 - lr: 1.0000e-04
# Epoch 57/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3522 - mae: 0.7688 - val_loss: 2.2826 - val_mae: 1.1732 - lr: 1.0000e-04
# Epoch 58/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3490 - mae: 0.7676 - val_loss: 2.2697 - val_mae: 1.1735 - lr: 1.0000e-04
# Epoch 59/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3473 - mae: 0.7669 - val_loss: 2.2707 - val_mae: 1.1735 - lr: 1.0000e-04
# Epoch 60/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3449 - mae: 0.7663 - val_loss: 2.2687 - val_mae: 1.1730 - lr: 1.0000e-04
# Epoch 61/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3430 - mae: 0.7660 - val_loss: 2.2666 - val_mae: 1.1731 - lr: 1.0000e-04
# Epoch 62/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3411 - mae: 0.7659 - val_loss: 2.2678 - val_mae: 1.1709 - lr: 1.0000e-04
# Epoch 63/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3397 - mae: 0.7656 - val_loss: 2.2728 - val_mae: 1.1698 - lr: 1.0000e-04
# Epoch 64/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.3373 - mae: 0.7647 - val_loss: 2.2666 - val_mae: 1.1689 - lr: 1.0000e-04
# Epoch 65/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3352 - mae: 0.7641 - val_loss: 2.2633 - val_mae: 1.1687 - lr: 1.0000e-04
# Epoch 66/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3335 - mae: 0.7631 - val_loss: 2.2549 - val_mae: 1.1697 - lr: 1.0000e-04
# Epoch 67/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3307 - mae: 0.7638 - val_loss: 2.2488 - val_mae: 1.1682 - lr: 1.0000e-04
# Epoch 68/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3289 - mae: 0.7622 - val_loss: 2.2509 - val_mae: 1.1682 - lr: 1.0000e-04
# Epoch 69/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3264 - mae: 0.7626 - val_loss: 2.2635 - val_mae: 1.1670 - lr: 1.0000e-04
# Epoch 70/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3240 - mae: 0.7609 - val_loss: 2.2412 - val_mae: 1.1665 - lr: 1.0000e-04
# Epoch 71/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3219 - mae: 0.7609 - val_loss: 2.2446 - val_mae: 1.1662 - lr: 1.0000e-04
# Epoch 72/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3206 - mae: 0.7606 - val_loss: 2.2434 - val_mae: 1.1639 - lr: 1.0000e-04
# Epoch 73/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3197 - mae: 0.7598 - val_loss: 2.2278 - val_mae: 1.1654 - lr: 1.0000e-04
# Epoch 74/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3175 - mae: 0.7600 - val_loss: 2.2359 - val_mae: 1.1620 - lr: 1.0000e-04
# Epoch 75/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3139 - mae: 0.7588 - val_loss: 2.2349 - val_mae: 1.1622 - lr: 1.0000e-04
# Epoch 76/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3126 - mae: 0.7582 - val_loss: 2.2230 - val_mae: 1.1619 - lr: 1.0000e-04
# Epoch 77/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3106 - mae: 0.7575 - val_loss: 2.2353 - val_mae: 1.1597 - lr: 1.0000e-04
# Epoch 78/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3084 - mae: 0.7568 - val_loss: 2.2216 - val_mae: 1.1600 - lr: 1.0000e-04
# Epoch 79/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3063 - mae: 0.7567 - val_loss: 2.2283 - val_mae: 1.1609 - lr: 1.0000e-04
# Epoch 80/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3052 - mae: 0.7564 - val_loss: 2.2231 - val_mae: 1.1602 - lr: 1.0000e-04
# Epoch 81/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3026 - mae: 0.7562 - val_loss: 2.2291 - val_mae: 1.1606 - lr: 1.0000e-04
# Epoch 82/100
# 34/34 [==============================] - ETA: 0s - loss: 1.3004 - mae: 0.7551
# Epoch 82: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 34/34 [==============================] - 0s 5ms/step - loss: 1.3004 - mae: 0.7551 - val_loss: 2.2152 - val_mae: 1.1600 - lr: 1.0000e-04
# Epoch 83/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2986 - mae: 0.7553 - val_loss: 2.2189 - val_mae: 1.1588 - lr: 2.0000e-05
# Epoch 84/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2981 - mae: 0.7542 - val_loss: 2.2253 - val_mae: 1.1585 - lr: 2.0000e-05
# Epoch 85/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2972 - mae: 0.7540 - val_loss: 2.2206 - val_mae: 1.1585 - lr: 2.0000e-05
# Epoch 86/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2970 - mae: 0.7542 - val_loss: 2.2200 - val_mae: 1.1586 - lr: 2.0000e-05
# Epoch 87/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.2970 - mae: 0.7542 - val_loss: 2.2201 - val_mae: 1.1585 - lr: 2.0000e-05
# Epoch 88/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.2970 - mae: 0.7544 - val_loss: 2.2189 - val_mae: 1.1577 - lr: 2.0000e-05
# Epoch 89/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2962 - mae: 0.7538 - val_loss: 2.2194 - val_mae: 1.1575 - lr: 2.0000e-05
# Epoch 90/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2958 - mae: 0.7538 - val_loss: 2.2172 - val_mae: 1.1575 - lr: 2.0000e-05
# Epoch 91/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2956 - mae: 0.7538 - val_loss: 2.2139 - val_mae: 1.1576 - lr: 2.0000e-05
# Epoch 92/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2948 - mae: 0.7534 - val_loss: 2.2175 - val_mae: 1.1571 - lr: 2.0000e-05
# Epoch 93/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2948 - mae: 0.7534 - val_loss: 2.2174 - val_mae: 1.1570 - lr: 2.0000e-05
# Epoch 94/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2943 - mae: 0.7534 - val_loss: 2.2156 - val_mae: 1.1574 - lr: 2.0000e-05
# Epoch 95/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2938 - mae: 0.7533 - val_loss: 2.2168 - val_mae: 1.1572 - lr: 2.0000e-05
# Epoch 96/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2946 - mae: 0.7535 - val_loss: 2.2225 - val_mae: 1.1565 - lr: 2.0000e-05
# Epoch 97/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2935 - mae: 0.7533 - val_loss: 2.2199 - val_mae: 1.1563 - lr: 2.0000e-05
# Epoch 98/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2928 - mae: 0.7526 - val_loss: 2.2171 - val_mae: 1.1565 - lr: 2.0000e-05
# Epoch 99/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2916 - mae: 0.7524 - val_loss: 2.2143 - val_mae: 1.1565 - lr: 2.0000e-05
# Epoch 100/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.2923 - mae: 0.7533 - val_loss: 2.2121 - val_mae: 1.1563 - lr: 2.0000e-05

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                160
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 281
# Trainable params: 281
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Showing training and validation loss
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
loss_values50 = loss_values[0:150]
val_loss_values50 = val_loss_values[0:150]
epochs = range(1, len(loss_values50) + 1)
plt.plot(epochs, loss_values50, label='Training Loss')
plt.plot(epochs, val_loss_values50, label='Validation Loss')
plt.rc('font', size = 14)
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.xticks(epochs)
plt.xticks(np.arange(min(epochs), max(epochs)+1, 10.0))
#fig.savefig('test&validationlosscnn.png', dpi=300)
plt.show()

# %%
loss_values = history_dict['mae']
val_loss_values = history_dict['val_mae']
loss_values50 = loss_values[0:150]
val_loss_values50 = val_loss_values[0:150]
epochs = range(1, len(loss_values50) + 1)
plt.plot(epochs, loss_values50, label='Training MAE')
plt.plot(epochs, val_loss_values50, label='Validation MAE')
plt.rc('font', size = 14)
plt.title('Training and Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.xticks(epochs)
plt.xticks(np.arange(min(epochs), max(epochs)+1, 10.0))
#fig.savefig('test&validationlosscnn.png', dpi=300)
plt.show()

# %%
#Evaluating model
trainScore = model.evaluate(Xtrain, Ytrain, verbose=1)
validScore = model.evaluate(Xvalid, Yvalid, verbose=1)
testScore = model.evaluate(Xtest, Ytest, verbose=1)
# Out:
# 135/135 [==============================] - 0s 3ms/step - loss: 1.2911 - mae: 0.7525
# 22/22 [==============================] - 0s 3ms/step - loss: 2.2121 - mae: 1.1563
# 23/23 [==============================] - 0s 3ms/step - loss: 4.6926 - mae: 1.5614

# %%
testScore, validScore, trainScore
# Out:
# ([4.6925787925720215, 1.5613951683044434],
#  [2.2120916843414307, 1.156308650970459],
#  [1.291082739830017, 0.752544641494751])

# %%
preds = model.predict(Xtest)
# Out:
# 23/23 [==============================] - 0s 1ms/step

# %%
Xtest.shape
# Out:
# (734, 15, 1)

# %%
plt.figure(figsize=(15,5))
plt.title('MSE: {}'.format(testScore[1]))
plt.plot(Ytest, label='Real')
plt.plot(preds, label='Prediction')

plt.legend(loc="best")

#for saving figures
# plt.savefig('CPALL_graph.png')
plt.show()

# %%
#denormalizing datasets
# preds = scaler.inverse_transform(preds)
# Ytest = scaler.inverse_transform(Ytest)

# %%
#Show Train and Test Scores
print('Train MSE \t Train RMSE \t Train MAE \t Testscore RMSE \tTest MSE \tTest MAE')
print('%.9f \t %.9f \t %.9f \t %.9f \t \t %.9f \t %.9f' % (trainScore[0], math.sqrt(trainScore[0]),trainScore[1],math.sqrt(testScore[0]),testScore[0],testScore[1]))
# Out:
# Train MSE 	 Train RMSE 	 Train MAE 	 Testscore RMSE 	Test MSE 	Test MAE
# 1.291082740 	 1.136258219 	 0.752544641 	 2.166236089 	 	 4.692578793 	 1.561395168

# %%
print('MAE \t\t MAPE')
print('%.4f \t\t %.4f' % (mean_absolute_error(Ytest,preds),(np.mean(np.abs((Ytest - preds) / Ytest)) * 100)))
# Out:
# MAE 		 MAPE
# 1.5614 		 4.1638
