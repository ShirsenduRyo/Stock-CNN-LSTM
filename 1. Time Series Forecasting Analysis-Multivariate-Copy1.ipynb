# %% [markdown]
# # The Packages

# %%
import numpy as np
import pandas as pd
import os
import gc
import datetime
import warnings

# %%
# DATA VISUALIZATION
# ------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (20.0, 10.0)
sns.set_style("darkgrid")
sns.color_palette("mako", as_cmap=True)
import plotly.express as px

# %%
# CONFIGURATIONS
# ------------------------------------------------------
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.2f}'.format
warnings.filterwarnings('ignore')

# %% [markdown]
# # Utility Functions

# %%
def plotSeries(time, series, lab,form='-'):
    plt.plot(time, series, form, label=lab)
    plt.xlabel("Date")
    plt.ylabel("Close Price")
    plt.grid(True)

# %% [markdown]
# # The Data

# %%
wfc = pd.read_csv('Dataset/WFC Daily1.csv')

# %%
wfc.head(2), wfc.shape
# Out:
# (         Date  Open  High   Low  Close  Adj Close    Volume
#  0  2000-01-03 20.16 20.19 19.00  19.56      10.44   9037000
#  1  2000-01-04 18.62 18.84 18.00  18.59       9.92  15237200,
#  (5754, 7))

# %%
wfc.Date.dtype
# Out:
# dtype('O')

# %%
wfc['Date'] = pd.to_datetime(wfc['Date'])
#wfc.set_index(['Date'],inplace=True)

# %%
wfc.head(3)
# Out:
#         Date  Open  High   Low  Close  Adj Close    Volume
# 0 2000-01-03 20.16 20.19 19.00  19.56      10.44   9037000
# 1 2000-01-04 18.62 18.84 18.00  18.59       9.92  15237200
# 2 2000-01-05 18.50 18.88 18.03  18.41       9.82   8228200

# %%
wfc.tail(2)
# Out:
#            Date  Open  High   Low  Close  Adj Close    Volume
# 5752 2022-11-10 47.02 48.11 46.93  47.95      47.95  23091900
# 5753 2022-11-11 48.10 48.36 47.33  47.55      47.55  18060100

# %%
wfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5754 entries, 0 to 5753
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5754 non-null   datetime64[ns]
#  1   Open       5754 non-null   float64
#  2   High       5754 non-null   float64
#  3   Low        5754 non-null   float64
#  4   Close      5754 non-null   float64
#  5   Adj Close  5754 non-null   float64
#  6   Volume     5754 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 314.8 KB

# %%
correlation = wfc.corr ()  
correlation. style.background_gradient ()
# Out:
# <style type="text/css">
# #T_a5101_row0_col0, #T_a5101_row0_col1, #T_a5101_row0_col2, #T_a5101_row0_col3, #T_a5101_row1_col0, #T_a5101_row1_col1, #T_a5101_row1_col2, #T_a5101_row1_col3, #T_a5101_row2_col0, #T_a5101_row2_col1, #T_a5101_row2_col2, #T_a5101_row2_col3, #T_a5101_row3_col0, #T_a5101_row3_col1, #T_a5101_row3_col2, #T_a5101_row3_col3, #T_a5101_row4_col4, #T_a5101_row5_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a5101_row0_col4, #T_a5101_row2_col4, #T_a5101_row3_col4 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_a5101_row0_col5, #T_a5101_row3_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_a5101_row1_col4, #T_a5101_row4_col0, #T_a5101_row4_col1, #T_a5101_row4_col2, #T_a5101_row4_col3 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_a5101_row1_col5 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_a5101_row2_col5, #T_a5101_row5_col0, #T_a5101_row5_col1, #T_a5101_row5_col2, #T_a5101_row5_col3, #T_a5101_row5_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a5101_row4_col5 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# </style>
# <table id="T_a5101">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5101_level0_col0" class="col_heading level0 col0" >Open</th>
#       <th id="T_a5101_level0_col1" class="col_heading level0 col1" >High</th>
#       <th id="T_a5101_level0_col2" class="col_heading level0 col2" >Low</th>
#       <th id="T_a5101_level0_col3" class="col_heading level0 col3" >Close</th>
#       <th id="T_a5101_level0_col4" class="col_heading level0 col4" >Adj Close</th>
#       <th id="T_a5101_level0_col5" class="col_heading level0 col5" >Volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5101_level0_row0" class="row_heading level0 row0" >Open</th>
#       <td id="T_a5101_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a5101_row0_col1" class="data row0 col1" >0.999324</td>
#       <td id="T_a5101_row0_col2" class="data row0 col2" >0.999274</td>
#       <td id="T_a5101_row0_col3" class="data row0 col3" >0.998754</td>
#       <td id="T_a5101_row0_col4" class="data row0 col4" >0.965403</td>
#       <td id="T_a5101_row0_col5" class="data row0 col5" >-0.184389</td>
#     </tr>
#     <tr>
#       <th id="T_a5101_level0_row1" class="row_heading level0 row1" >High</th>
#       <td id="T_a5101_row1_col0" class="data row1 col0" >0.999324</td>
#       <td id="T_a5101_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a5101_row1_col2" class="data row1 col2" >0.998796</td>
#       <td id="T_a5101_row1_col3" class="data row1 col3" >0.999323</td>
#       <td id="T_a5101_row1_col4" class="data row1 col4" >0.967945</td>
#       <td id="T_a5101_row1_col5" class="data row1 col5" >-0.169457</td>
#     </tr>
#     <tr>
#       <th id="T_a5101_level0_row2" class="row_heading level0 row2" >Low</th>
#       <td id="T_a5101_row2_col0" class="data row2 col0" >0.999274</td>
#       <td id="T_a5101_row2_col1" class="data row2 col1" >0.998796</td>
#       <td id="T_a5101_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_a5101_row2_col3" class="data row2 col3" >0.999303</td>
#       <td id="T_a5101_row2_col4" class="data row2 col4" >0.963519</td>
#       <td id="T_a5101_row2_col5" class="data row2 col5" >-0.199335</td>
#     </tr>
#     <tr>
#       <th id="T_a5101_level0_row3" class="row_heading level0 row3" >Close</th>
#       <td id="T_a5101_row3_col0" class="data row3 col0" >0.998754</td>
#       <td id="T_a5101_row3_col1" class="data row3 col1" >0.999323</td>
#       <td id="T_a5101_row3_col2" class="data row3 col2" >0.999303</td>
#       <td id="T_a5101_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_a5101_row3_col4" class="data row3 col4" >0.966149</td>
#       <td id="T_a5101_row3_col5" class="data row3 col5" >-0.183272</td>
#     </tr>
#     <tr>
#       <th id="T_a5101_level0_row4" class="row_heading level0 row4" >Adj Close</th>
#       <td id="T_a5101_row4_col0" class="data row4 col0" >0.965403</td>
#       <td id="T_a5101_row4_col1" class="data row4 col1" >0.967945</td>
#       <td id="T_a5101_row4_col2" class="data row4 col2" >0.963519</td>
#       <td id="T_a5101_row4_col3" class="data row4 col3" >0.966149</td>
#       <td id="T_a5101_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_a5101_row4_col5" class="data row4 col5" >-0.080189</td>
#     </tr>
#     <tr>
#       <th id="T_a5101_level0_row5" class="row_heading level0 row5" >Volume</th>
#       <td id="T_a5101_row5_col0" class="data row5 col0" >-0.184389</td>
#       <td id="T_a5101_row5_col1" class="data row5 col1" >-0.169457</td>
#       <td id="T_a5101_row5_col2" class="data row5 col2" >-0.199335</td>
#       <td id="T_a5101_row5_col3" class="data row5 col3" >-0.183272</td>
#       <td id="T_a5101_row5_col4" class="data row5 col4" >-0.080189</td>
#       <td id="T_a5101_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
wfc.drop(["Open", "High", "Low", "Adj Close"], axis = 1, inplace=True)
wfc.head()
# Out:
#         Date  Close    Volume
# 0 2000-01-03  19.56   9037000
# 1 2000-01-04  18.59  15237200
# 2 2000-01-05  18.41   8228200
# 3 2000-01-06  19.22   8326800
# 4 2000-01-07  19.56   7711200

# %%
#Week Starts with Monday
wfc["Weekday"] = wfc.Date.dt.weekday
wfc.head(3)
# Out:
#         Date  Close    Volume  Weekday
# 0 2000-01-03  19.56   9037000        0
# 1 2000-01-04  18.59  15237200        1
# 2 2000-01-05  18.41   8228200        2

# %%
wfc["volumeChange"] = wfc["Volume"].pct_change()*100
wfc["volumeChange"] = wfc["volumeChange"].shift(periods=-1)

# %%
wfc.drop(["Volume"], axis = 1, inplace=True)

# %%
wfc.head(2)
# Out:
#         Date  Close  Weekday  volumeChange
# 0 2000-01-03  19.56        0         68.61
# 1 2000-01-04  18.59        1        -46.00

# %%
wfc["closeChange"] = wfc["Close"].pct_change()*100
wfc["closeChange"] = wfc["closeChange"].shift(periods=-1)

# %%
# window_size  = 200
  
# # Get the window of series
# # of observations of specified window size
# windows = wfc.Close.rolling(window_size)
  
# # Create a series of moving
# # averages of each window
# moving_averages = windows.mean()
  
# # Convert pandas series back to list
# moving_averages_list = moving_averages.tolist()
  
# # Remove null entries from the list
# # final_list = moving_averages_list[window_size - 1:]

# %%
ema10 = wfc.Close.ewm(span=10).mean()
ema20 = wfc.Close.ewm(span=20).mean()
ema50 = wfc.Close.ewm(span=50).mean()
ema100 = wfc.Close.ewm(span=100).mean()

# %%
# Comparison plot b/w stock values & EMA
plt.plot(wfc.Close, label="Stock Values", color="black")
plt.plot(ema10, label="EMA Values 10", color="r")
plt.plot(ema20, label="EMA Values 20", color="orange")
plt.plot(ema50, label="EMA Values 50", color="yellow")
plt.plot(ema100, label="EMA Values 100", color="b")
plt.xlabel("Days")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
wfc["EMA 10"] = ema10
wfc["EMA 20"] = ema20
wfc["EMA 50"] = ema50
wfc["EMA 100"] = ema100

wfc.head()
# Out:
#         Date  Close  Weekday  volumeChange  closeChange  EMA 10  EMA 20  \
# 0 2000-01-03  19.56        0         68.61        -4.95   19.56   19.56
# 1 2000-01-04  18.59        1        -46.00        -1.01   19.03   19.05
# 2 2000-01-05  18.41        2          1.20         4.41   18.78   18.82
# 3 2000-01-06  19.22        3         -7.39         1.79   18.92   18.93
# 4 2000-01-07  19.56        4         16.11        -3.19   19.11   19.08
#
#    EMA 50  EMA 100
# 0   19.56    19.56
# 1   19.07    19.07
# 2   18.84    18.85
# 3   18.94    18.94
# 4   19.07    19.07

# %%
wfc["ROC5"] = wfc.closeChange.rolling(5).mean()
wfc["ROC10"] = wfc.closeChange.rolling(10).mean()
wfc["ROC15"] = wfc.closeChange.rolling(15).mean()
wfc["ROC20"] = wfc.closeChange.rolling(20).mean()
wfc = wfc.fillna(0)

# %%
wfc.head(3)
# Out:
#         Date  Close  Weekday  volumeChange  closeChange  EMA 10  EMA 20  \
# 0 2000-01-03  19.56        0         68.61        -4.95   19.56   19.56
# 1 2000-01-04  18.59        1        -46.00        -1.01   19.03   19.05
# 2 2000-01-05  18.41        2          1.20         4.41   18.78   18.82
#
#    EMA 50  EMA 100  ROC5  ROC10  ROC15  ROC20
# 0   19.56    19.56  0.00   0.00   0.00   0.00
# 1   19.07    19.07  0.00   0.00   0.00   0.00
# 2   18.84    18.85  0.00   0.00   0.00   0.00

# %%
wfc.isnull().sum().sort_values(ascending = False).head(3)
# Out:
# Date       0
# Close      0
# Weekday    0
# dtype: int64

# %% [markdown]
# # Treasury Rates

# %%
dtb3 = pd.read_csv('Dataset/DTB3.csv')
dtb6 = pd.read_csv('Dataset/DTB6.csv')
dgs5 = pd.read_csv('Dataset/DGS5.csv')

# %%
dtb3.head(3)
# Out:
#          DATE  TB3MS
# 0  2000-01-01   5.32
# 1  2000-02-01   5.55
# 2  2000-03-01   5.69

# %%
dtb6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5965 entries, 0 to 5964
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    5965 non-null   object
#  1   DTB6    5965 non-null   object
# dtypes: object(2)
# memory usage: 93.3+ KB

# %%
dtb6.head(3)
# Out:
#          DATE   DTB6
# 0  2000-01-03  5.550
# 1  2000-01-04  5.500
# 2  2000-01-05  5.490

# %%
dgs5.head(3)
# Out:
#          DATE  DGS5
# 0  2000-01-03  6.50
# 1  2000-01-04  6.40
# 2  2000-01-05  6.51

# %%
mergedDf = pd.merge(dtb6, dgs5, how='outer', on="DATE")
mergedDf.head(3)
# Out:
#          DATE   DTB6  DGS5
# 0  2000-01-03  5.550  6.50
# 1  2000-01-04  5.500  6.40
# 2  2000-01-05  5.490  6.51

# %%
mergedDf.isnull().sum().sort_values(ascending = False).head(3)
# Out:
# DATE    0
# DTB6    0
# DGS5    0
# dtype: int64

# %%
mergedDf['Date'] = pd.to_datetime(mergedDf['DATE'])
mergedDf.drop(['DATE'], axis = 1, inplace = True)
mergedDf.head(2)
# Out:
#     DTB6  DGS5       Date
# 0  5.550  6.50 2000-01-03
# 1  5.500  6.40 2000-01-04

# %%
treasuryDf = pd.merge(wfc, mergedDf, how ='left', on="Date" )
treasuryDf.head(2)
# Out:
#         Date  Close  Weekday  volumeChange  closeChange  EMA 10  EMA 20  \
# 0 2000-01-03  19.56        0         68.61        -4.95   19.56   19.56
# 1 2000-01-04  18.59        1        -46.00        -1.01   19.03   19.05
#
#    EMA 50  EMA 100  ROC5  ROC10  ROC15  ROC20   DTB6  DGS5
# 0   19.56    19.56  0.00   0.00   0.00   0.00  5.550  6.50
# 1   19.07    19.07  0.00   0.00   0.00   0.00  5.500  6.40

# %%
treasuryDf.shape, wfc.shape, mergedDf.shape
# Out:
# ((5754, 15), (5754, 13), (5965, 3))

# %%
treasuryDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5754 entries, 0 to 5753
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5754 non-null   datetime64[ns]
#  1   Close         5754 non-null   float64
#  2   Weekday       5754 non-null   int64
#  3   volumeChange  5754 non-null   float64
#  4   closeChange   5754 non-null   float64
#  5   EMA 10        5754 non-null   float64
#  6   EMA 20        5754 non-null   float64
#  7   EMA 50        5754 non-null   float64
#  8   EMA 100       5754 non-null   float64
#  9   ROC5          5754 non-null   float64
#  10  ROC10         5754 non-null   float64
#  11  ROC15         5754 non-null   float64
#  12  ROC20         5754 non-null   float64
#  13  DTB6          5754 non-null   object
#  14  DGS5          5754 non-null   object
# dtypes: datetime64[ns](1), float64(11), int64(1), object(2)
# memory usage: 719.2+ KB

# %%
# treasuryDf['DTB6'] = treasuryDf['DTB6'].astype(float)
treasuryDf['DTB6'] = treasuryDf['DTB6'].apply(lambda x: float(x.replace('.', '0')))
treasuryDf['DGS5'] = treasuryDf['DGS5'].apply(lambda x: float(x.replace('.', '0')))

# %%
treasuryDf['DTB6'] = treasuryDf['DTB6'].astype(float)
treasuryDf['DGS5'] = treasuryDf['DGS5'].astype(float)

# %%
# sns.heatmap(treasuryDf.isnull(), cbar=False)

# %%
treasuryDf.to_csv("Dataset/Treasury.csv", index = False)

# %%
wfc = treasuryDf.copy()

# %% [markdown]
# # The Split

# %%
min_date = wfc.Date.min()
max_date = wfc.Date.max()
print("Min:", min_date, "Max:", max_date)
# Out:
# Min: 2000-01-03 00:00:00 Max: 2022-11-11 00:00:00

# %%
train_percent = .75
valid_percent = .12

time_between = max_date - min_date

train_cutoff = min_date + train_percent*time_between
valid_cutoff = min_date + (train_percent + valid_percent)*time_between

print("Training Cutoff Date: {:s}".format(str(train_cutoff)))
print("Validation Cutoff Date: {:s}".format(str(valid_cutoff)))
# Out:
# Training Cutoff Date: 2017-02-23 00:00:00
# Validation Cutoff Date: 2019-11-21 18:14:24

# %%
train_df = wfc[wfc.Date <= train_cutoff]
valid_df = wfc[(wfc.Date > train_cutoff) & (wfc.Date <= valid_cutoff)]
test_df = wfc[wfc.Date > valid_cutoff]

# %%
print("Dataset shape: {:s}".format(str(wfc.shape)))
print("Train dataset shape: {:s}".format(str(train_df.shape)))
print("Vaid dataset shape: {:s}".format(str(valid_df.shape)))
print("Test dataset shape: {:s}".format(str(test_df.shape)))
# Out:
# Dataset shape: (5754, 15)
# Train dataset shape: (4313, 15)
# Vaid dataset shape: (692, 15)
# Test dataset shape: (749, 15)

# %% [markdown]
# # Stock Price Graph

# %%
plt.figure(figsize=(18, 10))

plotSeries(train_df.Date, train_df.Close, "Training Data")
plotSeries(valid_df.Date, valid_df.Close, "Validation Data")
plotSeries(test_df.Date, test_df.Close, "Test Data")
plt.legend(loc='upper left')

# %% [markdown]
# # Saving The File

# %%
train_df.to_csv("Dataset/trainMultiDf.csv", index = False)
valid_df.to_csv("Dataset/validMultiDf.csv", index = False)
test_df.to_csv("Dataset/testMultiDf.csv", index = False)

# %%
train_df.head()
# Out:
#         Date  Close  Weekday  volumeChange  closeChange  EMA 10  EMA 20  \
# 0 2000-01-03  19.56        0         68.61        -4.95   19.56   19.56
# 1 2000-01-04  18.59        1        -46.00        -1.01   19.03   19.05
# 2 2000-01-05  18.41        2          1.20         4.41   18.78   18.82
# 3 2000-01-06  19.22        3         -7.39         1.79   18.92   18.93
# 4 2000-01-07  19.56        4         16.11        -3.19   19.11   19.08
#
#    EMA 50  EMA 100  ROC5  ROC10  ROC15  ROC20     DTB6    DGS5
# 0   19.56    19.56  0.00   0.00   0.00   0.00 50550.00 6050.00
# 1   19.07    19.07  0.00   0.00   0.00   0.00 50500.00 6040.00
# 2   18.84    18.85  0.00   0.00   0.00   0.00 50490.00 6051.00
# 3   18.94    18.94  0.00   0.00   0.00   0.00 50440.00 6046.00
# 4   19.07    19.07 -0.59   0.00   0.00   0.00 50420.00 6042.00
