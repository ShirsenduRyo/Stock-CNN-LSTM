# %% [markdown]
# # The Packages

# %%
import numpy as np
import pandas as pd
import os
import gc
import datetime
import warnings

# %%
import statsmodels.api as sm
from datetime import date

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
import tensorflow as tf
import math 
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LSTM
from tensorflow.keras import losses
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.utils import plot_model

# %%
tf.__version__
# Out:
# '2.10.1'

# %%
# DATA VISUALIZATION
# ------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (20.0, 10.0)
sns.set_style("darkgrid")
sns.color_palette("mako", as_cmap=True)
import plotly.express as px

# %%
# CONFIGURATIONS
# ------------------------------------------------------
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.2f}'.format
warnings.filterwarnings('ignore')

# %% [markdown]
# # Utility Functions

# %%
def plotSeries(time, series, lab,form='-'):
    plt.plot(time, series, form, label=lab)
    plt.xlabel("Date")
    plt.ylabel("Close Price")
    plt.grid(True)

# %% [markdown]
# # The Data

# %%
wfc = pd.read_csv('Dataset/WFC Daily1.csv')

# %%
wfc.head()
# Out:
#          Date  Open  High   Low  Close  Adj Close    Volume
# 0  2000-01-03 20.16 20.19 19.00  19.56      10.44   9037000
# 1  2000-01-04 18.62 18.84 18.00  18.59       9.92  15237200
# 2  2000-01-05 18.50 18.88 18.03  18.41       9.82   8228200
# 3  2000-01-06 18.53 19.50 18.47  19.22      10.25   8326800
# 4  2000-01-07 19.62 19.84 19.28  19.56      10.44   7711200

# %%
wfc.Date.dtype
# Out:
# dtype('O')

# %%
wfc['Date'] = pd.to_datetime(wfc['Date'])
#wfc.set_index(['Date'],inplace=True)

# %%
wfc.head()
# Out:
#         Date  Open  High   Low  Close  Adj Close    Volume
# 0 2000-01-03 20.16 20.19 19.00  19.56      10.44   9037000
# 1 2000-01-04 18.62 18.84 18.00  18.59       9.92  15237200
# 2 2000-01-05 18.50 18.88 18.03  18.41       9.82   8228200
# 3 2000-01-06 18.53 19.50 18.47  19.22      10.25   8326800
# 4 2000-01-07 19.62 19.84 19.28  19.56      10.44   7711200

# %%
wfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5754 entries, 0 to 5753
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5754 non-null   datetime64[ns]
#  1   Open       5754 non-null   float64
#  2   High       5754 non-null   float64
#  3   Low        5754 non-null   float64
#  4   Close      5754 non-null   float64
#  5   Adj Close  5754 non-null   float64
#  6   Volume     5754 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 314.8 KB

# %%
wfc.describe()
# Out:
#          Open    High     Low   Close  Adj Close       Volume
# count 5754.00 5754.00 5754.00 5754.00    5754.00      5754.00
# mean    36.38   36.78   35.98   36.38      28.01  24313450.19
# std     11.74   11.77   11.73   11.75      12.85  26705062.78
# min      8.65    8.94    7.80    8.12       5.76   1774000.00
# 25%     26.71   27.20   26.25   26.74      18.01  10091200.00
# 50%     32.65   33.13   32.25   32.64      23.18  17086600.00
# 75%     47.75   48.19   47.33   47.79      41.58  29145250.00
# max     65.89   66.31   65.66   65.93      57.96 478736600.00

# %%
correlation = wfc.corr ()  
correlation. style.background_gradient ()
# Out:
# <style type="text/css">
# #T_30473_row0_col0, #T_30473_row0_col1, #T_30473_row0_col2, #T_30473_row0_col3, #T_30473_row1_col0, #T_30473_row1_col1, #T_30473_row1_col2, #T_30473_row1_col3, #T_30473_row2_col0, #T_30473_row2_col1, #T_30473_row2_col2, #T_30473_row2_col3, #T_30473_row3_col0, #T_30473_row3_col1, #T_30473_row3_col2, #T_30473_row3_col3, #T_30473_row4_col4, #T_30473_row5_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_30473_row0_col4, #T_30473_row2_col4, #T_30473_row3_col4 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_30473_row0_col5, #T_30473_row3_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_30473_row1_col4, #T_30473_row4_col0, #T_30473_row4_col1, #T_30473_row4_col2, #T_30473_row4_col3 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_30473_row1_col5 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_30473_row2_col5, #T_30473_row5_col0, #T_30473_row5_col1, #T_30473_row5_col2, #T_30473_row5_col3, #T_30473_row5_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_30473_row4_col5 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# </style>
# <table id="T_30473">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30473_level0_col0" class="col_heading level0 col0" >Open</th>
#       <th id="T_30473_level0_col1" class="col_heading level0 col1" >High</th>
#       <th id="T_30473_level0_col2" class="col_heading level0 col2" >Low</th>
#       <th id="T_30473_level0_col3" class="col_heading level0 col3" >Close</th>
#       <th id="T_30473_level0_col4" class="col_heading level0 col4" >Adj Close</th>
#       <th id="T_30473_level0_col5" class="col_heading level0 col5" >Volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30473_level0_row0" class="row_heading level0 row0" >Open</th>
#       <td id="T_30473_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_30473_row0_col1" class="data row0 col1" >0.999324</td>
#       <td id="T_30473_row0_col2" class="data row0 col2" >0.999274</td>
#       <td id="T_30473_row0_col3" class="data row0 col3" >0.998754</td>
#       <td id="T_30473_row0_col4" class="data row0 col4" >0.965403</td>
#       <td id="T_30473_row0_col5" class="data row0 col5" >-0.184389</td>
#     </tr>
#     <tr>
#       <th id="T_30473_level0_row1" class="row_heading level0 row1" >High</th>
#       <td id="T_30473_row1_col0" class="data row1 col0" >0.999324</td>
#       <td id="T_30473_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_30473_row1_col2" class="data row1 col2" >0.998796</td>
#       <td id="T_30473_row1_col3" class="data row1 col3" >0.999323</td>
#       <td id="T_30473_row1_col4" class="data row1 col4" >0.967945</td>
#       <td id="T_30473_row1_col5" class="data row1 col5" >-0.169457</td>
#     </tr>
#     <tr>
#       <th id="T_30473_level0_row2" class="row_heading level0 row2" >Low</th>
#       <td id="T_30473_row2_col0" class="data row2 col0" >0.999274</td>
#       <td id="T_30473_row2_col1" class="data row2 col1" >0.998796</td>
#       <td id="T_30473_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_30473_row2_col3" class="data row2 col3" >0.999303</td>
#       <td id="T_30473_row2_col4" class="data row2 col4" >0.963519</td>
#       <td id="T_30473_row2_col5" class="data row2 col5" >-0.199335</td>
#     </tr>
#     <tr>
#       <th id="T_30473_level0_row3" class="row_heading level0 row3" >Close</th>
#       <td id="T_30473_row3_col0" class="data row3 col0" >0.998754</td>
#       <td id="T_30473_row3_col1" class="data row3 col1" >0.999323</td>
#       <td id="T_30473_row3_col2" class="data row3 col2" >0.999303</td>
#       <td id="T_30473_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_30473_row3_col4" class="data row3 col4" >0.966149</td>
#       <td id="T_30473_row3_col5" class="data row3 col5" >-0.183272</td>
#     </tr>
#     <tr>
#       <th id="T_30473_level0_row4" class="row_heading level0 row4" >Adj Close</th>
#       <td id="T_30473_row4_col0" class="data row4 col0" >0.965403</td>
#       <td id="T_30473_row4_col1" class="data row4 col1" >0.967945</td>
#       <td id="T_30473_row4_col2" class="data row4 col2" >0.963519</td>
#       <td id="T_30473_row4_col3" class="data row4 col3" >0.966149</td>
#       <td id="T_30473_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_30473_row4_col5" class="data row4 col5" >-0.080189</td>
#     </tr>
#     <tr>
#       <th id="T_30473_level0_row5" class="row_heading level0 row5" >Volume</th>
#       <td id="T_30473_row5_col0" class="data row5 col0" >-0.184389</td>
#       <td id="T_30473_row5_col1" class="data row5 col1" >-0.169457</td>
#       <td id="T_30473_row5_col2" class="data row5 col2" >-0.199335</td>
#       <td id="T_30473_row5_col3" class="data row5 col3" >-0.183272</td>
#       <td id="T_30473_row5_col4" class="data row5 col4" >-0.080189</td>
#       <td id="T_30473_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # The Split

# %%
min_date = wfc.Date.min()
max_date = wfc.Date.max()
print("Min:", min_date, "Max:", max_date)
# Out:
# Min: 2000-01-03 00:00:00 Max: 2022-11-11 00:00:00

# %%
train_percent = .75
valid_percent = .12

time_between = max_date - min_date

train_cutoff = min_date + train_percent*time_between
valid_cutoff = min_date + (train_percent + valid_percent)*time_between

print("Training Cutoff Date: {:s}".format(str(train_cutoff)))
print("Validation Cutoff Date: {:s}".format(str(valid_cutoff)))
# Out:
# Training Cutoff Date: 2017-02-23 00:00:00
# Validation Cutoff Date: 2019-11-21 18:14:24

# %%
train_df = wfc[wfc.Date <= train_cutoff]
valid_df = wfc[(wfc.Date > train_cutoff) & (wfc.Date <= valid_cutoff)]
test_df = wfc[wfc.Date > valid_cutoff]

# %%
print("Dataset shape: {:s}".format(str(wfc.shape)))
print("Train dataset shape: {:s}".format(str(train_df.shape)))
print("Vaid dataset shape: {:s}".format(str(valid_df.shape)))
print("Test dataset shape: {:s}".format(str(test_df.shape)))
# Out:
# Dataset shape: (5754, 7)
# Train dataset shape: (4313, 7)
# Vaid dataset shape: (692, 7)
# Test dataset shape: (749, 7)

# %% [markdown]
# # Stock Price Graph

# %%
plotSeries(train_df.Date, train_df.Close, "Training Data")
plotSeries(valid_df.Date, valid_df.Close, "Validation Data")
plotSeries(test_df.Date, test_df.Close, "Test Data")
plt.legend(loc='upper left')

# %%
train_df.set_index(['Date'],inplace=True)
test_df.set_index(['Date'],inplace=True)
valid_df.set_index(['Date'],inplace=True)

# %%
trainNorm = train_df.Close.values.reshape(-1, 1)
testNorm = test_df.Close.values.reshape(-1, 1)
validNorm = valid_df.Close.values.reshape(-1, 1)

# %%
trainNorm.shape
# Out:
# (4313, 1)

# %% [markdown]
# ## Windowed Dataset

# %%
mse_arr=[]
Z = []

window = 50

# %%
X_train= []
Y_train=[]
X_valid= []
Y_valid=[]
X_test= []
Y_test=[]

for i in range(len(trainNorm) - (window)):
    X_train.append(trainNorm[i:i+window])
    Y_train.append(trainNorm[i+window])
    
for i in range(len(validNorm) - (window)):
    X_valid.append(validNorm[i:i+window])
    Y_valid.append(validNorm[i+window])
    
for i in range(len(testNorm) - (window)):
    X_test.append(testNorm[i:i+window])
    Y_test.append(testNorm[i+window])
    

X_train=np.asanyarray(X_train)
Y_train=np.asanyarray(Y_train)
X_valid=np.asanyarray(X_valid)
Y_valid=np.asanyarray(Y_valid)
X_test=np.asanyarray(X_test)
Y_test=np.asanyarray(Y_test)

Xtrain = X_train[:,:,:]  
Ytrain = Y_train[:]  
Xvalid = X_valid[:,:,:]  
Yvalid= Y_valid[:]  
Xtest = X_test[:,:,:]  
Ytest= Y_test[:]

# %% [markdown]
# # Model Building

# %%
tf.keras.backend.clear_session()
model = tf.keras.Sequential()

# %%
model.add(keras.layers.SimpleRNN(40, return_sequences = True))
model.add(keras.layers.SimpleRNN(40))
model.add(tf.keras.layers.Dense(1))

# %% [markdown]
# ## Optimizing Learning Rate

# %%
# lrSchedule = tf.keras.callbacks.LearningRateScheduler(
#     lambda epoch:1e-8*10**(epoch/20))
# earlyStop = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10, restore_best_weights=True)

# %%
# model.compile(loss=tf.keras.losses.MeanSquaredError(),
#              optimizer = Adam(1e-8),
#              metrics = ["mae"])

# %%
# history = model.fit(Xtrain,Ytrain,batch_size=128, epochs=500, callbacks=[lrSchedule, earlyStop])

# %%
# plt.figure(figsize=(20,8))
# plt.semilogx(history.history["lr"], history.history["loss"])
# #plt.axis([1e-8, 1e-4, 0, 30])

# %%
# plt.semilogx(history.history["lr"], history.history["loss"])
# plt.axis([1e-3, 1e-1, 0, 200])

# %% [markdown]
# ## Final Model Build

# %%
tf.keras.backend.clear_session()

# %%
model.compile(loss=tf.keras.losses.MeanSquaredError(),
              optimizer=Adam(1e-2),
              metrics=['mae'])

# %%
log_dir = "logs\\" + datetime.datetime.now().strftime("%d-%m-%Y_%H%M%S")

tensorboard_callback = [
#                         tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1),
#                         ModelCheckpoint(model_path, verbose=1, save_best_only=True),
#                         ReduceLROnPlateau(monitor= "val_mae", factor=0.1, patience=5, min_lr=1e-7, verbose=1),
                        ReduceLROnPlateau(monitor='val_mae', factor=0.2,patience=5, min_lr=1e-6, verbose=1),
#                         CSVLogger(csv_path),
                        TensorBoard(),
                        EarlyStopping(monitor= "val_mae", patience=10, restore_best_weights=True)
                       ]

# %%
history = model.fit(Xtrain, Ytrain,batch_size=128, epochs=500, verbose=1,validation_data=(Xvalid, Yvalid), callbacks=tensorboard_callback)
# Out:
# Epoch 1/500
# 34/34 [==============================] - 8s 150ms/step - loss: 671.6966 - mae: 23.4634 - val_loss: 1300.8774 - val_mae: 35.7834 - lr: 0.0100
# Epoch 2/500
# 34/34 [==============================] - 5s 158ms/step - loss: 241.7390 - mae: 11.8955 - val_loss: 699.9197 - val_mae: 26.0671 - lr: 0.0100
# Epoch 3/500
# 34/34 [==============================] - 5s 144ms/step - loss: 123.1284 - mae: 7.8821 - val_loss: 471.6454 - val_mae: 21.2419 - lr: 0.0100
# Epoch 4/500
# 34/34 [==============================] - 5s 152ms/step - loss: 105.5592 - mae: 7.8920 - val_loss: 404.9977 - val_mae: 19.6105 - lr: 0.0100
# Epoch 5/500
# 34/34 [==============================] - 5s 161ms/step - loss: 84.2267 - mae: 6.4310 - val_loss: 340.6906 - val_mae: 17.8962 - lr: 0.0100
# Epoch 6/500
# 34/34 [==============================] - 5s 143ms/step - loss: 50.8331 - mae: 4.1840 - val_loss: 221.1137 - val_mae: 14.1667 - lr: 0.0100
# Epoch 7/500
# 34/34 [==============================] - 5s 154ms/step - loss: 27.9423 - mae: 2.6672 - val_loss: 137.3041 - val_mae: 10.8112 - lr: 0.0100
# Epoch 8/500
# 34/34 [==============================] - 5s 154ms/step - loss: 16.5638 - mae: 2.1241 - val_loss: 86.9055 - val_mae: 8.1660 - lr: 0.0100
# Epoch 9/500
# 34/34 [==============================] - 5s 154ms/step - loss: 9.9475 - mae: 1.5669 - val_loss: 57.7643 - val_mae: 6.2745 - lr: 0.0100
# Epoch 10/500
# 34/34 [==============================] - 5s 144ms/step - loss: 6.4143 - mae: 1.3308 - val_loss: 40.8661 - val_mae: 5.0379 - lr: 0.0100
# Epoch 11/500
# 34/34 [==============================] - 5s 154ms/step - loss: 4.2643 - mae: 1.0493 - val_loss: 29.7371 - val_mae: 4.0938 - lr: 0.0100
# Epoch 12/500
# 34/34 [==============================] - 5s 156ms/step - loss: 3.0681 - mae: 0.9478 - val_loss: 22.7669 - val_mae: 3.4196 - lr: 0.0100
# Epoch 13/500
# 34/34 [==============================] - 5s 152ms/step - loss: 2.2826 - mae: 0.8385 - val_loss: 18.1337 - val_mae: 2.9340 - lr: 0.0100
# Epoch 14/500
# 34/34 [==============================] - 5s 160ms/step - loss: 1.9100 - mae: 0.8485 - val_loss: 14.8046 - val_mae: 2.5529 - lr: 0.0100
# Epoch 15/500
# 34/34 [==============================] - 5s 156ms/step - loss: 1.4673 - mae: 0.7230 - val_loss: 12.3882 - val_mae: 2.2498 - lr: 0.0100
# Epoch 16/500
# 34/34 [==============================] - 5s 159ms/step - loss: 1.3007 - mae: 0.7323 - val_loss: 10.9166 - val_mae: 2.0983 - lr: 0.0100
# Epoch 17/500
# 34/34 [==============================] - 5s 155ms/step - loss: 1.1734 - mae: 0.7157 - val_loss: 9.4197 - val_mae: 1.8543 - lr: 0.0100
# Epoch 18/500
# 34/34 [==============================] - 5s 151ms/step - loss: 0.9236 - mae: 0.6082 - val_loss: 8.5601 - val_mae: 1.8079 - lr: 0.0100
# Epoch 19/500
# 34/34 [==============================] - 5s 144ms/step - loss: 0.8304 - mae: 0.5823 - val_loss: 7.6226 - val_mae: 1.6157 - lr: 0.0100
# Epoch 20/500
# 34/34 [==============================] - 5s 150ms/step - loss: 0.7748 - mae: 0.5675 - val_loss: 7.2292 - val_mae: 1.6635 - lr: 0.0100
# Epoch 21/500
# 34/34 [==============================] - 5s 146ms/step - loss: 0.8158 - mae: 0.6233 - val_loss: 6.4619 - val_mae: 1.4482 - lr: 0.0100
# Epoch 22/500
# 34/34 [==============================] - 5s 145ms/step - loss: 0.7849 - mae: 0.6202 - val_loss: 6.1947 - val_mae: 1.4529 - lr: 0.0100
# Epoch 23/500
# 34/34 [==============================] - 5s 157ms/step - loss: 0.7399 - mae: 0.5823 - val_loss: 5.9085 - val_mae: 1.4066 - lr: 0.0100
# Epoch 24/500
# 34/34 [==============================] - 5s 133ms/step - loss: 0.7608 - mae: 0.6149 - val_loss: 5.7736 - val_mae: 1.4866 - lr: 0.0100
# Epoch 25/500
# 34/34 [==============================] - 5s 156ms/step - loss: 0.7945 - mae: 0.6457 - val_loss: 5.6406 - val_mae: 1.5243 - lr: 0.0100
# Epoch 26/500
# 34/34 [==============================] - 5s 153ms/step - loss: 0.5768 - mae: 0.5074 - val_loss: 4.8176 - val_mae: 1.2219 - lr: 0.0100
# Epoch 27/500
# 34/34 [==============================] - 5s 153ms/step - loss: 0.6078 - mae: 0.5254 - val_loss: 4.6156 - val_mae: 1.1908 - lr: 0.0100
# Epoch 28/500
# 34/34 [==============================] - 5s 161ms/step - loss: 0.6977 - mae: 0.5993 - val_loss: 4.8186 - val_mae: 1.3230 - lr: 0.0100
# Epoch 29/500
# 34/34 [==============================] - 5s 159ms/step - loss: 0.7253 - mae: 0.6041 - val_loss: 4.6047 - val_mae: 1.2738 - lr: 0.0100
# Epoch 30/500
# 34/34 [==============================] - 5s 157ms/step - loss: 0.6634 - mae: 0.5761 - val_loss: 4.8411 - val_mae: 1.4145 - lr: 0.0100
# Epoch 31/500
# 34/34 [==============================] - 5s 146ms/step - loss: 0.6196 - mae: 0.5410 - val_loss: 4.5035 - val_mae: 1.3045 - lr: 0.0100
# Epoch 32/500
# 34/34 [==============================] - 5s 158ms/step - loss: 0.6391 - mae: 0.5725 - val_loss: 4.0552 - val_mae: 1.1127 - lr: 0.0100
# Epoch 33/500
# 34/34 [==============================] - 5s 149ms/step - loss: 0.6102 - mae: 0.5562 - val_loss: 4.0250 - val_mae: 1.1435 - lr: 0.0100
# Epoch 34/500
# 34/34 [==============================] - 5s 158ms/step - loss: 0.6459 - mae: 0.5663 - val_loss: 4.2580 - val_mae: 1.2884 - lr: 0.0100
# Epoch 35/500
# 34/34 [==============================] - 5s 149ms/step - loss: 0.5767 - mae: 0.5234 - val_loss: 4.1755 - val_mae: 1.3081 - lr: 0.0100
# Epoch 36/500
# 34/34 [==============================] - 6s 163ms/step - loss: 0.6080 - mae: 0.5506 - val_loss: 3.9194 - val_mae: 1.2033 - lr: 0.0100
# Epoch 37/500
# 34/34 [==============================] - 5s 156ms/step - loss: 0.7365 - mae: 0.6284 - val_loss: 3.7177 - val_mae: 1.0917 - lr: 0.0100
# Epoch 38/500
# 34/34 [==============================] - 5s 154ms/step - loss: 0.6807 - mae: 0.5942 - val_loss: 3.6475 - val_mae: 1.0709 - lr: 0.0100
# Epoch 39/500
# 34/34 [==============================] - 5s 156ms/step - loss: 0.5648 - mae: 0.5172 - val_loss: 3.5262 - val_mae: 1.0526 - lr: 0.0100
# Epoch 40/500
# 34/34 [==============================] - 5s 158ms/step - loss: 0.5414 - mae: 0.5117 - val_loss: 3.4225 - val_mae: 1.0315 - lr: 0.0100
# Epoch 41/500
# 34/34 [==============================] - 5s 160ms/step - loss: 0.5933 - mae: 0.5457 - val_loss: 3.5996 - val_mae: 1.1740 - lr: 0.0100
# Epoch 42/500
# 34/34 [==============================] - 5s 143ms/step - loss: 0.5639 - mae: 0.5222 - val_loss: 3.3416 - val_mae: 1.0366 - lr: 0.0100
# Epoch 43/500
# 34/34 [==============================] - 5s 151ms/step - loss: 0.5427 - mae: 0.4994 - val_loss: 4.5368 - val_mae: 1.6132 - lr: 0.0100
# Epoch 44/500
# 34/34 [==============================] - 5s 154ms/step - loss: 0.6554 - mae: 0.5756 - val_loss: 3.3310 - val_mae: 1.0516 - lr: 0.0100
# Epoch 45/500
# 34/34 [==============================] - 5s 153ms/step - loss: 0.6599 - mae: 0.5807 - val_loss: 3.2474 - val_mae: 1.0128 - lr: 0.0100
# Epoch 46/500
# 34/34 [==============================] - 5s 150ms/step - loss: 0.6537 - mae: 0.5772 - val_loss: 3.2346 - val_mae: 1.0167 - lr: 0.0100
# Epoch 47/500
# 34/34 [==============================] - 5s 150ms/step - loss: 0.5234 - mae: 0.4900 - val_loss: 3.1534 - val_mae: 0.9977 - lr: 0.0100
# Epoch 48/500
# 34/34 [==============================] - 5s 140ms/step - loss: 0.5198 - mae: 0.4920 - val_loss: 3.0754 - val_mae: 0.9850 - lr: 0.0100
# Epoch 49/500
# 34/34 [==============================] - 5s 155ms/step - loss: 0.5164 - mae: 0.4856 - val_loss: 2.9802 - val_mae: 0.9535 - lr: 0.0100
# Epoch 50/500
# 34/34 [==============================] - 5s 145ms/step - loss: 0.4987 - mae: 0.4819 - val_loss: 2.9513 - val_mae: 0.9612 - lr: 0.0100
# Epoch 51/500
# 34/34 [==============================] - 5s 156ms/step - loss: 0.5630 - mae: 0.5351 - val_loss: 2.9562 - val_mae: 1.0006 - lr: 0.0100
# Epoch 52/500
# 34/34 [==============================] - 5s 160ms/step - loss: 0.6238 - mae: 0.5667 - val_loss: 2.8056 - val_mae: 0.9394 - lr: 0.0100
# Epoch 53/500
# 34/34 [==============================] - 5s 157ms/step - loss: 0.6734 - mae: 0.6048 - val_loss: 2.8958 - val_mae: 0.9630 - lr: 0.0100
# Epoch 54/500
# 34/34 [==============================] - 6s 162ms/step - loss: 0.5204 - mae: 0.4989 - val_loss: 2.7500 - val_mae: 0.9278 - lr: 0.0100
# Epoch 55/500
# 34/34 [==============================] - 5s 159ms/step - loss: 0.5503 - mae: 0.5238 - val_loss: 3.1767 - val_mae: 1.1873 - lr: 0.0100
# Epoch 56/500
# 34/34 [==============================] - 5s 149ms/step - loss: 0.5975 - mae: 0.5393 - val_loss: 3.0706 - val_mae: 1.0630 - lr: 0.0100
# Epoch 57/500
# 34/34 [==============================] - 5s 144ms/step - loss: 0.5577 - mae: 0.5266 - val_loss: 2.7901 - val_mae: 0.9198 - lr: 0.0100
# Epoch 58/500
# 34/34 [==============================] - 5s 149ms/step - loss: 0.5818 - mae: 0.5470 - val_loss: 3.1097 - val_mae: 1.1057 - lr: 0.0100
# Epoch 59/500
# 34/34 [==============================] - 5s 156ms/step - loss: 0.6385 - mae: 0.5742 - val_loss: 2.8616 - val_mae: 0.9502 - lr: 0.0100
# Epoch 60/500
# 34/34 [==============================] - 5s 150ms/step - loss: 0.5288 - mae: 0.5037 - val_loss: 3.0019 - val_mae: 1.0682 - lr: 0.0100
# Epoch 61/500
# 34/34 [==============================] - 5s 151ms/step - loss: 0.5737 - mae: 0.5336 - val_loss: 3.0225 - val_mae: 1.1127 - lr: 0.0100
# Epoch 62/500
# 34/34 [==============================] - ETA: 0s - loss: 0.5340 - mae: 0.5061
# Epoch 62: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 34/34 [==============================] - 5s 158ms/step - loss: 0.5340 - mae: 0.5061 - val_loss: 2.8433 - val_mae: 1.0146 - lr: 0.0100
# Epoch 63/500
# 34/34 [==============================] - 5s 158ms/step - loss: 0.4661 - mae: 0.4581 - val_loss: 2.8293 - val_mae: 1.0434 - lr: 0.0020
# Epoch 64/500
# 34/34 [==============================] - 4s 123ms/step - loss: 0.4443 - mae: 0.4413 - val_loss: 2.6253 - val_mae: 0.8947 - lr: 0.0020
# Epoch 65/500
# 34/34 [==============================] - 5s 143ms/step - loss: 0.4268 - mae: 0.4280 - val_loss: 2.5860 - val_mae: 0.8926 - lr: 0.0020
# Epoch 66/500
# 34/34 [==============================] - 5s 156ms/step - loss: 0.4343 - mae: 0.4357 - val_loss: 2.5774 - val_mae: 0.8864 - lr: 0.0020
# Epoch 67/500
# 34/34 [==============================] - 5s 152ms/step - loss: 0.4284 - mae: 0.4327 - val_loss: 2.5575 - val_mae: 0.8787 - lr: 0.0020
# Epoch 68/500
# 34/34 [==============================] - 5s 152ms/step - loss: 0.4327 - mae: 0.4290 - val_loss: 2.5418 - val_mae: 0.8844 - lr: 0.0020
# Epoch 69/500
# 34/34 [==============================] - 5s 154ms/step - loss: 0.4325 - mae: 0.4358 - val_loss: 2.5815 - val_mae: 0.9277 - lr: 0.0020
# Epoch 70/500
# 34/34 [==============================] - 5s 151ms/step - loss: 0.4358 - mae: 0.4402 - val_loss: 2.5125 - val_mae: 0.8693 - lr: 0.0020
# Epoch 71/500
# 34/34 [==============================] - 5s 160ms/step - loss: 0.4320 - mae: 0.4388 - val_loss: 2.4943 - val_mae: 0.8718 - lr: 0.0020
# Epoch 72/500
# 34/34 [==============================] - 5s 156ms/step - loss: 0.4297 - mae: 0.4310 - val_loss: 2.4804 - val_mae: 0.8668 - lr: 0.0020
# Epoch 73/500
# 34/34 [==============================] - 5s 159ms/step - loss: 0.4276 - mae: 0.4295 - val_loss: 2.4645 - val_mae: 0.8650 - lr: 0.0020
# Epoch 74/500
# 34/34 [==============================] - 6s 165ms/step - loss: 0.4250 - mae: 0.4314 - val_loss: 2.4566 - val_mae: 0.8596 - lr: 0.0020
# Epoch 75/500
# 34/34 [==============================] - 5s 158ms/step - loss: 0.4284 - mae: 0.4340 - val_loss: 2.5309 - val_mae: 0.9227 - lr: 0.0020
# Epoch 76/500
# 34/34 [==============================] - 5s 153ms/step - loss: 0.4267 - mae: 0.4296 - val_loss: 2.4457 - val_mae: 0.8656 - lr: 0.0020
# Epoch 77/500
# 34/34 [==============================] - 5s 153ms/step - loss: 0.4259 - mae: 0.4326 - val_loss: 2.4553 - val_mae: 0.8854 - lr: 0.0020
# Epoch 78/500
# 34/34 [==============================] - 6s 164ms/step - loss: 0.4355 - mae: 0.4363 - val_loss: 2.4057 - val_mae: 0.8514 - lr: 0.0020
# Epoch 79/500
# 34/34 [==============================] - 5s 162ms/step - loss: 0.4472 - mae: 0.4511 - val_loss: 2.4019 - val_mae: 0.8569 - lr: 0.0020
# Epoch 80/500
# 34/34 [==============================] - 6s 166ms/step - loss: 0.4596 - mae: 0.4628 - val_loss: 2.4725 - val_mae: 0.9017 - lr: 0.0020
# Epoch 81/500
# 34/34 [==============================] - 6s 166ms/step - loss: 0.4463 - mae: 0.4482 - val_loss: 2.3928 - val_mae: 0.8498 - lr: 0.0020
# Epoch 82/500
# 34/34 [==============================] - 5s 156ms/step - loss: 0.4472 - mae: 0.4526 - val_loss: 2.3846 - val_mae: 0.8511 - lr: 0.0020
# Epoch 83/500
# 34/34 [==============================] - 6s 163ms/step - loss: 0.4242 - mae: 0.4296 - val_loss: 2.3585 - val_mae: 0.8439 - lr: 0.0020
# Epoch 84/500
# 34/34 [==============================] - 5s 160ms/step - loss: 0.4282 - mae: 0.4338 - val_loss: 2.3721 - val_mae: 0.8508 - lr: 0.0020
# Epoch 85/500
# 34/34 [==============================] - 5s 157ms/step - loss: 0.4430 - mae: 0.4485 - val_loss: 2.5342 - val_mae: 0.9590 - lr: 0.0020
# Epoch 86/500
# 34/34 [==============================] - 5s 160ms/step - loss: 0.4336 - mae: 0.4405 - val_loss: 2.3563 - val_mae: 0.8575 - lr: 0.0020
# Epoch 87/500
# 34/34 [==============================] - 5s 159ms/step - loss: 0.4348 - mae: 0.4431 - val_loss: 2.3866 - val_mae: 0.8833 - lr: 0.0020
# Epoch 88/500
# 34/34 [==============================] - 5s 153ms/step - loss: 0.4470 - mae: 0.4509 - val_loss: 2.3293 - val_mae: 0.8404 - lr: 0.0020
# Epoch 89/500
# 34/34 [==============================] - 5s 157ms/step - loss: 0.4298 - mae: 0.4374 - val_loss: 2.3071 - val_mae: 0.8381 - lr: 0.0020
# Epoch 90/500
# 34/34 [==============================] - 5s 161ms/step - loss: 0.4351 - mae: 0.4431 - val_loss: 2.3272 - val_mae: 0.8561 - lr: 0.0020
# Epoch 91/500
# 34/34 [==============================] - 5s 157ms/step - loss: 0.4264 - mae: 0.4346 - val_loss: 2.2912 - val_mae: 0.8337 - lr: 0.0020
# Epoch 92/500
# 34/34 [==============================] - 5s 160ms/step - loss: 0.4351 - mae: 0.4408 - val_loss: 2.3258 - val_mae: 0.8658 - lr: 0.0020
# Epoch 93/500
# 34/34 [==============================] - 5s 150ms/step - loss: 0.4518 - mae: 0.4555 - val_loss: 2.2815 - val_mae: 0.8299 - lr: 0.0020
# Epoch 94/500
# 34/34 [==============================] - 5s 157ms/step - loss: 0.4298 - mae: 0.4395 - val_loss: 2.2950 - val_mae: 0.8507 - lr: 0.0020
# Epoch 95/500
# 34/34 [==============================] - 5s 151ms/step - loss: 0.4319 - mae: 0.4380 - val_loss: 2.2648 - val_mae: 0.8301 - lr: 0.0020
# Epoch 96/500
# 34/34 [==============================] - 5s 146ms/step - loss: 0.4369 - mae: 0.4450 - val_loss: 2.2862 - val_mae: 0.8511 - lr: 0.0020
# Epoch 97/500
# 34/34 [==============================] - 5s 156ms/step - loss: 0.4309 - mae: 0.4377 - val_loss: 2.2399 - val_mae: 0.8240 - lr: 0.0020
# Epoch 98/500
# 34/34 [==============================] - 5s 149ms/step - loss: 0.4249 - mae: 0.4323 - val_loss: 2.2585 - val_mae: 0.8488 - lr: 0.0020
# Epoch 99/500
# 34/34 [==============================] - 5s 157ms/step - loss: 0.4369 - mae: 0.4436 - val_loss: 2.2630 - val_mae: 0.8438 - lr: 0.0020
# Epoch 100/500
# 34/34 [==============================] - 5s 153ms/step - loss: 0.4355 - mae: 0.4454 - val_loss: 2.4112 - val_mae: 0.9610 - lr: 0.0020
# Epoch 101/500
# 34/34 [==============================] - 5s 154ms/step - loss: 0.4476 - mae: 0.4502 - val_loss: 2.3272 - val_mae: 0.8920 - lr: 0.0020
# Epoch 102/500
# 34/34 [==============================] - ETA: 0s - loss: 0.4415 - mae: 0.4498
# Epoch 102: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# 34/34 [==============================] - 5s 159ms/step - loss: 0.4415 - mae: 0.4498 - val_loss: 2.3176 - val_mae: 0.9020 - lr: 0.0020
# Epoch 103/500
# 34/34 [==============================] - 5s 158ms/step - loss: 0.4147 - mae: 0.4257 - val_loss: 2.2302 - val_mae: 0.8367 - lr: 4.0000e-04
# Epoch 104/500
# 34/34 [==============================] - 6s 164ms/step - loss: 0.4031 - mae: 0.4174 - val_loss: 2.2082 - val_mae: 0.8219 - lr: 4.0000e-04
# Epoch 105/500
# 34/34 [==============================] - 5s 154ms/step - loss: 0.4021 - mae: 0.4171 - val_loss: 2.1998 - val_mae: 0.8176 - lr: 4.0000e-04
# Epoch 106/500
# 34/34 [==============================] - 5s 144ms/step - loss: 0.4052 - mae: 0.4205 - val_loss: 2.1983 - val_mae: 0.8180 - lr: 4.0000e-04
# Epoch 107/500
# 34/34 [==============================] - 5s 147ms/step - loss: 0.4048 - mae: 0.4207 - val_loss: 2.1991 - val_mae: 0.8178 - lr: 4.0000e-04
# Epoch 108/500
# 34/34 [==============================] - 5s 140ms/step - loss: 0.4028 - mae: 0.4165 - val_loss: 2.2018 - val_mae: 0.8248 - lr: 4.0000e-04
# Epoch 109/500
# 34/34 [==============================] - 5s 159ms/step - loss: 0.4053 - mae: 0.4198 - val_loss: 2.2142 - val_mae: 0.8330 - lr: 4.0000e-04
# Epoch 110/500
# 34/34 [==============================] - ETA: 0s - loss: 0.4089 - mae: 0.4221
# Epoch 110: ReduceLROnPlateau reducing learning rate to 7.999999215826393e-05.
# 34/34 [==============================] - 5s 155ms/step - loss: 0.4089 - mae: 0.4221 - val_loss: 2.1973 - val_mae: 0.8217 - lr: 4.0000e-04
# Epoch 111/500
# 34/34 [==============================] - 5s 151ms/step - loss: 0.3993 - mae: 0.4145 - val_loss: 2.1917 - val_mae: 0.8175 - lr: 8.0000e-05
# Epoch 112/500
# 34/34 [==============================] - 5s 151ms/step - loss: 0.3984 - mae: 0.4131 - val_loss: 2.1875 - val_mae: 0.8147 - lr: 8.0000e-05
# Epoch 113/500
# 34/34 [==============================] - 5s 142ms/step - loss: 0.3980 - mae: 0.4127 - val_loss: 2.1865 - val_mae: 0.8142 - lr: 8.0000e-05
# Epoch 114/500
# 34/34 [==============================] - 5s 150ms/step - loss: 0.3981 - mae: 0.4134 - val_loss: 2.1874 - val_mae: 0.8151 - lr: 8.0000e-05
# Epoch 115/500
# 34/34 [==============================] - 5s 148ms/step - loss: 0.3974 - mae: 0.4126 - val_loss: 2.1847 - val_mae: 0.8137 - lr: 8.0000e-05
# Epoch 116/500
# 34/34 [==============================] - 5s 136ms/step - loss: 0.3979 - mae: 0.4130 - val_loss: 2.1859 - val_mae: 0.8147 - lr: 8.0000e-05
# Epoch 117/500
# 34/34 [==============================] - 4s 128ms/step - loss: 0.3983 - mae: 0.4140 - val_loss: 2.1848 - val_mae: 0.8141 - lr: 8.0000e-05
# Epoch 118/500
# 34/34 [==============================] - 4s 129ms/step - loss: 0.3979 - mae: 0.4135 - val_loss: 2.1849 - val_mae: 0.8144 - lr: 8.0000e-05
# Epoch 119/500
# 34/34 [==============================] - 5s 133ms/step - loss: 0.3979 - mae: 0.4131 - val_loss: 2.1836 - val_mae: 0.8135 - lr: 8.0000e-05
# Epoch 120/500
# 34/34 [==============================] - 5s 141ms/step - loss: 0.3975 - mae: 0.4133 - val_loss: 2.1828 - val_mae: 0.8134 - lr: 8.0000e-05
# Epoch 121/500
# 34/34 [==============================] - 5s 145ms/step - loss: 0.3983 - mae: 0.4137 - val_loss: 2.1832 - val_mae: 0.8141 - lr: 8.0000e-05
# Epoch 122/500
# 34/34 [==============================] - 4s 131ms/step - loss: 0.3979 - mae: 0.4138 - val_loss: 2.1815 - val_mae: 0.8132 - lr: 8.0000e-05
# Epoch 123/500
# 34/34 [==============================] - 5s 150ms/step - loss: 0.3978 - mae: 0.4128 - val_loss: 2.1814 - val_mae: 0.8133 - lr: 8.0000e-05
# Epoch 124/500
# 34/34 [==============================] - 5s 148ms/step - loss: 0.3978 - mae: 0.4125 - val_loss: 2.1811 - val_mae: 0.8137 - lr: 8.0000e-05
# Epoch 125/500
# 34/34 [==============================] - 5s 150ms/step - loss: 0.3976 - mae: 0.4130 - val_loss: 2.1812 - val_mae: 0.8141 - lr: 8.0000e-05
# Epoch 126/500
# 34/34 [==============================] - 5s 142ms/step - loss: 0.3976 - mae: 0.4127 - val_loss: 2.1801 - val_mae: 0.8136 - lr: 8.0000e-05
# Epoch 127/500
# 34/34 [==============================] - 5s 142ms/step - loss: 0.3976 - mae: 0.4135 - val_loss: 2.1800 - val_mae: 0.8130 - lr: 8.0000e-05
# Epoch 128/500
# 34/34 [==============================] - 5s 144ms/step - loss: 0.3975 - mae: 0.4127 - val_loss: 2.1782 - val_mae: 0.8128 - lr: 8.0000e-05
# Epoch 129/500
# 34/34 [==============================] - 5s 150ms/step - loss: 0.3984 - mae: 0.4138 - val_loss: 2.1804 - val_mae: 0.8142 - lr: 8.0000e-05
# Epoch 130/500
# 34/34 [==============================] - 5s 146ms/step - loss: 0.3980 - mae: 0.4136 - val_loss: 2.1795 - val_mae: 0.8140 - lr: 8.0000e-05
# Epoch 131/500
# 34/34 [==============================] - 5s 148ms/step - loss: 0.3978 - mae: 0.4132 - val_loss: 2.1776 - val_mae: 0.8128 - lr: 8.0000e-05
# Epoch 132/500
# 34/34 [==============================] - 5s 151ms/step - loss: 0.3982 - mae: 0.4133 - val_loss: 2.1758 - val_mae: 0.8125 - lr: 8.0000e-05
# Epoch 133/500
# 34/34 [==============================] - 4s 133ms/step - loss: 0.3978 - mae: 0.4137 - val_loss: 2.1758 - val_mae: 0.8121 - lr: 8.0000e-05
# Epoch 134/500
# 34/34 [==============================] - 5s 142ms/step - loss: 0.3976 - mae: 0.4128 - val_loss: 2.1748 - val_mae: 0.8124 - lr: 8.0000e-05
# Epoch 135/500
# 34/34 [==============================] - 5s 144ms/step - loss: 0.3982 - mae: 0.4136 - val_loss: 2.1732 - val_mae: 0.8117 - lr: 8.0000e-05
# Epoch 136/500
# 34/34 [==============================] - 5s 145ms/step - loss: 0.3972 - mae: 0.4124 - val_loss: 2.1731 - val_mae: 0.8117 - lr: 8.0000e-05
# Epoch 137/500
# 34/34 [==============================] - 5s 153ms/step - loss: 0.3983 - mae: 0.4144 - val_loss: 2.1714 - val_mae: 0.8116 - lr: 8.0000e-05
# Epoch 138/500
# 34/34 [==============================] - 5s 156ms/step - loss: 0.3971 - mae: 0.4131 - val_loss: 2.1755 - val_mae: 0.8148 - lr: 8.0000e-05
# Epoch 139/500
# 34/34 [==============================] - 5s 148ms/step - loss: 0.3983 - mae: 0.4137 - val_loss: 2.1728 - val_mae: 0.8124 - lr: 8.0000e-05
# Epoch 140/500
# 34/34 [==============================] - 5s 150ms/step - loss: 0.3982 - mae: 0.4132 - val_loss: 2.1701 - val_mae: 0.8111 - lr: 8.0000e-05
# Epoch 141/500
# 34/34 [==============================] - 5s 152ms/step - loss: 0.3985 - mae: 0.4137 - val_loss: 2.1698 - val_mae: 0.8113 - lr: 8.0000e-05
# Epoch 142/500
# 34/34 [==============================] - 5s 146ms/step - loss: 0.3985 - mae: 0.4150 - val_loss: 2.1798 - val_mae: 0.8202 - lr: 8.0000e-05
# Epoch 143/500
# 34/34 [==============================] - 5s 149ms/step - loss: 0.3981 - mae: 0.4142 - val_loss: 2.1670 - val_mae: 0.8108 - lr: 8.0000e-05
# Epoch 144/500
# 34/34 [==============================] - 5s 156ms/step - loss: 0.3980 - mae: 0.4133 - val_loss: 2.1694 - val_mae: 0.8115 - lr: 8.0000e-05
# Epoch 145/500
# 34/34 [==============================] - 5s 152ms/step - loss: 0.3977 - mae: 0.4139 - val_loss: 2.1701 - val_mae: 0.8134 - lr: 8.0000e-05
# Epoch 146/500
# 34/34 [==============================] - 5s 153ms/step - loss: 0.3980 - mae: 0.4139 - val_loss: 2.1653 - val_mae: 0.8109 - lr: 8.0000e-05
# Epoch 147/500
# 34/34 [==============================] - 5s 153ms/step - loss: 0.3973 - mae: 0.4130 - val_loss: 2.1648 - val_mae: 0.8098 - lr: 8.0000e-05
# Epoch 148/500
# 34/34 [==============================] - 5s 148ms/step - loss: 0.3979 - mae: 0.4139 - val_loss: 2.1650 - val_mae: 0.8105 - lr: 8.0000e-05
# Epoch 149/500
# 34/34 [==============================] - 5s 150ms/step - loss: 0.3977 - mae: 0.4129 - val_loss: 2.1657 - val_mae: 0.8120 - lr: 8.0000e-05
# Epoch 150/500
# 34/34 [==============================] - 5s 146ms/step - loss: 0.3984 - mae: 0.4142 - val_loss: 2.1647 - val_mae: 0.8105 - lr: 8.0000e-05
# Epoch 151/500
# 34/34 [==============================] - 5s 147ms/step - loss: 0.3975 - mae: 0.4134 - val_loss: 2.1662 - val_mae: 0.8128 - lr: 8.0000e-05
# Epoch 152/500
# 34/34 [==============================] - ETA: 0s - loss: 0.3972 - mae: 0.4128
# Epoch 152: ReduceLROnPlateau reducing learning rate to 1.599999814061448e-05.
# 34/34 [==============================] - 5s 149ms/step - loss: 0.3972 - mae: 0.4128 - val_loss: 2.1651 - val_mae: 0.8134 - lr: 8.0000e-05
# Epoch 153/500
# 34/34 [==============================] - 5s 148ms/step - loss: 0.3974 - mae: 0.4129 - val_loss: 2.1602 - val_mae: 0.8097 - lr: 1.6000e-05
# Epoch 154/500
# 34/34 [==============================] - 5s 150ms/step - loss: 0.3960 - mae: 0.4124 - val_loss: 2.1605 - val_mae: 0.8097 - lr: 1.6000e-05
# Epoch 155/500
# 34/34 [==============================] - 5s 142ms/step - loss: 0.3961 - mae: 0.4122 - val_loss: 2.1601 - val_mae: 0.8095 - lr: 1.6000e-05
# Epoch 156/500
# 34/34 [==============================] - 5s 153ms/step - loss: 0.3960 - mae: 0.4119 - val_loss: 2.1599 - val_mae: 0.8095 - lr: 1.6000e-05
# Epoch 157/500
# 34/34 [==============================] - 5s 153ms/step - loss: 0.3959 - mae: 0.4120 - val_loss: 2.1597 - val_mae: 0.8096 - lr: 1.6000e-05
# Epoch 158/500
# 34/34 [==============================] - 5s 150ms/step - loss: 0.3960 - mae: 0.4125 - val_loss: 2.1593 - val_mae: 0.8093 - lr: 1.6000e-05
# Epoch 159/500
# 34/34 [==============================] - 5s 139ms/step - loss: 0.3961 - mae: 0.4119 - val_loss: 2.1594 - val_mae: 0.8094 - lr: 1.6000e-05
# Epoch 160/500
# 34/34 [==============================] - 5s 154ms/step - loss: 0.3960 - mae: 0.4120 - val_loss: 2.1601 - val_mae: 0.8096 - lr: 1.6000e-05
# Epoch 161/500
# 34/34 [==============================] - 5s 144ms/step - loss: 0.3958 - mae: 0.4119 - val_loss: 2.1594 - val_mae: 0.8095 - lr: 1.6000e-05
# Epoch 162/500
# 34/34 [==============================] - 5s 144ms/step - loss: 0.3958 - mae: 0.4119 - val_loss: 2.1589 - val_mae: 0.8093 - lr: 1.6000e-05
# Epoch 163/500
# 34/34 [==============================] - ETA: 0s - loss: 0.3959 - mae: 0.4119
# Epoch 163: ReduceLROnPlateau reducing learning rate to 3.199999628122896e-06.
# 34/34 [==============================] - 5s 149ms/step - loss: 0.3959 - mae: 0.4119 - val_loss: 2.1587 - val_mae: 0.8093 - lr: 1.6000e-05
# Epoch 164/500
# 34/34 [==============================] - 5s 146ms/step - loss: 0.3956 - mae: 0.4118 - val_loss: 2.1588 - val_mae: 0.8094 - lr: 3.2000e-06
# Epoch 165/500
# 34/34 [==============================] - 5s 151ms/step - loss: 0.3956 - mae: 0.4118 - val_loss: 2.1587 - val_mae: 0.8093 - lr: 3.2000e-06
# Epoch 166/500
# 34/34 [==============================] - 5s 133ms/step - loss: 0.3956 - mae: 0.4117 - val_loss: 2.1586 - val_mae: 0.8093 - lr: 3.2000e-06
# Epoch 167/500
# 34/34 [==============================] - 5s 140ms/step - loss: 0.3955 - mae: 0.4118 - val_loss: 2.1587 - val_mae: 0.8094 - lr: 3.2000e-06
# Epoch 168/500
# 34/34 [==============================] - ETA: 0s - loss: 0.3955 - mae: 0.4118
# Epoch 168: ReduceLROnPlateau reducing learning rate to 1e-06.
# 34/34 [==============================] - 5s 150ms/step - loss: 0.3955 - mae: 0.4118 - val_loss: 2.1585 - val_mae: 0.8093 - lr: 3.2000e-06
# Epoch 169/500
# 34/34 [==============================] - 5s 151ms/step - loss: 0.3955 - mae: 0.4117 - val_loss: 2.1585 - val_mae: 0.8093 - lr: 1.0000e-06
# Epoch 170/500
# 34/34 [==============================] - 5s 151ms/step - loss: 0.3955 - mae: 0.4117 - val_loss: 2.1585 - val_mae: 0.8094 - lr: 1.0000e-06
# Epoch 171/500
# 34/34 [==============================] - 5s 154ms/step - loss: 0.3955 - mae: 0.4117 - val_loss: 2.1585 - val_mae: 0.8093 - lr: 1.0000e-06
# Epoch 172/500
# 34/34 [==============================] - 5s 147ms/step - loss: 0.3955 - mae: 0.4117 - val_loss: 2.1585 - val_mae: 0.8093 - lr: 1.0000e-06
# Epoch 173/500
# 34/34 [==============================] - 5s 153ms/step - loss: 0.3955 - mae: 0.4118 - val_loss: 2.1585 - val_mae: 0.8093 - lr: 1.0000e-06

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 50, 40)            1680
#
#  simple_rnn_1 (SimpleRNN)    (None, 40)                3240
#
#  dense (Dense)               (None, 1)                 41
#
# =================================================================
# Total params: 4,961
# Trainable params: 4,961
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Showing training and validation loss
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
loss_values50 = loss_values[0:150]
val_loss_values50 = val_loss_values[0:150]
epochs = range(1, len(loss_values50) + 1)
plt.plot(epochs, loss_values50, label='Training Loss')
plt.plot(epochs, val_loss_values50, label='Validation Loss')
plt.rc('font', size = 14)
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.xticks(epochs)
plt.xticks(np.arange(min(epochs), max(epochs)+1, 10.0))
#fig.savefig('test&validationlosscnn.png', dpi=300)
plt.show()

# %%
loss_values = history_dict['mae']
val_loss_values = history_dict['val_mae']
loss_values50 = loss_values[0:150]
val_loss_values50 = val_loss_values[0:150]
epochs = range(1, len(loss_values50) + 1)
plt.plot(epochs, loss_values50, label='Training MAE')
plt.plot(epochs, val_loss_values50, label='Validation MAE')
plt.rc('font', size = 14)
plt.title('Training and Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.xticks(epochs)
plt.xticks(np.arange(min(epochs), max(epochs)+1, 10.0))
#fig.savefig('test&validationlosscnn.png', dpi=300)
plt.show()

# %%
#Evaluating model
trainScore = model.evaluate(Xtrain, Ytrain, verbose=1)
validScore = model.evaluate(Xvalid, Yvalid, verbose=1)
testScore = model.evaluate(Xtest, Ytest, verbose=1)
# Out:
# 134/134 [==============================] - 2s 18ms/step - loss: 0.3955 - mae: 0.4117
# 21/21 [==============================] - 0s 19ms/step - loss: 2.1587 - mae: 0.8093
# 22/22 [==============================] - 0s 20ms/step - loss: 1.0867 - mae: 0.7762

# %%
testScore, validScore, trainScore
# Out:
# ([1.0866972208023071, 0.7761947512626648],
#  [2.158735990524292, 0.8093220591545105],
#  [0.39553385972976685, 0.41172298789024353])

# %%
preds = model.predict(Xtest)
# Out:
# 22/22 [==============================] - 1s 16ms/step

# %%
Xtest.shape
# Out:
# (699, 50, 1)

# %%
plt.title('MAE: {}'.format(testScore[1]))
plt.plot(Ytest, label='Real')
plt.plot(preds, label='Prediction')

plt.legend(loc="best")

#for saving figures
# plt.savefig('CPALL_graph.png')
plt.show()

# %%
#denormalizing datasets
# preds = scaler.inverse_transform(preds)
# Ytest = scaler.inverse_transform(Ytest)

# %%
#Show Train and Test Scores
print('Train MSE \t Train RMSE \t Train MAE \t Testscore RMSE \tTest MSE \tTest MAE')
print('%.9f \t %.9f \t %.9f \t %.9f \t \t %.9f \t %.9f' % (trainScore[0], math.sqrt(trainScore[0]),trainScore[1],math.sqrt(testScore[0]),testScore[0],testScore[1]))
# Out:
# Train MSE 	 Train RMSE 	 Train MAE 	 Testscore RMSE 	Test MSE 	Test MAE
# 0.395533860 	 0.628914827 	 0.411722988 	 1.042447707 	 	 1.086697221 	 0.776194751

# %%
print('MAE \t\t MAPE')
print('%.4f \t\t %.4f' % (mean_absolute_error(Ytest,preds),(np.mean(np.abs((Ytest - preds) / Ytest)) * 100)))
# Out:
# MAE 		 MAPE
# 0.7762 		 2.0826
