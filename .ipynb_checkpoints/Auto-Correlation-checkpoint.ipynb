# %%
import numpy as np
import pandas as pd
import warnings

# %%
# DATA VISUALIZATION
# ------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (20.0, 10.0)
sns.set_style("darkgrid")
sns.color_palette("mako", as_cmap=True)
import plotly.express as px

# %%
df = pd.read_csv('Dataset/WFC Daily1.csv')
last_day = pd.DataFrame(df.iloc[-1 :])
last_day['Date'] = pd.to_datetime(last_day['Date']) + pd.Timedelta(days=1)
df = pd.concat([df, last_day], axis = 0)
df.reset_index(drop = True, inplace = True)
df.tail()
# Out:
#                      Date       Open       High        Low      Close  \
# 5750           2022-11-08  47.250000  47.470001  46.720001  47.180000
# 5751           2022-11-09  46.799999  47.000000  45.950001  45.970001
# 5752           2022-11-10  47.020000  48.110001  46.930000  47.950001
# 5753           2022-11-11  48.099998  48.360001  47.330002  47.549999
# 5754  2022-11-12 00:00:00  48.099998  48.360001  47.330002  47.549999
#
#       Adj Close    Volume
# 5750  47.180000  14842700
# 5751  45.970001  18318700
# 5752  47.950001  23091900
# 5753  47.549999  18060100
# 5754  47.549999  18060100

# %%
df_close = pd.DataFrame(df['Low'])
df_close.index = pd.to_datetime(df['Date'])
df_close.head()

sns.relplot(x='Date',y='Low', kind='line',data=df_close)
plt.xticks(rotation=45)
plt.plot()
# Out:
# []

# %%
# !pip install statsmodels==0.12.1

# %%
from statsmodels.tsa import stattools
acf,_,_,_ = stattools.acf(df_close,unbiased=True,nlags=50,qstat=True,fft=True,alpha = 0.05)
#acf is a numpy ndarray
sns.set_style("darkgrid")
sns.relplot(pd.Series(acf), kind='line')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [12], line 2
#       1 from statsmodels.tsa import stattools
# ----> 2 acf,_,_,_ = stattools.acf(df_close,unbiased=True,nlags=50,qstat=True,fft=True,alpha = 0.05)
#       3 #acf is a numpy ndarray
#       4 sns.set_style("darkgrid")
#
# TypeError: acf() got an unexpected keyword argument 'unbiased'
